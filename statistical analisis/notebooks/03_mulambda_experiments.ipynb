# %% [markdown]
# # μ+λ Evolution Strategy Experiments with Best Parameters (30 Seeds)
#
# This notebook runs μ+λ experiments with the best configuration using 30 different seeds for statistical analysis.

# %% [markdown]
# ## 1. Import Libraries

# %%
import os
import sys
import sqlite3
import time
import random
import numpy as np
import multiprocessing as mp

# Add project root to path
ROOT_DIR = os.path.dirname(os.path.abspath(os.getcwd()))
sys.path.append(ROOT_DIR)

from algorithms.mulambda_runner import run_mulambda

print("✓ Libraries imported successfully")
# Out:
# ✓ Libraries imported successfully

# %% [markdown]
# ## 2. Database Setup

# %%
DB_PATH = "../data/mulambda_experiments.db"

def init_mulambda_db(db_path):
    """Initialize database for μ+λ results"""
    con = sqlite3.connect(db_path)
    cur = con.cursor()
    
    cur.execute("""
        CREATE TABLE IF NOT EXISTS runs (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            mu INTEGER,
            lambda_ INTEGER,
            ngen INTEGER,
            cxpb REAL,
            mutpb REAL,
            seed INTEGER,
            best_penalized REAL,
            best_clean REAL,
            time_sec REAL,
            timestamp DATETIME DEFAULT CURRENT_TIMESTAMP
        )
    """)
    
    con.commit()
    con.close()
    print(f"✓ Database initialized: {db_path}")

init_mulambda_db(DB_PATH)
# Out:
# ✓ Database initialized: mulambda_experiments.db

# %% [markdown]
# ## 3. Save Results Function

# %%
def save_mulambda_run(db_path, mu, lambda_, ngen, cxpb, mutpb, seed, best_penalized, best_distance, time_sec):
    """Save a single μ+λ run to database"""
    con = sqlite3.connect(db_path)
    cur = con.cursor()
    
    cur.execute("""
        INSERT INTO runs (
            mu, lambda_, ngen, cxpb, mutpb, seed,
            best_penalized, best_clean, time_sec
        ) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
    """, (
        mu, lambda_, ngen, cxpb, mutpb, seed,
        float(best_penalized), float(best_distance), time_sec
    ))
    
    con.commit()
    con.close()

print("✓ Save function defined")
# Out:
# ✓ Save function defined

# %% [markdown]
# ## 4. Worker Function for Multiprocessing

# %%
def mulambda_worker(args):
    """Worker function to run a single μ+λ experiment"""
    mu, lambda_, ngen, cxpb, mutpb, seed, db_path = args
    
    t0 = time.time()
    try:
        results = run_mulambda(
            mu=mu,
            lambda_=lambda_,
            ngen=ngen,
            cxpb=cxpb,
            mutpb=mutpb,
            seed=seed,
            show_plots=False,
            show_anim=False,
            debug_interval=max(1, ngen // 10)
        )
        t1 = time.time()
        
        save_mulambda_run(db_path, mu, lambda_, ngen, cxpb, mutpb, seed, 
                         results['best_penalized'], results['best_distance'], t1 - t0)
        
        return {
            'success': True,
            'seed': seed,
            'best_penalized': results['best_penalized'],
            'time': t1 - t0
        }
    except Exception as e:
        return {
            'success': False,
            'seed': seed,
            'error': str(e)
        }

print("✓ Worker function defined")
# Out:
# ✓ Worker function defined

# %% [markdown]
# ## 5. Best Parameters Configuration

# %%
# Best parameters for μ+λ (from grid search: mu=120, lambda=120, ngen=800, cxpb=0.5)
BEST_PARAMS = {
    'mu': 120,
    'lambda_': 50,
    'ngen': 800,
    'cxpb': 0.5,
    'mutpb': 0.5  # mutpb = 1.0 - cxpb
}

# Seeds for statistical analysis (31 runs: 0-30)
SEEDS = list(range(31))

# Number of parallel processes
N_JOBS = min(8, mp.cpu_count())

print(f"Best parameters: {BEST_PARAMS}")
print(f"Number of seeds: {len(SEEDS)}")
print(f"Number of parallel jobs: {N_JOBS}")
print(f"Total experiments: {len(SEEDS)}")
# Out:
# Best parameters: {'mu': 120, 'lambda_': 50, 'ngen': 800, 'cxpb': 0.5, 'mutpb': 0.5}
# Number of seeds: 31
# Number of parallel jobs: 8
# Total experiments: 31

# %% [markdown]
# ## 6. Run Experiments with Multithreading

# %%
from tqdm.notebook import tqdm

# Generate tasks (one per seed, no nested loops)
tasks = [(BEST_PARAMS['mu'], BEST_PARAMS['lambda_'], BEST_PARAMS['ngen'], 
          BEST_PARAMS['cxpb'], BEST_PARAMS['mutpb'], seed, DB_PATH) for seed in SEEDS]

print(f"Total experiments to run: {len(tasks)}")
print(f"Running with {N_JOBS} parallel workers...\n")

# Run experiments in parallel
start_time = time.time()
with mp.Pool(processes=N_JOBS) as pool:
    results = list(tqdm(
        pool.imap(mulambda_worker, tasks),
        total=len(tasks),
        desc="μ+λ Experiments"
    ))
total_time = time.time() - start_time

# Summary
successful = sum(1 for r in results if r['success'])
failed = len(results) - successful

print(f"\n{'='*60}")
print(f"Experiments completed!")
print(f"Successful: {successful}")
print(f"Failed: {failed}")
print(f"Total time: {total_time/60:.2f} minutes")
print(f"Average time per run: {total_time/len(tasks):.2f} seconds")
print(f"{'='*60}")
# Out:
# Total experiments to run: 31
# Running with 8 parallel workers...
#
# [INFO] Valores únicos del BMP original:[INFO] Valores únicos del BMP original:
# μ+λ Experiments:   0%|          | 0/31 [00:00<?, ?it/s]
# [INFO] Valores únicos del BMP original: [INFO] Valores únicos del BMP original:[INFO] Valores únicos del BMP original:[INFO] Valores únicos del BMP original:    [INFO] Valores únicos del BMP original:[  0 255][  0 255] [  0 255] [  0 255]
# [  0 255]
# [  0 255]
#
#
# [  0 255][INFO] Valores únicos tras invertir:[INFO] Valores únicos del BMP original:[INFO] Valores únicos tras invertir:[INFO] Valores únicos tras invertir:
# [INFO] Valores únicos tras invertir:
#     [INFO] Valores únicos tras invertir:[INFO] Valores únicos tras invertir: [  0 255][  0 255][  0 255] [  0 255] [  0 255]
# [INFO] Valores únicos tras invertir:[  0 255]
#
# [  0 255]
#
# [INFO] Environment cargado: 92 x 113[INFO] Environment cargado: 92 x 113
# [INFO] Environment cargado: 92 x 113[INFO] Environment cargado: 92 x 113[INFO] Valores únicos tras invertir:
#
#
#
# [  0 255] [INFO] Environment cargado: 92 x 113
#
# [INFO] Environment cargado: 92 x 113[  0 255]
# [INFO] Environment cargado: 92 x 113
#
#
# [INFO] Environment cargado: 92 x 113
# [GEN   80] CleanBestDist=1080.12  CleanAvgDist=1085.82  Std=1.31  MinDist=5.00  Conflicts=3
# [GEN   80] CleanBestDist=1085.39  CleanAvgDist=1086.80  Std=0.13  MinDist=1.00  Conflicts=5
# [GEN   80] CleanBestDist=1077.32  CleanAvgDist=1078.50  Std=2.47  MinDist=5.00  Conflicts=3
# [GEN   80] CleanBestDist=1084.05  CleanAvgDist=1085.92  Std=5.17  MinDist=5.00  Conflicts=2
# [GEN   80] CleanBestDist=1085.71  CleanAvgDist=1122.94  Std=65.24  MinDist=6.71  Conflicts=0
# [GEN   80] CleanBestDist=1089.29  CleanAvgDist=1093.35  Std=6.08  MinDist=6.08  Conflicts=0
# [GEN   80] CleanBestDist=1080.91  CleanAvgDist=1080.91  Std=0.00  MinDist=5.00  Conflicts=2
# [GEN   80] CleanBestDist=1076.57  CleanAvgDist=1120.47  Std=48.44  MinDist=5.00  Conflicts=2
# [GEN  160] CleanBestDist=1080.12  CleanAvgDist=1080.12  Std=0.00  MinDist=5.00  Conflicts=3
# [GEN  160] CleanBestDist=1089.29  CleanAvgDist=1089.29  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  160] CleanBestDist=1074.32  CleanAvgDist=1074.32  Std=0.00  MinDist=5.00  Conflicts=3
# [GEN  160] CleanBestDist=1085.39  CleanAvgDist=1085.39  Std=0.00  MinDist=1.00  Conflicts=5
# [GEN  160] CleanBestDist=1080.91  CleanAvgDist=1080.91  Std=0.00  MinDist=5.00  Conflicts=2
# [GEN  160] CleanBestDist=1167.26  CleanAvgDist=1167.26  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  160] CleanBestDist=1096.39  CleanAvgDist=1097.89  Std=1.96  MinDist=5.00  Conflicts=1
# [GEN  160] CleanBestDist=1206.16  CleanAvgDist=1206.16  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  240] CleanBestDist=1080.12  CleanAvgDist=1081.67  Std=11.89  MinDist=5.39  Conflicts=1
# [GEN  240] CleanBestDist=1089.29  CleanAvgDist=1089.29  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  240] CleanBestDist=1080.91  CleanAvgDist=1080.91  Std=0.00  MinDist=5.00  Conflicts=2
# [GEN  240] CleanBestDist=1074.32  CleanAvgDist=1074.32  Std=0.00  MinDist=5.00  Conflicts=3
# [GEN  240] CleanBestDist=1176.68  CleanAvgDist=1181.76  Std=1.47  MinDist=6.32  Conflicts=0
# [GEN  240] CleanBestDist=1096.39  CleanAvgDist=1096.39  Std=0.00  MinDist=5.00  Conflicts=1
# [GEN  240] CleanBestDist=1166.44  CleanAvgDist=1166.44  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  240] CleanBestDist=1203.34  CleanAvgDist=1203.34  Std=0.00  MinDist=6.71  Conflicts=0
# [GEN  320] CleanBestDist=1089.29  CleanAvgDist=1089.29  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  320] CleanBestDist=1080.91  CleanAvgDist=1080.91  Std=0.00  MinDist=5.00  Conflicts=2
# [GEN  320] CleanBestDist=1074.32  CleanAvgDist=1074.32  Std=0.00  MinDist=5.00  Conflicts=3
# [GEN  320] CleanBestDist=1172.99  CleanAvgDist=1172.99  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  320] CleanBestDist=1096.39  CleanAvgDist=1096.39  Std=0.00  MinDist=5.00  Conflicts=1
# [GEN  320] CleanBestDist=1171.85  CleanAvgDist=1173.47  Std=0.82  MinDist=6.71  Conflicts=0
# [GEN  320] CleanBestDist=1163.02  CleanAvgDist=1163.02  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  320] CleanBestDist=1197.51  CleanAvgDist=1200.84  Std=0.53  MinDist=7.07  Conflicts=0
# [GEN  400] CleanBestDist=1089.29  CleanAvgDist=1089.29  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  400] CleanBestDist=1088.32  CleanAvgDist=1088.32  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  400] CleanBestDist=1074.32  CleanAvgDist=1074.32  Std=0.00  MinDist=5.00  Conflicts=3
# [GEN  400] CleanBestDist=1096.39  CleanAvgDist=1096.39  Std=0.00  MinDist=5.00  Conflicts=1
# [GEN  400] CleanBestDist=1167.34  CleanAvgDist=1170.14  Std=0.26  MinDist=6.08  Conflicts=0
# [GEN  400] CleanBestDist=1167.85  CleanAvgDist=1167.85  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN  400] CleanBestDist=1163.02  CleanAvgDist=1163.02  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  400] CleanBestDist=1192.92  CleanAvgDist=1192.92  Std=0.00  MinDist=7.07  Conflicts=0
# [GEN  480] CleanBestDist=1089.29  CleanAvgDist=1089.29  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  480] CleanBestDist=1088.32  CleanAvgDist=1088.32  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  480] CleanBestDist=1081.32  CleanAvgDist=1081.32  Std=0.00  MinDist=5.00  Conflicts=2
# [GEN  480] CleanBestDist=1096.39  CleanAvgDist=1096.39  Std=0.00  MinDist=5.00  Conflicts=1
# [GEN  480] CleanBestDist=1167.34  CleanAvgDist=1167.34  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  480] CleanBestDist=1166.85  CleanAvgDist=1166.85  Std=0.00  MinDist=7.00  Conflicts=0
# [GEN  480] CleanBestDist=1163.02  CleanAvgDist=1163.02  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  480] CleanBestDist=1191.51  CleanAvgDist=1192.14  Std=0.35  MinDist=7.07  Conflicts=0
# [GEN  560] CleanBestDist=1089.29  CleanAvgDist=1089.29  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  560] CleanBestDist=1088.32  CleanAvgDist=1088.32  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  560] CleanBestDist=1133.81  CleanAvgDist=1133.81  Std=0.00  MinDist=5.83  Conflicts=1
# [GEN  560] CleanBestDist=1093.57  CleanAvgDist=1096.28  Std=0.57  MinDist=5.00  Conflicts=1
# [GEN  560] CleanBestDist=1165.92  CleanAvgDist=1167.32  Std=0.13  MinDist=6.08  Conflicts=0
# [GEN  560] CleanBestDist=1166.85  CleanAvgDist=1166.85  Std=0.00  MinDist=7.00  Conflicts=0
# [GEN  560] CleanBestDist=1163.02  CleanAvgDist=1163.02  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  560] CleanBestDist=1188.51  CleanAvgDist=1188.51  Std=0.00  MinDist=7.07  Conflicts=0
# [GEN  640] CleanBestDist=1089.29  CleanAvgDist=1089.29  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  640] CleanBestDist=1086.91  CleanAvgDist=1088.29  Std=0.22  MinDist=6.08  Conflicts=0
# [GEN  640] CleanBestDist=1129.81  CleanAvgDist=1141.20  Std=28.79  MinDist=6.00  Conflicts=0
# [GEN  640] CleanBestDist=1092.98  CleanAvgDist=1092.98  Std=0.00  MinDist=5.00  Conflicts=1
# [GEN  640] CleanBestDist=1165.92  CleanAvgDist=1165.92  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  640] CleanBestDist=1161.61  CleanAvgDist=1161.61  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN  640] CleanBestDist=1164.85  CleanAvgDist=1164.85  Std=0.00  MinDist=7.00  Conflicts=0
# [GEN  640] CleanBestDist=1188.51  CleanAvgDist=1188.51  Std=0.00  MinDist=7.07  Conflicts=0
# [GEN  720] CleanBestDist=1089.29  CleanAvgDist=1089.29  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  720] CleanBestDist=1082.91  CleanAvgDist=1086.81  Std=0.62  MinDist=6.08  Conflicts=0
# [GEN  720] CleanBestDist=1092.98  CleanAvgDist=1092.98  Std=0.00  MinDist=5.00  Conflicts=1
# [GEN  720] CleanBestDist=1205.36  CleanAvgDist=1208.34  Std=0.27  MinDist=6.08  Conflicts=0
# [GEN  720] CleanBestDist=1165.92  CleanAvgDist=1165.92  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  720] CleanBestDist=1161.61  CleanAvgDist=1161.61  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN  720] CleanBestDist=1163.68  CleanAvgDist=1163.68  Std=0.00  MinDist=7.00  Conflicts=0
# [GEN  720] CleanBestDist=1188.51  CleanAvgDist=1188.51  Std=0.00  MinDist=7.07  Conflicts=0
# [GEN  800] CleanBestDist=1089.29  CleanAvgDist=1089.29  Std=0.00  MinDist=6.08  Conflicts=0
#
# ===== μ+λ COMPLETADO =====
# Mejor fitness penalizado = 1618.244
# Mejor distancia real     = 1089.294
# Tiempo = 188.11 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN  800] CleanBestDist=1082.91  CleanAvgDist=1082.91  Std=0.00  MinDist=6.08  Conflicts=0
#
# ===== μ+λ COMPLETADO =====
# Mejor fitness penalizado = 1104.659
# Mejor distancia real     = 1082.909
# Tiempo = 189.94 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN  800] CleanBestDist=1092.39  CleanAvgDist=1130.48  Std=42.97  MinDist=7.00  Conflicts=0
#
# ===== μ+λ COMPLETADO =====
# Mejor fitness penalizado = 1298.979
# Mejor distancia real     = 1177.779
# Tiempo = 194.10 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN  800] CleanBestDist=1205.54  CleanAvgDist=1205.54  Std=0.00  MinDist=6.08  Conflicts=0
#
# ===== μ+λ COMPLETADO =====
# Mejor fitness penalizado = 1404.086
# Mejor distancia real     = 1205.536
# Tiempo = 196.95 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN  800] CleanBestDist=1161.92  CleanAvgDist=1161.92  Std=0.00  MinDist=6.08  Conflicts=0
#
# ===== μ+λ COMPLETADO =====
# Mejor fitness penalizado = 1316.221
# Mejor distancia real     = 1161.921
# Tiempo = 199.93 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN  800] CleanBestDist=1161.61  CleanAvgDist=1161.61  Std=0.00  MinDist=6.00  Conflicts=0
#
# ===== μ+λ COMPLETADO =====
# Mejor fitness penalizado = 1328.357
# Mejor distancia real     = 1161.607
# Tiempo = 200.93 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN  800] CleanBestDist=1163.68  CleanAvgDist=1163.68  Std=0.00  MinDist=7.00  Conflicts=0
#
# ===== μ+λ COMPLETADO =====
# Mejor fitness penalizado = 1202.478
# Mejor distancia real     = 1163.678
# Tiempo = 201.46 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN  800] CleanBestDist=1184.68  CleanAvgDist=1184.68  Std=0.00  MinDist=7.07  Conflicts=0
#
# ===== μ+λ COMPLETADO =====
# Mejor fitness penalizado = 1277.878
# Mejor distancia real     = 1184.678
# Tiempo = 207.19 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN   80] CleanBestDist=1076.91  CleanAvgDist=1076.97  Std=0.37  MinDist=5.00  Conflicts=2
# [GEN   80] CleanBestDist=1202.85  CleanAvgDist=1211.53  Std=2.77  MinDist=7.62  Conflicts=0
# [GEN   80] CleanBestDist=1086.29  CleanAvgDist=1094.99  Std=10.91  MinDist=6.08  Conflicts=0
# [GEN   80] CleanBestDist=1103.64  CleanAvgDist=1104.73  Std=1.19  MinDist=5.00  Conflicts=2
# [GEN   80] CleanBestDist=1148.78  CleanAvgDist=1152.53  Std=1.12  MinDist=6.32  Conflicts=0
# [GEN   80] CleanBestDist=1070.47  CleanAvgDist=1091.87  Std=31.08  MinDist=6.00  Conflicts=0
# [GEN   80] CleanBestDist=1079.71  CleanAvgDist=1079.79  Std=0.33  MinDist=5.00  Conflicts=3
# [GEN   80] CleanBestDist=1079.29  CleanAvgDist=1085.38  Std=14.75  MinDist=5.00  Conflicts=2
# [GEN  160] CleanBestDist=1078.74  CleanAvgDist=1078.74  Std=0.00  MinDist=5.00  Conflicts=2
# [GEN  160] CleanBestDist=1175.02  CleanAvgDist=1175.02  Std=0.00  MinDist=7.00  Conflicts=0
# [GEN  160] CleanBestDist=1101.12  CleanAvgDist=1118.07  Std=15.91  MinDist=7.00  Conflicts=0
# [GEN  160] CleanBestDist=1187.31  CleanAvgDist=1187.89  Std=0.05  MinDist=7.00  Conflicts=0
# [GEN  160] CleanBestDist=1150.36  CleanAvgDist=1150.36  Std=0.00  MinDist=6.40  Conflicts=0
# [GEN  160] CleanBestDist=1078.88  CleanAvgDist=1079.48  Std=1.92  MinDist=5.39  Conflicts=2
# [GEN  160] CleanBestDist=1171.02  CleanAvgDist=1172.87  Std=0.53  MinDist=6.32  Conflicts=0
# [GEN  160] CleanBestDist=1081.88  CleanAvgDist=1081.88  Std=0.00  MinDist=5.00  Conflicts=2
# [GEN  240] CleanBestDist=1085.15  CleanAvgDist=1085.15  Std=0.00  MinDist=5.66  Conflicts=1
# [GEN  240] CleanBestDist=1095.29  CleanAvgDist=1095.94  Std=0.70  MinDist=6.40  Conflicts=0
# [GEN  240] CleanBestDist=1169.02  CleanAvgDist=1173.40  Std=7.57  MinDist=7.07  Conflicts=0
# [GEN  240] CleanBestDist=1185.89  CleanAvgDist=1185.89  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  240] CleanBestDist=1098.36  CleanAvgDist=1099.52  Std=1.39  MinDist=5.39  Conflicts=1
# [GEN  240] CleanBestDist=1146.95  CleanAvgDist=1147.78  Std=0.70  MinDist=6.40  Conflicts=0
# [GEN  240] CleanBestDist=1167.02  CleanAvgDist=1170.99  Std=0.36  MinDist=6.32  Conflicts=0
# [GEN  240] CleanBestDist=1168.02  CleanAvgDist=1168.02  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN  320] CleanBestDist=1085.15  CleanAvgDist=1085.15  Std=0.00  MinDist=5.66  Conflicts=1
# [GEN  320] CleanBestDist=1095.29  CleanAvgDist=1095.29  Std=0.00  MinDist=6.40  Conflicts=0
# [GEN  320] CleanBestDist=1169.02  CleanAvgDist=1169.02  Std=0.00  MinDist=7.07  Conflicts=0
# [GEN  320] CleanBestDist=1185.31  CleanAvgDist=1185.31  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  320] CleanBestDist=1120.09  CleanAvgDist=1120.09  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  320] CleanBestDist=1145.54  CleanAvgDist=1146.32  Std=0.19  MinDist=6.32  Conflicts=0
# [GEN  320] CleanBestDist=1166.44  CleanAvgDist=1166.44  Std=0.00  MinDist=6.32  Conflicts=0
# [GEN  400] CleanBestDist=1087.57  CleanAvgDist=1087.57  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  320] CleanBestDist=1168.02  CleanAvgDist=1168.02  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN  400] CleanBestDist=1094.47  CleanAvgDist=1094.47  Std=0.00  MinDist=6.40  Conflicts=0
# [GEN  400] CleanBestDist=1167.02  CleanAvgDist=1169.00  Std=0.18  MinDist=7.07  Conflicts=0
# [GEN  400] CleanBestDist=1184.31  CleanAvgDist=1184.31  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  400] CleanBestDist=1118.09  CleanAvgDist=1118.09  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  400] CleanBestDist=1139.54  CleanAvgDist=1139.54  Std=0.00  MinDist=6.32  Conflicts=0
# [GEN  480] CleanBestDist=1086.98  CleanAvgDist=1087.50  Std=0.19  MinDist=6.08  Conflicts=0
# [GEN  400] CleanBestDist=1163.85  CleanAvgDist=1163.85  Std=0.00  MinDist=6.32  Conflicts=0
# [GEN  400] CleanBestDist=1168.02  CleanAvgDist=1168.02  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN  480] CleanBestDist=1090.81  CleanAvgDist=1091.90  Std=0.50  MinDist=6.40  Conflicts=0
# [GEN  480] CleanBestDist=1164.02  CleanAvgDist=1164.02  Std=0.00  MinDist=7.07  Conflicts=0
# [GEN  480] CleanBestDist=1183.48  CleanAvgDist=1184.21  Std=0.27  MinDist=6.08  Conflicts=0
# [GEN  480] CleanBestDist=1118.09  CleanAvgDist=1118.09  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  480] CleanBestDist=1134.12  CleanAvgDist=1134.12  Std=0.00  MinDist=7.21  Conflicts=0
# [GEN  560] CleanBestDist=1086.98  CleanAvgDist=1086.98  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  480] CleanBestDist=1160.44  CleanAvgDist=1163.45  Std=1.10  MinDist=6.32  Conflicts=0
# [GEN  480] CleanBestDist=1168.02  CleanAvgDist=1168.02  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN  560] CleanBestDist=1090.81  CleanAvgDist=1090.81  Std=0.00  MinDist=6.40  Conflicts=0
# [GEN  560] CleanBestDist=1161.44  CleanAvgDist=1162.01  Std=0.09  MinDist=6.40  Conflicts=0
# [GEN  560] CleanBestDist=1179.06  CleanAvgDist=1180.41  Std=0.21  MinDist=6.08  Conflicts=0
# [GEN  560] CleanBestDist=1115.26  CleanAvgDist=1117.76  Std=0.91  MinDist=6.08  Conflicts=0
# [GEN  560] CleanBestDist=1130.12  CleanAvgDist=1133.19  Std=1.69  MinDist=7.07  Conflicts=0
# [GEN  640] CleanBestDist=1086.98  CleanAvgDist=1086.98  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  560] CleanBestDist=1159.85  CleanAvgDist=1159.85  Std=0.00  MinDist=6.32  Conflicts=0
# [GEN  640] CleanBestDist=1090.81  CleanAvgDist=1090.81  Std=0.00  MinDist=6.40  Conflicts=0
# [GEN  560] CleanBestDist=1168.02  CleanAvgDist=1168.02  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN  640] CleanBestDist=1155.02  CleanAvgDist=1155.02  Std=0.00  MinDist=6.40  Conflicts=0
# [GEN  640] CleanBestDist=1115.26  CleanAvgDist=1115.26  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  640] CleanBestDist=1168.58  CleanAvgDist=1176.09  Std=0.99  MinDist=6.08  Conflicts=0
# [GEN  720] CleanBestDist=1086.98  CleanAvgDist=1086.98  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  640] CleanBestDist=1126.71  CleanAvgDist=1126.71  Std=0.00  MinDist=7.00  Conflicts=0
# [GEN  720] CleanBestDist=1090.81  CleanAvgDist=1090.81  Std=0.00  MinDist=6.40  Conflicts=0
# [GEN  640] CleanBestDist=1159.26  CleanAvgDist=1159.26  Std=0.00  MinDist=6.32  Conflicts=0
# [GEN  640] CleanBestDist=1168.02  CleanAvgDist=1168.02  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN  720] CleanBestDist=1151.02  CleanAvgDist=1151.02  Std=0.00  MinDist=6.40  Conflicts=0
# [GEN  720] CleanBestDist=1168.58  CleanAvgDist=1168.58  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  720] CleanBestDist=1115.26  CleanAvgDist=1115.26  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  800] CleanBestDist=1086.98  CleanAvgDist=1086.98  Std=0.00  MinDist=6.08  Conflicts=0
#
# ===== μ+λ COMPLETADO =====
# Mejor fitness penalizado = 1277.130
# Mejor distancia real     = 1086.980
# Tiempo = 185.88 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN  720] CleanBestDist=1126.12  CleanAvgDist=1126.69  Std=0.09  MinDist=6.08  Conflicts=0
# [GEN  800] CleanBestDist=1090.81  CleanAvgDist=1090.81  Std=0.00  MinDist=6.40  Conflicts=0
#
# ===== μ+λ COMPLETADO =====
# Mejor fitness penalizado = 1139.608
# Mejor distancia real     = 1090.808
# Tiempo = 183.86 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN  720] CleanBestDist=1158.26  CleanAvgDist=1158.97  Std=0.45  MinDist=6.32  Conflicts=0
# [GEN  720] CleanBestDist=1168.02  CleanAvgDist=1168.02  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN  800] CleanBestDist=1151.02  CleanAvgDist=1151.02  Std=0.00  MinDist=6.40  Conflicts=0
#
# ===== μ+λ COMPLETADO =====
# Mejor fitness penalizado = 1427.821
# Mejor distancia real     = 1151.021
# Tiempo = 197.84 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN  800] CleanBestDist=1112.19  CleanAvgDist=1112.19  Std=0.00  MinDist=6.08  Conflicts=0
#
# ===== μ+λ COMPLETADO =====
# Mejor fitness penalizado = 1221.943
# Mejor distancia real     = 1112.193
# Tiempo = 187.52 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN  800] CleanBestDist=1168.58  CleanAvgDist=1168.58  Std=0.00  MinDist=6.08  Conflicts=0
#
# ===== μ+λ COMPLETADO =====
# Mejor fitness penalizado = 1256.328
# Mejor distancia real     = 1168.578
# Tiempo = 192.37 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN   80] CleanBestDist=1099.15  CleanAvgDist=1100.56  Std=4.46  MinDist=5.00  Conflicts=2
# [GEN  800] CleanBestDist=1124.12  CleanAvgDist=1124.12  Std=0.00  MinDist=6.08  Conflicts=0
#
# ===== μ+λ COMPLETADO =====
# Mejor fitness penalizado = 1242.572
# Mejor distancia real     = 1124.122
# Tiempo = 194.84 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN   80] CleanBestDist=1079.98  CleanAvgDist=1081.23  Std=5.96  MinDist=5.00  Conflicts=2
# [GEN  800] CleanBestDist=1157.44  CleanAvgDist=1157.44  Std=0.00  MinDist=6.32  Conflicts=0
#
# ===== μ+λ COMPLETADO =====
# Mejor fitness penalizado = 1245.786
# Mejor distancia real     = 1157.436
# Tiempo = 199.80 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN  800] CleanBestDist=1168.02  CleanAvgDist=1168.02  Std=0.00  MinDist=6.00  Conflicts=0
#
# ===== μ+λ COMPLETADO =====
# Mejor fitness penalizado = 1338.421
# Mejor distancia real     = 1168.021
# Tiempo = 194.06 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN   80] CleanBestDist=1192.89  CleanAvgDist=1193.22  Std=2.55  MinDist=7.21  Conflicts=0
# [GEN   80] CleanBestDist=1104.12  CleanAvgDist=1106.91  Std=12.32  MinDist=6.00  Conflicts=0
# [GEN   80] CleanBestDist=1093.88  CleanAvgDist=1096.33  Std=7.86  MinDist=6.00  Conflicts=0
# [GEN  160] CleanBestDist=1127.78  CleanAvgDist=1134.38  Std=1.23  MinDist=5.00  Conflicts=2
# [GEN   80] CleanBestDist=1127.71  CleanAvgDist=1127.71  Std=0.00  MinDist=5.00  Conflicts=2
# [GEN  160] CleanBestDist=1106.05  CleanAvgDist=1106.05  Std=0.00  MinDist=5.00  Conflicts=2
# [GEN   80] CleanBestDist=1096.05  CleanAvgDist=1100.33  Std=19.30  MinDist=5.10  Conflicts=1
# [GEN   80] CleanBestDist=1087.36  CleanAvgDist=1087.36  Std=0.00  MinDist=5.00  Conflicts=2
# [GEN  160] CleanBestDist=1101.88  CleanAvgDist=1101.88  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN  160] CleanBestDist=1165.85  CleanAvgDist=1165.85  Std=0.00  MinDist=7.07  Conflicts=0
# [GEN  160] CleanBestDist=1211.38  CleanAvgDist=1211.38  Std=0.00  MinDist=7.00  Conflicts=0
# [GEN  240] CleanBestDist=1124.78  CleanAvgDist=1126.19  Std=1.32  MinDist=5.00  Conflicts=2
# [GEN  160] CleanBestDist=1127.12  CleanAvgDist=1127.12  Std=0.00  MinDist=5.00  Conflicts=2
# [GEN  240] CleanBestDist=1106.05  CleanAvgDist=1106.05  Std=0.00  MinDist=5.00  Conflicts=2
# [GEN  160] CleanBestDist=1091.12  CleanAvgDist=1093.88  Std=0.44  MinDist=6.08  Conflicts=0
# [GEN  160] CleanBestDist=1098.88  CleanAvgDist=1101.86  Std=18.61  MinDist=5.10  Conflicts=1
# [GEN  240] CleanBestDist=1101.88  CleanAvgDist=1101.88  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN  240] CleanBestDist=1165.26  CleanAvgDist=1165.84  Std=0.07  MinDist=7.07  Conflicts=0
# [GEN  240] CleanBestDist=1211.38  CleanAvgDist=1211.38  Std=0.00  MinDist=7.00  Conflicts=0
# [GEN  320] CleanBestDist=1209.58  CleanAvgDist=1209.58  Std=0.00  MinDist=6.40  Conflicts=0
# [GEN  240] CleanBestDist=1177.68  CleanAvgDist=1183.03  Std=1.86  MinDist=6.00  Conflicts=0
# [GEN  320] CleanBestDist=1103.05  CleanAvgDist=1103.05  Std=0.00  MinDist=5.00  Conflicts=2
# [GEN  240] CleanBestDist=1091.12  CleanAvgDist=1091.12  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  240] CleanBestDist=1218.06  CleanAvgDist=1218.16  Std=0.87  MinDist=6.00  Conflicts=0
# [GEN  320] CleanBestDist=1101.88  CleanAvgDist=1101.88  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN  320] CleanBestDist=1162.44  CleanAvgDist=1163.39  Std=0.66  MinDist=7.07  Conflicts=0
# [GEN  320] CleanBestDist=1205.13  CleanAvgDist=1206.25  Std=0.57  MinDist=7.21  Conflicts=0
# [GEN  400] CleanBestDist=1209.58  CleanAvgDist=1209.58  Std=0.00  MinDist=6.40  Conflicts=0
# [GEN  320] CleanBestDist=1170.19  CleanAvgDist=1176.73  Std=0.85  MinDist=6.00  Conflicts=0
# [GEN  400] CleanBestDist=1103.05  CleanAvgDist=1103.05  Std=0.00  MinDist=5.00  Conflicts=2
# [GEN  320] CleanBestDist=1091.12  CleanAvgDist=1091.12  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  320] CleanBestDist=1218.23  CleanAvgDist=1220.16  Std=0.70  MinDist=6.08  Conflicts=0
# [GEN  400] CleanBestDist=1101.29  CleanAvgDist=1101.29  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  400] CleanBestDist=1162.44  CleanAvgDist=1162.44  Std=0.00  MinDist=7.07  Conflicts=0
# [GEN  400] CleanBestDist=1205.13  CleanAvgDist=1205.13  Std=0.00  MinDist=7.21  Conflicts=0
# [GEN  480] CleanBestDist=1209.58  CleanAvgDist=1209.58  Std=0.00  MinDist=6.40  Conflicts=0
# [GEN  400] CleanBestDist=1168.78  CleanAvgDist=1168.78  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN  400] CleanBestDist=1091.12  CleanAvgDist=1091.12  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  480] CleanBestDist=1203.19  CleanAvgDist=1203.19  Std=0.00  MinDist=7.07  Conflicts=0
# [GEN  400] CleanBestDist=1214.82  CleanAvgDist=1216.12  Std=0.39  MinDist=6.08  Conflicts=0
# [GEN  480] CleanBestDist=1100.29  CleanAvgDist=1100.29  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN  480] CleanBestDist=1156.44  CleanAvgDist=1162.39  Std=0.55  MinDist=7.07  Conflicts=0
# [GEN  480] CleanBestDist=1168.19  CleanAvgDist=1168.19  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN  480] CleanBestDist=1091.12  CleanAvgDist=1091.12  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  480] CleanBestDist=1201.13  CleanAvgDist=1202.93  Std=0.60  MinDist=6.00  Conflicts=0
# [GEN  560] CleanBestDist=1207.58  CleanAvgDist=1207.58  Std=0.00  MinDist=6.32  Conflicts=0
# [GEN  560] CleanBestDist=1203.19  CleanAvgDist=1203.19  Std=0.00  MinDist=7.07  Conflicts=0
# [GEN  480] CleanBestDist=1214.82  CleanAvgDist=1214.82  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  560] CleanBestDist=1100.29  CleanAvgDist=1100.29  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN  560] CleanBestDist=1156.44  CleanAvgDist=1156.44  Std=0.00  MinDist=7.07  Conflicts=0
# [GEN  560] CleanBestDist=1088.29  CleanAvgDist=1088.29  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  560] CleanBestDist=1168.19  CleanAvgDist=1168.19  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN  560] CleanBestDist=1199.13  CleanAvgDist=1199.13  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN  640] CleanBestDist=1207.58  CleanAvgDist=1207.58  Std=0.00  MinDist=6.32  Conflicts=0
# [GEN  640] CleanBestDist=1197.54  CleanAvgDist=1197.54  Std=0.00  MinDist=6.32  Conflicts=0
# [GEN  640] CleanBestDist=1095.29  CleanAvgDist=1095.29  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN  560] CleanBestDist=1207.58  CleanAvgDist=1207.58  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  640] CleanBestDist=1156.44  CleanAvgDist=1156.44  Std=0.00  MinDist=7.07  Conflicts=0
# [GEN  640] CleanBestDist=1088.29  CleanAvgDist=1088.29  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  640] CleanBestDist=1164.19  CleanAvgDist=1164.19  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN  640] CleanBestDist=1197.13  CleanAvgDist=1199.08  Std=0.31  MinDist=6.00  Conflicts=0
# [GEN  720] CleanBestDist=1207.58  CleanAvgDist=1207.58  Std=0.00  MinDist=6.32  Conflicts=0
# [GEN  720] CleanBestDist=1196.95  CleanAvgDist=1196.95  Std=0.00  MinDist=6.32  Conflicts=0
# [GEN  720] CleanBestDist=1095.29  CleanAvgDist=1095.29  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN  640] CleanBestDist=1206.58  CleanAvgDist=1206.58  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  720] CleanBestDist=1156.44  CleanAvgDist=1156.44  Std=0.00  MinDist=7.07  Conflicts=0
# [GEN  720] CleanBestDist=1088.29  CleanAvgDist=1088.29  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  720] CleanBestDist=1157.19  CleanAvgDist=1157.19  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN  720] CleanBestDist=1194.13  CleanAvgDist=1197.06  Std=0.47  MinDist=6.00  Conflicts=0
# [GEN  800] CleanBestDist=1205.58  CleanAvgDist=1205.58  Std=0.00  MinDist=6.08  Conflicts=0
#
# ===== μ+λ COMPLETADO =====
# Mejor fitness penalizado = 1342.578
# Mejor distancia real     = 1205.578
# Tiempo = 198.94 s
# [INFO] Valores únicos del BMP original: [GEN  800] CleanBestDist=1193.95  CleanAvgDist=1194.47  Std=0.67  MinDist=6.32  Conflicts=0[  0 255]
#
#
# ===== μ+λ COMPLETADO =====[INFO] Valores únicos tras invertir:
#  Mejor fitness penalizado = 1457.450[  0 255]
#
# [INFO] Environment cargado: 92 x 113Mejor distancia real     = 1193.950
#
# Tiempo = 194.95 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN  800] CleanBestDist=1095.29  CleanAvgDist=1095.29  Std=0.00  MinDist=6.00  Conflicts=0
#
# ===== μ+λ COMPLETADO =====
# Mejor fitness penalizado = 1177.044
# Mejor distancia real     = 1095.294
# Tiempo = 183.48 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN  720] CleanBestDist=1199.75  CleanAvgDist=1203.72  Std=0.36  MinDist=6.08  Conflicts=0
# [GEN  800] CleanBestDist=1088.29  CleanAvgDist=1088.29  Std=0.00  MinDist=6.08  Conflicts=0
#
# ===== μ+λ COMPLETADO =====
# Mejor fitness penalizado = 1117.744
# Mejor distancia real     = 1088.294
# Tiempo = 182.23 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN  800] CleanBestDist=1156.44  CleanAvgDist=1156.44  Std=0.00  MinDist=7.07  Conflicts=0
#
# ===== μ+λ COMPLETADO =====
# Mejor fitness penalizado = 1179.236
# Mejor distancia real     = 1156.436
# Tiempo = 195.36 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN  800] CleanBestDist=1157.19  CleanAvgDist=1157.19  Std=0.00  MinDist=6.00  Conflicts=0
#
# ===== μ+λ COMPLETADO =====
# Mejor fitness penalizado = 1187.293
# Mejor distancia real     = 1157.193
# Tiempo = 193.58 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN   80] CleanBestDist=1122.95  CleanAvgDist=1122.95  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN   80] CleanBestDist=1108.71  CleanAvgDist=1108.71  Std=0.00  MinDist=5.00  Conflicts=2
# [GEN  800] CleanBestDist=1194.13  CleanAvgDist=1194.13  Std=0.00  MinDist=6.00  Conflicts=0
#
# ===== μ+λ COMPLETADO =====
# Mejor fitness penalizado = 1228.934
# Mejor distancia real     = 1194.134
# Tiempo = 205.12 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN   80] CleanBestDist=1138.09  CleanAvgDist=1138.09  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN  800] CleanBestDist=1199.16  CleanAvgDist=1199.16  Std=0.00  MinDist=6.08  Conflicts=0
#
# ===== μ+λ COMPLETADO =====
# Mejor fitness penalizado = 1483.564
# Mejor distancia real     = 1199.164
# Tiempo = 197.43 s
# [GEN   80] CleanBestDist=1090.39  CleanAvgDist=1105.33  Std=15.28  MinDist=2.83  Conflicts=4
# [GEN   80] CleanBestDist=1110.98  CleanAvgDist=1112.44  Std=3.42  MinDist=6.40  Conflicts=0
# [GEN   80] CleanBestDist=1073.32  CleanAvgDist=1084.74  Std=22.11  MinDist=5.00  Conflicts=3
# [GEN  160] CleanBestDist=1108.71  CleanAvgDist=1108.71  Std=0.00  MinDist=5.00  Conflicts=2
# [GEN  160] CleanBestDist=1122.95  CleanAvgDist=1122.95  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN   80] CleanBestDist=1104.29  CleanAvgDist=1104.84  Std=0.13  MinDist=6.71  Conflicts=0
# [GEN  160] CleanBestDist=1135.26  CleanAvgDist=1136.41  Std=0.51  MinDist=6.71  Conflicts=0
# [GEN  160] CleanBestDist=1119.64  CleanAvgDist=1123.54  Std=0.62  MinDist=6.40  Conflicts=0
# [GEN  160] CleanBestDist=1121.36  CleanAvgDist=1121.36  Std=0.00  MinDist=5.00  Conflicts=2
# [GEN  160] CleanBestDist=1073.32  CleanAvgDist=1110.02  Std=51.69  MinDist=6.00  Conflicts=0
# [GEN  240] CleanBestDist=1122.95  CleanAvgDist=1122.95  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN  160] CleanBestDist=1102.88  CleanAvgDist=1102.88  Std=0.00  MinDist=6.71  Conflicts=0
# [GEN  240] CleanBestDist=1108.71  CleanAvgDist=1108.71  Std=0.00  MinDist=5.00  Conflicts=2
# [GEN  240] CleanBestDist=1134.68  CleanAvgDist=1135.19  Std=0.20  MinDist=6.40  Conflicts=0
# [GEN  240] CleanBestDist=1119.64  CleanAvgDist=1119.64  Std=0.00  MinDist=6.40  Conflicts=0
# [GEN  240] CleanBestDist=1119.95  CleanAvgDist=1122.47  Std=8.63  MinDist=5.83  Conflicts=1
# [GEN  240] CleanBestDist=1166.29  CleanAvgDist=1166.44  Std=0.65  MinDist=6.00  Conflicts=0
# [GEN  320] CleanBestDist=1120.36  CleanAvgDist=1121.45  Std=0.31  MinDist=6.00  Conflicts=0
# [GEN  240] CleanBestDist=1102.88  CleanAvgDist=1102.88  Std=0.00  MinDist=6.71  Conflicts=0
# [GEN  320] CleanBestDist=1104.71  CleanAvgDist=1106.69  Std=0.18  MinDist=5.00  Conflicts=2
# [GEN  320] CleanBestDist=1128.02  CleanAvgDist=1129.68  Std=0.53  MinDist=7.00  Conflicts=0
# [GEN  320] CleanBestDist=1114.64  CleanAvgDist=1114.64  Std=0.00  MinDist=6.32  Conflicts=0
# [GEN  320] CleanBestDist=1205.82  CleanAvgDist=1207.80  Std=0.18  MinDist=6.00  Conflicts=0
# [GEN  400] CleanBestDist=1120.36  CleanAvgDist=1120.36  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN  320] CleanBestDist=1102.88  CleanAvgDist=1102.88  Std=0.00  MinDist=6.71  Conflicts=0
# [GEN  320] CleanBestDist=1165.29  CleanAvgDist=1167.12  Std=1.46  MinDist=6.08  Conflicts=0
# [GEN  400] CleanBestDist=1104.12  CleanAvgDist=1104.12  Std=0.00  MinDist=5.00  Conflicts=2
# [GEN  400] CleanBestDist=1126.02  CleanAvgDist=1126.02  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  400] CleanBestDist=1107.81  CleanAvgDist=1111.77  Std=0.36  MinDist=6.32  Conflicts=0
# [GEN  400] CleanBestDist=1202.82  CleanAvgDist=1202.82  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN  400] CleanBestDist=1102.88  CleanAvgDist=1102.88  Std=0.00  MinDist=6.71  Conflicts=0
# [GEN  480] CleanBestDist=1120.36  CleanAvgDist=1120.36  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN  480] CleanBestDist=1126.02  CleanAvgDist=1126.02  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  400] CleanBestDist=1161.88  CleanAvgDist=1161.88  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  480] CleanBestDist=1208.58  CleanAvgDist=1208.58  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  480] CleanBestDist=1106.39  CleanAvgDist=1107.80  Std=0.13  MinDist=6.32  Conflicts=0
# [GEN  480] CleanBestDist=1200.48  CleanAvgDist=1201.99  Std=0.49  MinDist=6.00  Conflicts=0
# [GEN  480] CleanBestDist=1102.29  CleanAvgDist=1102.87  Std=0.05  MinDist=6.32  Conflicts=0
# [GEN  560] CleanBestDist=1120.36  CleanAvgDist=1120.36  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN  560] CleanBestDist=1126.02  CleanAvgDist=1126.02  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  480] CleanBestDist=1159.05  CleanAvgDist=1159.05  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  560] CleanBestDist=1201.58  CleanAvgDist=1207.24  Std=2.76  MinDist=6.08  Conflicts=0
# [GEN  560] CleanBestDist=1104.39  CleanAvgDist=1104.39  Std=0.00  MinDist=6.32  Conflicts=0
# [GEN  560] CleanBestDist=1196.48  CleanAvgDist=1196.48  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN  560] CleanBestDist=1102.29  CleanAvgDist=1102.29  Std=0.00  MinDist=6.32  Conflicts=0
# [GEN  640] CleanBestDist=1120.36  CleanAvgDist=1120.36  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN  640] CleanBestDist=1126.02  CleanAvgDist=1126.02  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  560] CleanBestDist=1159.05  CleanAvgDist=1159.05  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  640] CleanBestDist=1201.58  CleanAvgDist=1201.58  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  640] CleanBestDist=1103.22  CleanAvgDist=1104.24  Std=0.40  MinDist=6.32  Conflicts=0
# [GEN  640] CleanBestDist=1188.06  CleanAvgDist=1188.06  Std=0.00  MinDist=7.00  Conflicts=0
# [GEN  640] CleanBestDist=1102.29  CleanAvgDist=1102.29  Std=0.00  MinDist=6.32  Conflicts=0
# [GEN  720] CleanBestDist=1120.36  CleanAvgDist=1120.36  Std=0.00  MinDist=6.00  Conflicts=0
# [GEN  720] CleanBestDist=1117.54  CleanAvgDist=1119.66  Std=0.97  MinDist=6.00  Conflicts=0
# [GEN  640] CleanBestDist=1159.05  CleanAvgDist=1159.05  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  720] CleanBestDist=1199.58  CleanAvgDist=1199.58  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  720] CleanBestDist=1100.39  CleanAvgDist=1100.39  Std=0.00  MinDist=6.32  Conflicts=0
# [GEN  720] CleanBestDist=1100.88  CleanAvgDist=1100.88  Std=0.00  MinDist=6.71  Conflicts=0
# [GEN  720] CleanBestDist=1186.06  CleanAvgDist=1187.85  Std=0.62  MinDist=7.00  Conflicts=0
# [GEN  800] CleanBestDist=1120.36  CleanAvgDist=1120.36  Std=0.00  MinDist=6.00  Conflicts=0
#
# ===== μ+λ COMPLETADO =====
# Mejor fitness penalizado = 1417.615
# Mejor distancia real     = 1120.365
# Tiempo = 173.18 s
# [GEN  800] CleanBestDist=1116.71  CleanAvgDist=1117.40  Std=0.31  MinDist=6.00  Conflicts=0
#
# ===== μ+λ COMPLETADO =====
# Mejor fitness penalizado = 1251.658
# Mejor distancia real     = 1116.708
# Tiempo = 172.12 s
# [GEN  720] CleanBestDist=1159.05  CleanAvgDist=1159.05  Std=0.00  MinDist=6.08  Conflicts=0
# [GEN  800] CleanBestDist=1191.92  CleanAvgDist=1197.73  Std=3.28  MinDist=6.08  Conflicts=0
#
# ===== μ+λ COMPLETADO =====
# Mejor fitness penalizado = 1312.421
# Mejor distancia real     = 1191.921
# Tiempo = 179.22 s
# [GEN  800] CleanBestDist=1100.39  CleanAvgDist=1100.39  Std=0.00  MinDist=6.32  Conflicts=0
#
# ===== μ+λ COMPLETADO =====
# Mejor fitness penalizado = 1324.194
# Mejor distancia real     = 1100.394
# Tiempo = 168.60 s
# [GEN  800] CleanBestDist=1100.88  CleanAvgDist=1100.88  Std=0.00  MinDist=6.71  Conflicts=0
#
# ===== μ+λ COMPLETADO =====
# Mejor fitness penalizado = 1191.579
# Mejor distancia real     = 1100.879
# Tiempo = 164.00 s
# [GEN  800] CleanBestDist=1186.06  CleanAvgDist=1186.06  Std=0.00  MinDist=7.00  Conflicts=0
#
# ===== μ+λ COMPLETADO =====
# Mejor fitness penalizado = 1319.813
# Mejor distancia real     = 1186.063
# Tiempo = 174.13 s
# [GEN  800] CleanBestDist=1158.47  CleanAvgDist=1158.47  Std=0.00  MinDist=6.08  Conflicts=0
#
# ===== μ+λ COMPLETADO =====
# Mejor fitness penalizado = 1422.765
# Mejor distancia real     = 1158.465
# Tiempo = 175.54 s
#
# ============================================================
# Experiments completed!
# Successful: 31
# Failed: 0
# Total time: 12.76 minutes
# Average time per run: 24.70 seconds
# ============================================================

# %% [markdown]
# ## 7. Statistical Analysis

# %%
import pandas as pd
from scipy import stats

# Load results from database
con = sqlite3.connect(DB_PATH)
df = pd.read_sql_query("SELECT * FROM runs", con)
con.close()

print(f"Total runs in database: {len(df)}")
df.head()
# Out:
# Total runs in database: 31
#    id   mu  lambda_  ngen  cxpb  mutpb  seed  best_penalized   best_clean  \
# 0   1  120       50   800   0.5    0.5     4     1618.243506  1089.293506
# 1   2  120       50   800   0.5    0.5     0     1104.658730  1082.908730
# 2   3  120       50   800   0.5    0.5     1     1298.978787  1177.778787
# 3   4  120       50   800   0.5    0.5     3     1404.086147  1205.536147
# 4   5  120       50   800   0.5    0.5     5     1316.220923  1161.920923
#
#      time_sec            timestamp
# 0  188.593172  2025-12-11 11:02:55
# 1  190.382614  2025-12-11 11:02:56
# 2  194.603116  2025-12-11 11:03:01
# 3  197.450833  2025-12-11 11:03:03
# 4  200.474139  2025-12-11 11:03:07

# %%
# Statistical summary
print("\n" + "="*80)
print("μ+λ STATISTICAL SUMMARY")
print("="*80)
print(f"\nConfiguration: mu={BEST_PARAMS['mu']}, lambda={BEST_PARAMS['lambda_']}, "
      f"ngen={BEST_PARAMS['ngen']}, cxpb={BEST_PARAMS['cxpb']}, mutpb={BEST_PARAMS['mutpb']}")
print(f"Number of runs: {len(df)}\n")

# Best Penalized
print(f"Best Penalized:")
print(f"  Mean: {df['best_penalized'].mean():.2f}")
print(f"  Std: {df['best_penalized'].std():.2f}")
print(f"  Min: {df['best_penalized'].min():.2f}")
print(f"  Max: {df['best_penalized'].max():.2f}")
print(f"  Median: {df['best_penalized'].median():.2f}")

# Best Clean
print(f"\nBest Clean:")
print(f"  Mean: {df['best_clean'].mean():.2f}")
print(f"  Std: {df['best_clean'].std():.2f}")
print(f"  Min: {df['best_clean'].min():.2f}")
print(f"  Max: {df['best_clean'].max():.2f}")
print(f"  Median: {df['best_clean'].median():.2f}")

# Computation Time
print(f"\nComputation Time (seconds):")
print(f"  Mean: {df['time_sec'].mean():.2f}")
print(f"  Std: {df['time_sec'].std():.2f}")
print(f"  Min: {df['time_sec'].min():.2f}")
print(f"  Max: {df['time_sec'].max():.2f}")

# 95% Confidence intervals
ci_penalized = stats.t.interval(0.95, len(df)-1, 
                                 loc=df['best_penalized'].mean(),
                                 scale=stats.sem(df['best_penalized']))
ci_clean = stats.t.interval(0.95, len(df)-1,
                            loc=df['best_clean'].mean(),
                            scale=stats.sem(df['best_clean']))

print(f"\n95% Confidence Intervals:")
print(f"  Best Penalized: [{ci_penalized[0]:.2f}, {ci_penalized[1]:.2f}]")
print(f"  Best Clean: [{ci_clean[0]:.2f}, {ci_clean[1]:.2f}]")
# Out:
# ================================================================================
# μ+λ STATISTICAL SUMMARY
# ================================================================================
#
# Configuration: mu=120, lambda=50, ngen=800, cxpb=0.5, mutpb=0.5
# Number of runs: 31
#
# Best Penalized:
#   Mean: 1294.01
#   Std: 115.99
#   Min: 1104.66
#   Max: 1618.24
#   Median: 1277.88
#
# Best Clean:
#   Mean: 1146.82
#   Std: 40.81
#   Min: 1082.91
#   Max: 1205.58
#   Median: 1157.44
#
# Computation Time (seconds):
#   Mean: 189.92
#   Std: 11.28
#   Min: 164.36
#   Max: 207.68
#
# 95% Confidence Intervals:
#   Best Penalized: [1251.47, 1336.56]
#   Best Clean: [1131.85, 1161.79]

# %% [markdown]
# ## 8. Normality Tests

# %%
# Shapiro-Wilk test for normality
stat_pen, p_pen = stats.shapiro(df['best_penalized'])
stat_clean, p_clean = stats.shapiro(df['best_clean'])

print("\n=== Normality Tests (Shapiro-Wilk) ===")
print(f"Best Penalized: stat={stat_pen:.4f}, p-value={p_pen:.4f}")
print(f"  -> {'Normal distribution' if p_pen > 0.05 else 'Not normal distribution'} (α=0.05)")
print(f"\nBest Clean: stat={stat_clean:.4f}, p-value={p_clean:.4f}")
print(f"  -> {'Normal distribution' if p_clean > 0.05 else 'Not normal distribution'} (α=0.05)")
# Out:
# === Normality Tests (Shapiro-Wilk) ===
# Best Penalized: stat=0.9644, p-value=0.3801
#   -> Normal distribution (α=0.05)
#
# Best Clean: stat=0.9087, p-value=0.0120
#   -> Not normal distribution (α=0.05)

# %% [markdown]
# ## 9. Export Results

# %%
# Export all results to CSV
df.to_csv('../results/individual/mulambda_all_results.csv', index=False)
print("✓ All results exported to mulambda_all_results.csv")

# Export summary statistics
summary = pd.DataFrame({
    'metric': ['best_penalized', 'best_clean', 'time_sec'],
    'mean': [df['best_penalized'].mean(), df['best_clean'].mean(), df['time_sec'].mean()],
    'std': [df['best_penalized'].std(), df['best_clean'].std(), df['time_sec'].std()],
    'min': [df['best_penalized'].min(), df['best_clean'].min(), df['time_sec'].min()],
    'max': [df['best_penalized'].max(), df['best_clean'].max(), df['time_sec'].max()],
    'median': [df['best_penalized'].median(), df['best_clean'].median(), df['time_sec'].median()]
})
summary.to_csv('../results/individual/mulambda_statistical_summary.csv', index=False)
print("✓ Statistical summary exported to mulambda_statistical_summary.csv")
# Out:
# ✓ All results exported to mulambda_all_results.csv
# ✓ Statistical summary exported to mulambda_statistical_summary.csv
