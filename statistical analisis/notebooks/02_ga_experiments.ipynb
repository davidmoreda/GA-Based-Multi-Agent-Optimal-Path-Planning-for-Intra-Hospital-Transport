# %% [markdown]
# # GA Experiments with Best Parameters (30 Seeds)
#
# This notebook runs GA experiments with the best configuration using 30 different seeds for statistical analysis.

# %% [markdown]
# ## 1. Import Libraries

# %%
import os
import sys
import sqlite3
import time
import random
import numpy as np
import multiprocessing as mp

# Add project root to path
ROOT_DIR = os.path.dirname(os.path.abspath(os.getcwd()))
sys.path.append(ROOT_DIR)

from algorithms.ga_runner import run_ga

print("✓ Libraries imported successfully")
# Out:
# ✓ Libraries imported successfully

# %% [markdown]
# ## 2. Database Setup

# %%
DB_PATH = "../data/ga_experiments.db"

def init_ga_db(db_path):
    """Initialize database for GA results"""
    con = sqlite3.connect(db_path)
    cur = con.cursor()
    
    cur.execute("""
        CREATE TABLE IF NOT EXISTS runs (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            pop_size INTEGER,
            ngen INTEGER,
            cxpb REAL,
            mutpb REAL,
            seed INTEGER,
            best_penalized REAL,
            best_clean REAL,
            time_sec REAL,
            timestamp DATETIME DEFAULT CURRENT_TIMESTAMP
        )
    """)
    
    con.commit()
    con.close()
    print(f"✓ Database initialized: {db_path}")

init_ga_db(DB_PATH)
# Out:
# ✓ Database initialized: ga_experiments.db

# %% [markdown]
# ## 3. Save Results Function

# %%
def save_ga_run(db_path, pop_size, ngen, cxpb, mutpb, seed, best_penalized, best_clean, time_sec):
    """Save a single GA run to database"""
    con = sqlite3.connect(db_path)
    cur = con.cursor()
    
    cur.execute("""
        INSERT INTO runs (
            pop_size, ngen, cxpb, mutpb, seed,
            best_penalized, best_clean, time_sec
        ) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
    """, (
        pop_size, ngen, cxpb, mutpb, seed,
        float(best_penalized), float(best_clean), time_sec
    ))
    
    con.commit()
    con.close()

print("✓ Save function defined")
# Out:
# ✓ Save function defined

# %% [markdown]
# ## 4. Worker Function for Multiprocessing

# %%
def ga_worker(args):
    """Worker function to run a single GA experiment"""
    pop_size, ngen, cxpb, mutpb, seed, db_path = args
    
    t0 = time.time()
    try:
        results = run_ga(
            pop_size=pop_size,
            ngen=ngen,
            cxpb=cxpb,
            mutpb=mutpb,
            seed=seed,
            show_plots=False,
            show_anim=False,
            debug_interval=max(1, ngen // 10)
        )
        t1 = time.time()
        
        save_ga_run(db_path, pop_size, ngen, cxpb, mutpb, seed, 
                   results['best_penalized'], results['best_clean'], t1 - t0)
        
        return {
            'success': True,
            'seed': seed,
            'best_penalized': results['best_penalized'],
            'time': t1 - t0
        }
    except Exception as e:
        return {
            'success': False,
            'seed': seed,
            'error': str(e)
        }

print("✓ Worker function defined")
# Out:
# ✓ Worker function defined

# %% [markdown]
# ## 5. Best Parameters Configuration

# %%
# Best parameters for GA (from grid search: pop=120, ngen=800, cxpb=0.5, mutpb=0.3)
BEST_PARAMS = {
    'pop_size': 150,
    'ngen': 800,
    'cxpb': 0.8,
    'mutpb': 0.3
}

# Seeds for statistical analysis (31 runs: 0-30)
SEEDS = list(range(31))

# Number of parallel processes
N_JOBS = min(8, mp.cpu_count())

print(f"Best parameters: {BEST_PARAMS}")
print(f"Number of seeds: {len(SEEDS)}")
print(f"Number of parallel jobs: {N_JOBS}")
print(f"Total experiments: {len(SEEDS)}")
# Out:
# Best parameters: {'pop_size': 150, 'ngen': 800, 'cxpb': 0.8, 'mutpb': 0.3}
# Number of seeds: 31
# Number of parallel jobs: 8
# Total experiments: 31

# %% [markdown]
# ## 6. Run Experiments with Multithreading

# %%
from tqdm.notebook import tqdm

# Generate tasks (one per seed, no nested loops)
tasks = [(BEST_PARAMS['pop_size'], BEST_PARAMS['ngen'], BEST_PARAMS['cxpb'], 
          BEST_PARAMS['mutpb'], seed, DB_PATH) for seed in SEEDS]

print(f"Total experiments to run: {len(tasks)}")
print(f"Running with {N_JOBS} parallel workers...\n")

# Run experiments in parallel
start_time = time.time()
with mp.Pool(processes=N_JOBS) as pool:
    results = list(tqdm(
        pool.imap(ga_worker, tasks),
        total=len(tasks),
        desc="GA Experiments"
    ))
total_time = time.time() - start_time

# Summary
successful = sum(1 for r in results if r['success'])
failed = len(results) - successful

print(f"\n{'='*60}")
print(f"Experiments completed!")
print(f"Successful: {successful}")
print(f"Failed: {failed}")
print(f"Total time: {total_time/60:.2f} minutes")
print(f"Average time per run: {total_time/len(tasks):.2f} seconds")
print(f"{'='*60}")
# Out:
# Total experiments to run: 31
# Running with 8 parallel workers...
#
# [INFO] Valores únicos del BMP original:
# GA Experiments:   0%|          | 0/31 [00:00<?, ?it/s]
# [INFO] Valores únicos del BMP original:[INFO] Valores únicos del BMP original:[INFO] Valores únicos del BMP original:[INFO] Valores únicos del BMP original:[INFO] Valores únicos del BMP original: [INFO] Valores únicos del BMP original:[INFO] Valores únicos del BMP original:       [  0 255][  0 255][  0 255][  0 255]
# [  0 255][  0 255][  0 255]
#
# [  0 255][INFO] Valores únicos tras invertir:
#
#
#
# [INFO] Valores únicos tras invertir:[INFO] Valores únicos tras invertir:[INFO] Valores únicos tras invertir:[INFO] Valores únicos tras invertir: [INFO] Valores únicos tras invertir:  [INFO] Valores únicos tras invertir:
# [  0 255][  0 255]   [  0 255][INFO] Valores únicos tras invertir:
# [  0 255]
# [  0 255]
#  [  0 255][  0 255][INFO] Environment cargado: 92 x 113
#
# [INFO] Environment cargado: 92 x 113[INFO] Environment cargado: 92 x 113[  0 255]
#
#
#
# [INFO] Environment cargado: 92 x 113
# [INFO] Environment cargado: 92 x 113[INFO] Environment cargado: 92 x 113[INFO] Environment cargado: 92 x 113
#
#
#
#
# [INFO] Environment cargado: 92 x 113
# [GEN   80] PenalizedBest=1564.7 | AvgPenalized=1626.2 | CleanBest=1082.1 | AvgClean=1083.4 | Std=7.2 | MinDist=5.00 | Conflicts=2
# [GEN   80] PenalizedBest=1503.6 | AvgPenalized=1525.8 | CleanBest=1139.3 | AvgClean=1140.0 | Std=7.9 | MinDist=4.47 | Conflicts=2
# [GEN   80] PenalizedBest=1210.2 | AvgPenalized=1223.2 | CleanBest=1187.4 | AvgClean=1188.1 | Std=7.8 | MinDist=6.40 | Conflicts=0
# [GEN   80] PenalizedBest=1672.6 | AvgPenalized=1735.3 | CleanBest=1132.0 | AvgClean=1133.4 | Std=9.8 | MinDist=5.00 | Conflicts=2
# [GEN   80] PenalizedBest=2110.2 | AvgPenalized=2148.3 | CleanBest=1119.6 | AvgClean=1121.0 | Std=6.9 | MinDist=0.00 | Conflicts=5
# [GEN   80] PenalizedBest=1235.4 | AvgPenalized=1252.8 | CleanBest=1175.8 | AvgClean=1176.7 | Std=5.8 | MinDist=6.08 | Conflicts=0
# [GEN   80] PenalizedBest=2024.9 | AvgPenalized=2084.3 | CleanBest=1131.8 | AvgClean=1136.8 | Std=24.7 | MinDist=5.00 | Conflicts=4
# [GEN   80] PenalizedBest=1266.1 | AvgPenalized=1308.2 | CleanBest=1243.4 | AvgClean=1244.7 | Std=8.8 | MinDist=6.00 | Conflicts=0
# [GEN  160] PenalizedBest=1444.9 | AvgPenalized=1474.0 | CleanBest=1092.7 | AvgClean=1094.0 | Std=10.8 | MinDist=5.66 | Conflicts=1
# [GEN  160] PenalizedBest=1208.2 | AvgPenalized=1314.4 | CleanBest=1136.2 | AvgClean=1146.8 | Std=15.8 | MinDist=6.40 | Conflicts=0
# [GEN  160] PenalizedBest=1670.6 | AvgPenalized=1716.4 | CleanBest=1130.0 | AvgClean=1131.6 | Std=9.1 | MinDist=6.00 | Conflicts=0
# [GEN  160] PenalizedBest=1206.9 | AvgPenalized=1208.1 | CleanBest=1185.8 | AvgClean=1186.3 | Std=3.9 | MinDist=6.40 | Conflicts=0
# [GEN  160] PenalizedBest=2110.2 | AvgPenalized=2180.7 | CleanBest=1119.6 | AvgClean=1121.8 | Std=13.0 | MinDist=0.00 | Conflicts=5
# [GEN  160] PenalizedBest=1230.6 | AvgPenalized=1273.7 | CleanBest=1171.0 | AvgClean=1172.4 | Std=7.7 | MinDist=6.08 | Conflicts=0
# [GEN  160] PenalizedBest=2022.1 | AvgPenalized=2069.2 | CleanBest=1129.0 | AvgClean=1130.5 | Std=8.9 | MinDist=5.00 | Conflicts=4
# [GEN  160] PenalizedBest=1266.1 | AvgPenalized=1274.0 | CleanBest=1243.4 | AvgClean=1243.9 | Std=5.5 | MinDist=6.00 | Conflicts=0
# [GEN  240] PenalizedBest=1388.2 | AvgPenalized=1596.0 | CleanBest=1092.7 | AvgClean=1101.7 | Std=24.4 | MinDist=6.00 | Conflicts=0
# [GEN  240] PenalizedBest=1208.2 | AvgPenalized=1248.8 | CleanBest=1143.9 | AvgClean=1145.0 | Std=7.2 | MinDist=6.40 | Conflicts=0
# [GEN  240] PenalizedBest=1399.2 | AvgPenalized=1437.2 | CleanBest=1154.1 | AvgClean=1156.7 | Std=10.4 | MinDist=6.00 | Conflicts=0
# [GEN  240] PenalizedBest=1206.1 | AvgPenalized=1213.2 | CleanBest=1185.0 | AvgClean=1185.4 | Std=2.6 | MinDist=6.40 | Conflicts=0
# [GEN  240] PenalizedBest=1551.7 | AvgPenalized=1612.7 | CleanBest=1185.7 | AvgClean=1189.3 | Std=16.8 | MinDist=7.81 | Conflicts=0
# [GEN  240] PenalizedBest=1224.7 | AvgPenalized=1325.0 | CleanBest=1168.2 | AvgClean=1171.2 | Std=14.4 | MinDist=6.08 | Conflicts=0
# [GEN  240] PenalizedBest=2022.1 | AvgPenalized=2074.6 | CleanBest=1129.0 | AvgClean=1130.2 | Std=7.5 | MinDist=5.00 | Conflicts=4
# [GEN  240] PenalizedBest=1262.6 | AvgPenalized=1275.6 | CleanBest=1240.0 | AvgClean=1241.0 | Std=11.3 | MinDist=6.00 | Conflicts=0
# [GEN  320] PenalizedBest=1353.0 | AvgPenalized=1360.4 | CleanBest=1179.7 | AvgClean=1179.9 | Std=1.5 | MinDist=6.00 | Conflicts=0
# [GEN  320] PenalizedBest=1208.2 | AvgPenalized=1276.8 | CleanBest=1143.9 | AvgClean=1148.2 | Std=16.7 | MinDist=6.32 | Conflicts=0
# [GEN  320] PenalizedBest=1396.3 | AvgPenalized=1458.6 | CleanBest=1149.7 | AvgClean=1155.4 | Std=11.3 | MinDist=6.00 | Conflicts=0
# [GEN  320] PenalizedBest=1206.1 | AvgPenalized=1220.0 | CleanBest=1185.0 | AvgClean=1187.4 | Std=17.9 | MinDist=6.40 | Conflicts=0
# [GEN  320] PenalizedBest=1520.9 | AvgPenalized=1551.0 | CleanBest=1182.2 | AvgClean=1183.8 | Std=12.1 | MinDist=7.81 | Conflicts=0
# [GEN  320] PenalizedBest=1223.9 | AvgPenalized=1240.5 | CleanBest=1167.4 | AvgClean=1168.3 | Std=7.8 | MinDist=6.00 | Conflicts=0
# [GEN  320] PenalizedBest=1400.9 | AvgPenalized=1443.9 | CleanBest=1254.6 | AvgClean=1254.9 | Std=2.7 | MinDist=6.00 | Conflicts=0
# [GEN  320] PenalizedBest=1262.6 | AvgPenalized=1282.0 | CleanBest=1240.0 | AvgClean=1241.4 | Std=8.7 | MinDist=6.00 | Conflicts=0
# [GEN  400] PenalizedBest=1208.2 | AvgPenalized=1219.6 | CleanBest=1143.9 | AvgClean=1144.7 | Std=4.4 | MinDist=6.32 | Conflicts=0
# [GEN  400] PenalizedBest=1348.8 | AvgPenalized=1462.9 | CleanBest=1175.5 | AvgClean=1182.4 | Std=22.4 | MinDist=6.00 | Conflicts=0
# [GEN  400] PenalizedBest=1278.5 | AvgPenalized=1361.9 | CleanBest=1137.7 | AvgClean=1140.2 | Std=11.7 | MinDist=6.00 | Conflicts=0
# [GEN  400] PenalizedBest=1220.7 | AvgPenalized=1227.3 | CleanBest=1163.5 | AvgClean=1164.1 | Std=4.8 | MinDist=6.08 | Conflicts=0
# [GEN  400] PenalizedBest=1408.7 | AvgPenalized=1467.1 | CleanBest=1176.2 | AvgClean=1178.2 | Std=12.7 | MinDist=6.08 | Conflicts=0
# [GEN  400] PenalizedBest=1204.5 | AvgPenalized=1223.4 | CleanBest=1182.0 | AvgClean=1183.1 | Std=7.0 | MinDist=6.40 | Conflicts=0
# [GEN  400] PenalizedBest=1395.8 | AvgPenalized=1418.7 | CleanBest=1248.2 | AvgClean=1249.3 | Std=9.1 | MinDist=6.08 | Conflicts=0
# [GEN  400] PenalizedBest=1262.6 | AvgPenalized=1276.1 | CleanBest=1240.0 | AvgClean=1240.4 | Std=4.7 | MinDist=6.00 | Conflicts=0
# [GEN  480] PenalizedBest=1208.2 | AvgPenalized=1288.8 | CleanBest=1143.9 | AvgClean=1146.5 | Std=11.7 | MinDist=6.32 | Conflicts=0
# [GEN  480] PenalizedBest=1278.5 | AvgPenalized=1290.8 | CleanBest=1137.7 | AvgClean=1138.0 | Std=2.4 | MinDist=6.08 | Conflicts=0
# [GEN  480] PenalizedBest=1332.4 | AvgPenalized=1358.5 | CleanBest=1161.4 | AvgClean=1162.3 | Std=8.7 | MinDist=6.08 | Conflicts=0
# [GEN  480] PenalizedBest=1220.7 | AvgPenalized=1254.2 | CleanBest=1163.5 | AvgClean=1164.9 | Std=7.3 | MinDist=6.08 | Conflicts=0
# [GEN  480] PenalizedBest=1407.2 | AvgPenalized=1487.2 | CleanBest=1172.9 | AvgClean=1178.9 | Std=20.1 | MinDist=6.08 | Conflicts=0
# [GEN  480] PenalizedBest=1204.5 | AvgPenalized=1207.2 | CleanBest=1182.0 | AvgClean=1182.2 | Std=1.7 | MinDist=6.40 | Conflicts=0
# [GEN  480] PenalizedBest=1256.7 | AvgPenalized=1354.3 | CleanBest=1235.3 | AvgClean=1237.4 | Std=9.3 | MinDist=6.00 | Conflicts=0
# [GEN  480] PenalizedBest=1395.8 | AvgPenalized=1417.9 | CleanBest=1248.2 | AvgClean=1248.3 | Std=1.7 | MinDist=6.08 | Conflicts=0
# [GEN  560] PenalizedBest=1206.2 | AvgPenalized=1233.5 | CleanBest=1141.9 | AvgClean=1143.3 | Std=10.0 | MinDist=6.40 | Conflicts=0
# [GEN  560] PenalizedBest=1274.5 | AvgPenalized=1312.7 | CleanBest=1133.7 | AvgClean=1135.4 | Std=9.9 | MinDist=6.00 | Conflicts=0
# [GEN  560] PenalizedBest=1332.4 | AvgPenalized=1361.3 | CleanBest=1161.4 | AvgClean=1162.5 | Std=6.8 | MinDist=6.08 | Conflicts=0
# [GEN  560] PenalizedBest=1219.9 | AvgPenalized=1264.9 | CleanBest=1162.7 | AvgClean=1163.7 | Std=5.6 | MinDist=6.08 | Conflicts=0
# [GEN  560] PenalizedBest=1405.2 | AvgPenalized=1422.6 | CleanBest=1172.7 | AvgClean=1173.7 | Std=7.2 | MinDist=6.08 | Conflicts=0
# [GEN  560] PenalizedBest=1204.5 | AvgPenalized=1231.9 | CleanBest=1182.0 | AvgClean=1184.0 | Std=9.7 | MinDist=6.40 | Conflicts=0
# [GEN  560] PenalizedBest=1256.7 | AvgPenalized=1291.6 | CleanBest=1235.3 | AvgClean=1236.6 | Std=10.4 | MinDist=6.00 | Conflicts=0
# [GEN  560] PenalizedBest=1395.8 | AvgPenalized=1472.5 | CleanBest=1248.2 | AvgClean=1250.5 | Std=13.3 | MinDist=6.08 | Conflicts=0
# [GEN  640] PenalizedBest=1204.2 | AvgPenalized=1214.9 | CleanBest=1139.9 | AvgClean=1140.2 | Std=2.6 | MinDist=6.40 | Conflicts=0
# [GEN  640] PenalizedBest=1268.1 | AvgPenalized=1352.6 | CleanBest=1128.8 | AvgClean=1135.2 | Std=22.9 | MinDist=6.00 | Conflicts=0
# [GEN  640] PenalizedBest=1330.4 | AvgPenalized=1351.3 | CleanBest=1159.4 | AvgClean=1160.2 | Std=6.1 | MinDist=6.08 | Conflicts=0
# [GEN  640] PenalizedBest=1188.2 | AvgPenalized=1201.8 | CleanBest=1155.7 | AvgClean=1158.2 | Std=1.8 | MinDist=7.00 | Conflicts=0
# [GEN  640] PenalizedBest=1405.2 | AvgPenalized=1483.8 | CleanBest=1172.7 | AvgClean=1175.8 | Std=14.5 | MinDist=6.08 | Conflicts=0
# [GEN  640] PenalizedBest=1204.5 | AvgPenalized=1210.7 | CleanBest=1182.0 | AvgClean=1182.5 | Std=3.9 | MinDist=6.40 | Conflicts=0
# [GEN  640] PenalizedBest=1256.7 | AvgPenalized=1266.5 | CleanBest=1235.3 | AvgClean=1235.6 | Std=3.2 | MinDist=6.00 | Conflicts=0
# [GEN  640] PenalizedBest=1367.1 | AvgPenalized=1407.2 | CleanBest=1240.5 | AvgClean=1242.0 | Std=7.7 | MinDist=6.08 | Conflicts=0
# [GEN  720] PenalizedBest=1204.2 | AvgPenalized=1291.7 | CleanBest=1139.9 | AvgClean=1142.6 | Std=13.0 | MinDist=6.40 | Conflicts=0
# [GEN  720] PenalizedBest=1267.5 | AvgPenalized=1268.0 | CleanBest=1129.7 | AvgClean=1129.8 | Std=1.3 | MinDist=6.00 | Conflicts=0
# [GEN  720] PenalizedBest=1330.4 | AvgPenalized=1442.6 | CleanBest=1159.4 | AvgClean=1162.2 | Std=14.5 | MinDist=6.08 | Conflicts=0
# [GEN  720] PenalizedBest=1188.2 | AvgPenalized=1277.8 | CleanBest=1155.7 | AvgClean=1157.3 | Std=9.4 | MinDist=7.00 | Conflicts=0
# [GEN  720] PenalizedBest=1403.0 | AvgPenalized=1429.6 | CleanBest=1170.5 | AvgClean=1171.9 | Std=12.5 | MinDist=6.08 | Conflicts=0
# [GEN  720] PenalizedBest=1204.5 | AvgPenalized=1229.8 | CleanBest=1182.0 | AvgClean=1183.0 | Std=8.7 | MinDist=6.40 | Conflicts=0
# [GEN  720] PenalizedBest=1243.3 | AvgPenalized=1298.5 | CleanBest=1223.5 | AvgClean=1225.9 | Std=9.5 | MinDist=6.00 | Conflicts=0
# [GEN  720] PenalizedBest=1367.1 | AvgPenalized=1380.9 | CleanBest=1240.5 | AvgClean=1240.9 | Std=4.4 | MinDist=6.08 | Conflicts=0
# [GEN  800] PenalizedBest=1204.2 | AvgPenalized=1268.1 | CleanBest=1139.9 | AvgClean=1141.7 | Std=11.3 | MinDist=6.40 | Conflicts=0
#
# ===== GA COMPLETADO =====
# Mejor fitness penalizado = 1204.191
# Mejor distancia real     = 1139.891
# Tiempo = 395.76 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN  800] PenalizedBest=1266.9 | AvgPenalized=1269.5 | CleanBest=1129.1 | AvgClean=1129.8 | Std=5.7 | MinDist=6.00 | Conflicts=0
#
# ===== GA COMPLETADO =====
# Mejor fitness penalizado = 1266.650
# Mejor distancia real     = 1128.850
# Tiempo = 401.74 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN  800] PenalizedBest=1330.4 | AvgPenalized=1341.8 | CleanBest=1159.4 | AvgClean=1160.3 | Std=5.9 | MinDist=6.08 | Conflicts=0
#
# ===== GA COMPLETADO =====
# Mejor fitness penalizado = 1330.386
# Mejor distancia real     = 1159.436
# Tiempo = 410.56 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN  800] PenalizedBest=1323.0 | AvgPenalized=1331.7 | CleanBest=1162.5 | AvgClean=1162.9 | Std=3.0 | MinDist=6.08 | Conflicts=0
#
# ===== GA COMPLETADO =====
# Mejor fitness penalizado = 1323.007
# Mejor distancia real     = 1162.507
# Tiempo = 420.77 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN  800] PenalizedBest=1188.2 | AvgPenalized=1195.4 | CleanBest=1155.7 | AvgClean=1155.9 | Std=1.8 | MinDist=6.08 | Conflicts=0
#
# ===== GA COMPLETADO =====
# Mejor fitness penalizado = 1184.629
# Mejor distancia real     = 1153.879
# Tiempo = 421.33 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN  800] PenalizedBest=1204.0 | AvgPenalized=1243.1 | CleanBest=1181.4 | AvgClean=1184.4 | Std=15.7 | MinDist=6.40 | Conflicts=0
#
# ===== GA COMPLETADO =====
# Mejor fitness penalizado = 1203.956
# Mejor distancia real     = 1181.406
# Tiempo = 424.98 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN   80] PenalizedBest=1170.1 | AvgPenalized=1767.2 | CleanBest=1085.0 | AvgClean=1107.7 | Std=25.4 | MinDist=6.00 | Conflicts=0
# [GEN  800] PenalizedBest=1365.5 | AvgPenalized=1458.5 | CleanBest=1237.5 | AvgClean=1239.1 | Std=10.5 | MinDist=6.08 | Conflicts=0
#
# ===== GA COMPLETADO =====
# Mejor fitness penalizado = 1365.098
# Mejor distancia real     = 1238.548
# Tiempo = 437.81 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN  800] PenalizedBest=1237.6 | AvgPenalized=1323.3 | CleanBest=1217.8 | AvgClean=1221.5 | Std=21.0 | MinDist=6.00 | Conflicts=0
#
# ===== GA COMPLETADO =====
# Mejor fitness penalizado = 1187.651
# Mejor distancia real     = 1140.051
# Tiempo = 437.92 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN   80] PenalizedBest=1408.2 | AvgPenalized=1564.2 | CleanBest=1131.3 | AvgClean=1134.0 | Std=12.1 | MinDist=5.39 | Conflicts=1
# [GEN   80] PenalizedBest=1293.9 | AvgPenalized=1295.5 | CleanBest=1129.1 | AvgClean=1129.3 | Std=1.6 | MinDist=6.08 | Conflicts=0
# [GEN   80] PenalizedBest=1430.2 | AvgPenalized=1457.5 | CleanBest=1095.9 | AvgClean=1097.7 | Std=5.8 | MinDist=6.08 | Conflicts=0
# [GEN   80] PenalizedBest=1197.1 | AvgPenalized=1237.0 | CleanBest=1158.2 | AvgClean=1159.3 | Std=9.4 | MinDist=6.40 | Conflicts=0
# [GEN   80] PenalizedBest=1494.0 | AvgPenalized=1539.7 | CleanBest=1086.2 | AvgClean=1088.8 | Std=12.7 | MinDist=6.32 | Conflicts=0
# [GEN  160] PenalizedBest=1169.5 | AvgPenalized=1288.7 | CleanBest=1132.5 | AvgClean=1136.5 | Std=18.2 | MinDist=6.00 | Conflicts=0
# [GEN   80] PenalizedBest=1461.4 | AvgPenalized=1478.4 | CleanBest=1077.9 | AvgClean=1078.8 | Std=6.9 | MinDist=5.00 | Conflicts=2
# [GEN   80] PenalizedBest=1858.9 | AvgPenalized=1888.0 | CleanBest=1092.4 | AvgClean=1094.3 | Std=9.7 | MinDist=2.00 | Conflicts=5
# [GEN  160] PenalizedBest=1408.2 | AvgPenalized=1466.1 | CleanBest=1131.3 | AvgClean=1132.8 | Std=9.6 | MinDist=5.39 | Conflicts=1
# [GEN  160] PenalizedBest=1275.4 | AvgPenalized=1307.2 | CleanBest=1117.7 | AvgClean=1118.2 | Std=3.2 | MinDist=6.08 | Conflicts=0
# [GEN  160] PenalizedBest=1428.8 | AvgPenalized=1488.2 | CleanBest=1095.5 | AvgClean=1098.8 | Std=18.7 | MinDist=6.08 | Conflicts=0
# [GEN  160] PenalizedBest=1488.3 | AvgPenalized=1559.0 | CleanBest=1080.6 | AvgClean=1083.3 | Std=12.2 | MinDist=6.32 | Conflicts=0
# [GEN  160] PenalizedBest=1185.6 | AvgPenalized=1221.0 | CleanBest=1145.3 | AvgClean=1146.8 | Std=10.5 | MinDist=7.00 | Conflicts=0
# [GEN  240] PenalizedBest=1168.1 | AvgPenalized=1191.6 | CleanBest=1131.1 | AvgClean=1132.5 | Std=6.2 | MinDist=6.00 | Conflicts=0
# [GEN  160] PenalizedBest=1245.9 | AvgPenalized=1258.0 | CleanBest=1157.8 | AvgClean=1159.3 | Std=11.3 | MinDist=6.08 | Conflicts=0
# [GEN  160] PenalizedBest=1231.7 | AvgPenalized=1276.4 | CleanBest=1097.4 | AvgClean=1165.8 | Std=12.1 | MinDist=7.00 | Conflicts=0
# [GEN  240] PenalizedBest=1384.9 | AvgPenalized=1416.1 | CleanBest=1177.5 | AvgClean=1178.4 | Std=5.0 | MinDist=6.40 | Conflicts=0
# [GEN  240] PenalizedBest=1269.0 | AvgPenalized=1281.9 | CleanBest=1114.3 | AvgClean=1116.5 | Std=14.6 | MinDist=6.08 | Conflicts=0
# [GEN  240] PenalizedBest=1208.3 | AvgPenalized=1245.3 | CleanBest=1087.8 | AvgClean=1088.9 | Std=7.7 | MinDist=6.08 | Conflicts=0
# [GEN  240] PenalizedBest=1289.3 | AvgPenalized=1319.3 | CleanBest=1171.1 | AvgClean=1172.1 | Std=7.7 | MinDist=6.08 | Conflicts=0
# [GEN  240] PenalizedBest=1164.1 | AvgPenalized=1246.6 | CleanBest=1135.5 | AvgClean=1136.8 | Std=6.8 | MinDist=6.32 | Conflicts=0
# [GEN  320] PenalizedBest=1168.1 | AvgPenalized=1206.4 | CleanBest=1131.1 | AvgClean=1132.9 | Std=9.8 | MinDist=6.00 | Conflicts=0
# [GEN  240] PenalizedBest=1244.5 | AvgPenalized=1256.7 | CleanBest=1156.4 | AvgClean=1157.4 | Std=5.7 | MinDist=6.00 | Conflicts=0
# [GEN  320] PenalizedBest=1381.5 | AvgPenalized=1446.9 | CleanBest=1174.1 | AvgClean=1176.0 | Std=7.8 | MinDist=6.40 | Conflicts=0
# [GEN  240] PenalizedBest=1231.1 | AvgPenalized=1247.8 | CleanBest=1164.1 | AvgClean=1164.4 | Std=1.9 | MinDist=6.08 | Conflicts=0
# [GEN  320] PenalizedBest=1265.2 | AvgPenalized=1341.4 | CleanBest=1107.5 | AvgClean=1109.9 | Std=11.3 | MinDist=6.08 | Conflicts=0
# [GEN  320] PenalizedBest=1206.1 | AvgPenalized=1264.1 | CleanBest=1085.6 | AvgClean=1087.1 | Std=11.0 | MinDist=6.08 | Conflicts=0
# [GEN  320] PenalizedBest=1260.8 | AvgPenalized=1274.9 | CleanBest=1160.8 | AvgClean=1162.5 | Std=6.8 | MinDist=6.08 | Conflicts=0
# [GEN  320] PenalizedBest=1153.2 | AvgPenalized=1211.8 | CleanBest=1124.7 | AvgClean=1127.2 | Std=10.3 | MinDist=6.40 | Conflicts=0
# [GEN  400] PenalizedBest=1160.2 | AvgPenalized=1192.2 | CleanBest=1130.5 | AvgClean=1131.3 | Std=7.1 | MinDist=6.00 | Conflicts=0
# [GEN  320] PenalizedBest=1244.5 | AvgPenalized=1313.6 | CleanBest=1152.4 | AvgClean=1159.1 | Std=11.7 | MinDist=6.00 | Conflicts=0
# [GEN  400] PenalizedBest=1360.8 | AvgPenalized=1413.3 | CleanBest=1166.5 | AvgClean=1168.3 | Std=6.6 | MinDist=6.40 | Conflicts=0
# [GEN  400] PenalizedBest=1258.8 | AvgPenalized=1329.8 | CleanBest=1104.1 | AvgClean=1106.9 | Std=10.0 | MinDist=6.08 | Conflicts=0
# [GEN  320] PenalizedBest=1231.1 | AvgPenalized=1307.6 | CleanBest=1164.1 | AvgClean=1166.3 | Std=14.4 | MinDist=6.08 | Conflicts=0
# [GEN  400] PenalizedBest=1199.7 | AvgPenalized=1223.4 | CleanBest=1082.2 | AvgClean=1082.9 | Std=6.4 | MinDist=6.08 | Conflicts=0
# [GEN  400] PenalizedBest=1260.8 | AvgPenalized=1316.0 | CleanBest=1160.8 | AvgClean=1163.7 | Std=12.9 | MinDist=6.08 | Conflicts=0
# [GEN  400] PenalizedBest=1135.6 | AvgPenalized=1326.3 | CleanBest=1113.0 | AvgClean=1117.6 | Std=23.0 | MinDist=7.00 | Conflicts=0
# [GEN  480] PenalizedBest=1158.8 | AvgPenalized=1286.1 | CleanBest=1129.1 | AvgClean=1133.2 | Std=20.7 | MinDist=6.00 | Conflicts=0
# [GEN  480] PenalizedBest=1258.8 | AvgPenalized=1339.4 | CleanBest=1104.1 | AvgClean=1106.0 | Std=11.0 | MinDist=6.08 | Conflicts=0
# [GEN  400] PenalizedBest=1244.5 | AvgPenalized=1306.9 | CleanBest=1156.4 | AvgClean=1159.6 | Std=13.4 | MinDist=6.00 | Conflicts=0
# [GEN  480] PenalizedBest=1358.8 | AvgPenalized=1366.0 | CleanBest=1164.5 | AvgClean=1164.9 | Std=3.8 | MinDist=6.40 | Conflicts=0
# [GEN  400] PenalizedBest=1231.1 | AvgPenalized=1341.1 | CleanBest=1164.1 | AvgClean=1166.0 | Std=9.3 | MinDist=6.08 | Conflicts=0
# [GEN  480] PenalizedBest=1196.8 | AvgPenalized=1212.4 | CleanBest=1079.3 | AvgClean=1080.2 | Std=6.1 | MinDist=6.08 | Conflicts=0
# [GEN  480] PenalizedBest=1260.8 | AvgPenalized=1268.6 | CleanBest=1160.8 | AvgClean=1161.5 | Std=6.2 | MinDist=6.08 | Conflicts=0
# [GEN  480] PenalizedBest=1130.7 | AvgPenalized=1147.0 | CleanBest=1108.2 | AvgClean=1111.3 | Std=3.8 | MinDist=6.71 | Conflicts=0
# [GEN  560] PenalizedBest=1158.2 | AvgPenalized=1246.3 | CleanBest=1128.5 | AvgClean=1129.7 | Std=8.1 | MinDist=6.00 | Conflicts=0
# [GEN  560] PenalizedBest=1258.8 | AvgPenalized=1347.5 | CleanBest=1104.1 | AvgClean=1107.0 | Std=17.2 | MinDist=6.08 | Conflicts=0
# [GEN  480] PenalizedBest=1244.5 | AvgPenalized=1262.8 | CleanBest=1156.4 | AvgClean=1157.0 | Std=4.1 | MinDist=6.00 | Conflicts=0
# [GEN  560] PenalizedBest=1353.8 | AvgPenalized=1411.0 | CleanBest=1159.4 | AvgClean=1160.7 | Std=7.2 | MinDist=6.40 | Conflicts=0
# [GEN  480] PenalizedBest=1231.1 | AvgPenalized=1305.0 | CleanBest=1164.1 | AvgClean=1166.4 | Std=11.8 | MinDist=6.08 | Conflicts=0
# [GEN  560] PenalizedBest=1196.8 | AvgPenalized=1265.5 | CleanBest=1079.3 | AvgClean=1082.2 | Std=17.2 | MinDist=6.08 | Conflicts=0
# [GEN  560] PenalizedBest=1129.3 | AvgPenalized=1132.7 | CleanBest=1106.8 | AvgClean=1107.0 | Std=2.4 | MinDist=6.71 | Conflicts=0
# [GEN  560] PenalizedBest=1260.8 | AvgPenalized=1270.3 | CleanBest=1160.8 | AvgClean=1161.9 | Std=7.0 | MinDist=6.08 | Conflicts=0
# [GEN  640] PenalizedBest=1158.2 | AvgPenalized=1204.0 | CleanBest=1128.5 | AvgClean=1129.3 | Std=5.5 | MinDist=6.00 | Conflicts=0
# [GEN  640] PenalizedBest=1252.9 | AvgPenalized=1252.9 | CleanBest=1101.2 | AvgClean=1101.2 | Std=0.0 | MinDist=6.08 | Conflicts=0
# [GEN  560] PenalizedBest=1244.5 | AvgPenalized=1303.7 | CleanBest=1156.4 | AvgClean=1161.1 | Std=22.1 | MinDist=6.00 | Conflicts=0
# [GEN  640] PenalizedBest=1332.5 | AvgPenalized=1366.5 | CleanBest=1154.4 | AvgClean=1155.8 | Std=10.9 | MinDist=6.00 | Conflicts=0
# [GEN  640] PenalizedBest=1196.8 | AvgPenalized=1238.2 | CleanBest=1079.3 | AvgClean=1081.4 | Std=11.1 | MinDist=6.08 | Conflicts=0
# [GEN  560] PenalizedBest=1231.1 | AvgPenalized=1231.1 | CleanBest=1164.1 | AvgClean=1164.1 | Std=0.0 | MinDist=6.08 | Conflicts=0
# [GEN  640] PenalizedBest=1127.1 | AvgPenalized=1140.6 | CleanBest=1104.5 | AvgClean=1104.9 | Std=2.6 | MinDist=6.71 | Conflicts=0
# [GEN  640] PenalizedBest=1259.3 | AvgPenalized=1265.8 | CleanBest=1162.3 | AvgClean=1162.5 | Std=2.7 | MinDist=6.08 | Conflicts=0
# [GEN  720] PenalizedBest=1156.0 | AvgPenalized=1185.9 | CleanBest=1125.0 | AvgClean=1126.3 | Std=7.4 | MinDist=6.00 | Conflicts=0
# [GEN  720] PenalizedBest=1247.9 | AvgPenalized=1247.9 | CleanBest=1096.2 | AvgClean=1096.2 | Std=0.0 | MinDist=6.08 | Conflicts=0
# [GEN  720] PenalizedBest=1332.5 | AvgPenalized=1427.8 | CleanBest=1154.4 | AvgClean=1157.7 | Std=15.8 | MinDist=6.00 | Conflicts=0
# [GEN  720] PenalizedBest=1196.8 | AvgPenalized=1230.7 | CleanBest=1079.3 | AvgClean=1081.3 | Std=11.4 | MinDist=6.08 | Conflicts=0
# [GEN  640] PenalizedBest=1244.5 | AvgPenalized=1272.8 | CleanBest=1156.4 | AvgClean=1157.6 | Std=6.0 | MinDist=6.00 | Conflicts=0
# [GEN  640] PenalizedBest=1231.1 | AvgPenalized=1384.4 | CleanBest=1164.1 | AvgClean=1167.0 | Std=14.2 | MinDist=6.08 | Conflicts=0
# [GEN  720] PenalizedBest=1127.1 | AvgPenalized=1128.0 | CleanBest=1104.5 | AvgClean=1104.8 | Std=3.8 | MinDist=6.71 | Conflicts=0
# [GEN  720] PenalizedBest=1250.3 | AvgPenalized=1318.4 | CleanBest=1159.3 | AvgClean=1162.3 | Std=15.8 | MinDist=6.08 | Conflicts=0
# [GEN  800] PenalizedBest=1156.0 | AvgPenalized=1214.3 | CleanBest=1125.0 | AvgClean=1126.9 | Std=8.6 | MinDist=6.00 | Conflicts=0
#
# ===== GA COMPLETADO =====
# Mejor fitness penalizado = 1155.950
# Mejor distancia real     = 1124.950
# Tiempo = 390.12 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN  800] PenalizedBest=1247.9 | AvgPenalized=1338.0 | CleanBest=1096.2 | AvgClean=1097.4 | Std=10.4 | MinDist=6.08 | Conflicts=0
#
# ===== GA COMPLETADO =====
# Mejor fitness penalizado = 1247.851
# Mejor distancia real     = 1096.151
# Tiempo = 383.02 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN  800] PenalizedBest=1196.8 | AvgPenalized=1231.7 | CleanBest=1079.3 | AvgClean=1080.6 | Std=9.4 | MinDist=6.08 | Conflicts=0
#
# ===== GA COMPLETADO =====
# Mejor fitness penalizado = 1196.823
# Mejor distancia real     = 1079.323
# Tiempo = 377.54 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN  800] PenalizedBest=1330.5 | AvgPenalized=1404.0 | CleanBest=1152.4 | AvgClean=1156.5 | Std=14.3 | MinDist=6.40 | Conflicts=0
#
# ===== GA COMPLETADO =====
# Mejor fitness penalizado = 1330.506
# Mejor distancia real     = 1152.406
# Tiempo = 402.39 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN  720] PenalizedBest=1244.5 | AvgPenalized=1302.4 | CleanBest=1156.4 | AvgClean=1158.9 | Std=16.2 | MinDist=6.00 | Conflicts=0
# [GEN  720] PenalizedBest=1230.3 | AvgPenalized=1263.6 | CleanBest=1163.3 | AvgClean=1164.8 | Std=7.7 | MinDist=6.08 | Conflicts=0
# [GEN  800] PenalizedBest=1124.1 | AvgPenalized=1139.2 | CleanBest=1098.5 | AvgClean=1099.5 | Std=7.2 | MinDist=6.32 | Conflicts=0
#
# ===== GA COMPLETADO =====
# Mejor fitness penalizado = 1123.086
# Mejor distancia real     = 1100.536
# Tiempo = 399.51 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN  800] PenalizedBest=1244.5 | AvgPenalized=1308.3 | CleanBest=1156.4 | AvgClean=1158.5 | Std=10.6 | MinDist=6.08 | Conflicts=0
#
# ===== GA COMPLETADO =====
# Mejor fitness penalizado = 1139.922
# Mejor distancia real     = 1100.222
# Tiempo = 404.33 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN   80] PenalizedBest=1549.5 | AvgPenalized=1634.4 | CleanBest=1145.5 | AvgClean=1148.8 | Std=16.0 | MinDist=5.39 | Conflicts=2
# [GEN   80] PenalizedBest=2260.7 | AvgPenalized=2284.5 | CleanBest=1128.0 | AvgClean=1128.9 | Std=5.7 | MinDist=0.00 | Conflicts=5
# [GEN   80] PenalizedBest=1841.0 | AvgPenalized=1942.3 | CleanBest=1173.2 | AvgClean=1177.4 | Std=14.3 | MinDist=5.00 | Conflicts=2
# [GEN   80] PenalizedBest=1267.0 | AvgPenalized=1354.5 | CleanBest=1182.0 | AvgClean=1185.4 | Std=19.7 | MinDist=6.00 | Conflicts=0
# [GEN  800] PenalizedBest=1244.5 | AvgPenalized=1264.1 | CleanBest=1156.4 | AvgClean=1157.4 | Std=4.6 | MinDist=6.00 | Conflicts=0
#
# ===== GA COMPLETADO =====
# Mejor fitness penalizado = 1244.486
# Mejor distancia real     = 1156.436
# Tiempo = 411.73 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN  800] PenalizedBest=1229.5 | AvgPenalized=1334.8 | CleanBest=1162.5 | AvgClean=1165.7 | Std=17.4 | MinDist=6.08 | Conflicts=0
#
# ===== GA COMPLETADO =====
# Mejor fitness penalizado = 1229.465
# Mejor distancia real     = 1162.465
# Tiempo = 418.48 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN   80] PenalizedBest=1223.7 | AvgPenalized=1244.2 | CleanBest=1181.4 | AvgClean=1182.7 | Std=7.4 | MinDist=6.40 | Conflicts=0
# [GEN   80] PenalizedBest=1994.1 | AvgPenalized=2098.6 | CleanBest=1128.9 | AvgClean=1129.8 | Std=6.4 | MinDist=5.00 | Conflicts=2
# [GEN  160] PenalizedBest=1398.0 | AvgPenalized=1579.8 | CleanBest=1141.5 | AvgClean=1143.9 | Std=11.1 | MinDist=5.83 | Conflicts=1
# [GEN  160] PenalizedBest=2260.7 | AvgPenalized=2321.9 | CleanBest=1128.0 | AvgClean=1129.7 | Std=10.7 | MinDist=0.00 | Conflicts=5
# [GEN  160] PenalizedBest=1718.5 | AvgPenalized=1725.5 | CleanBest=1184.9 | AvgClean=1185.6 | Std=6.0 | MinDist=5.00 | Conflicts=2
# [GEN  160] PenalizedBest=1265.6 | AvgPenalized=1321.7 | CleanBest=1180.6 | AvgClean=1182.1 | Std=7.8 | MinDist=6.00 | Conflicts=0
# [GEN   80] PenalizedBest=1604.9 | AvgPenalized=1636.8 | CleanBest=1093.6 | AvgClean=1094.4 | Std=4.5 | MinDist=5.00 | Conflicts=3
# [GEN   80] PenalizedBest=1502.6 | AvgPenalized=1530.2 | CleanBest=1314.6 | AvgClean=1316.0 | Std=9.1 | MinDist=7.62 | Conflicts=0
# [GEN  160] PenalizedBest=1223.7 | AvgPenalized=1267.9 | CleanBest=1181.4 | AvgClean=1183.1 | Std=7.8 | MinDist=6.40 | Conflicts=0
# [GEN  240] PenalizedBest=1242.0 | AvgPenalized=1302.3 | CleanBest=1136.5 | AvgClean=1138.2 | Std=11.1 | MinDist=6.08 | Conflicts=0
# [GEN  160] PenalizedBest=1745.6 | AvgPenalized=1821.2 | CleanBest=1166.5 | AvgClean=1174.8 | Std=8.1 | MinDist=7.07 | Conflicts=0
# [GEN  240] PenalizedBest=2244.7 | AvgPenalized=2257.2 | CleanBest=1124.0 | AvgClean=1124.9 | Std=11.6 | MinDist=0.00 | Conflicts=5
# [GEN  240] PenalizedBest=1715.1 | AvgPenalized=1721.8 | CleanBest=1181.5 | AvgClean=1182.4 | Std=9.1 | MinDist=5.00 | Conflicts=2
# [GEN  240] PenalizedBest=1255.6 | AvgPenalized=1284.1 | CleanBest=1167.7 | AvgClean=1169.8 | Std=4.8 | MinDist=6.00 | Conflicts=0
# [GEN  160] PenalizedBest=1604.9 | AvgPenalized=1634.7 | CleanBest=1093.6 | AvgClean=1095.0 | Std=7.9 | MinDist=5.00 | Conflicts=3
# [GEN  320] PenalizedBest=1225.9 | AvgPenalized=1263.8 | CleanBest=1123.4 | AvgClean=1124.8 | Std=6.3 | MinDist=6.08 | Conflicts=0
# [GEN  240] PenalizedBest=1222.3 | AvgPenalized=1247.1 | CleanBest=1180.0 | AvgClean=1180.9 | Std=6.7 | MinDist=6.08 | Conflicts=0
# [GEN  240] PenalizedBest=1685.3 | AvgPenalized=1697.0 | CleanBest=1155.1 | AvgClean=1156.3 | Std=12.5 | MinDist=6.71 | Conflicts=0
# [GEN  160] PenalizedBest=1488.7 | AvgPenalized=1521.6 | CleanBest=1309.6 | AvgClean=1314.7 | Std=15.8 | MinDist=7.62 | Conflicts=0
# [GEN  320] PenalizedBest=1580.8 | AvgPenalized=1592.4 | CleanBest=1187.5 | AvgClean=1187.8 | Std=2.9 | MinDist=6.08 | Conflicts=0
# [GEN  320] PenalizedBest=1255.6 | AvgPenalized=1402.7 | CleanBest=1169.1 | AvgClean=1172.1 | Std=12.8 | MinDist=6.00 | Conflicts=0
# [GEN  240] PenalizedBest=1371.8 | AvgPenalized=1443.4 | CleanBest=1150.1 | AvgClean=1151.8 | Std=10.2 | MinDist=5.83 | Conflicts=1
# [GEN  320] PenalizedBest=1488.5 | AvgPenalized=1608.7 | CleanBest=1253.2 | AvgClean=1257.4 | Std=20.7 | MinDist=7.62 | Conflicts=0
# [GEN  400] PenalizedBest=1225.3 | AvgPenalized=1251.8 | CleanBest=1122.8 | AvgClean=1123.6 | Std=4.7 | MinDist=6.08 | Conflicts=0
# [GEN  320] PenalizedBest=1684.5 | AvgPenalized=1740.4 | CleanBest=1154.3 | AvgClean=1155.5 | Std=6.2 | MinDist=6.32 | Conflicts=0
# [GEN  320] PenalizedBest=1195.9 | AvgPenalized=1265.6 | CleanBest=1171.5 | AvgClean=1174.5 | Std=7.6 | MinDist=6.08 | Conflicts=0
# [GEN  240] PenalizedBest=1474.3 | AvgPenalized=1543.7 | CleanBest=1297.7 | AvgClean=1305.0 | Std=20.2 | MinDist=6.00 | Conflicts=0
# [GEN  400] PenalizedBest=1579.4 | AvgPenalized=1625.7 | CleanBest=1186.1 | AvgClean=1187.3 | Std=5.8 | MinDist=6.08 | Conflicts=0
# [GEN  400] PenalizedBest=1249.3 | AvgPenalized=1383.1 | CleanBest=1162.8 | AvgClean=1165.5 | Std=11.8 | MinDist=6.00 | Conflicts=0
# [GEN  320] PenalizedBest=1366.1 | AvgPenalized=1413.4 | CleanBest=1149.1 | AvgClean=1152.8 | Std=11.7 | MinDist=5.83 | Conflicts=1
# [GEN  400] PenalizedBest=1477.3 | AvgPenalized=1484.0 | CleanBest=1240.5 | AvgClean=1243.0 | Std=4.7 | MinDist=7.62 | Conflicts=0
# [GEN  480] PenalizedBest=1221.3 | AvgPenalized=1233.5 | CleanBest=1118.8 | AvgClean=1119.4 | Std=4.2 | MinDist=6.08 | Conflicts=0
# [GEN  400] PenalizedBest=1678.8 | AvgPenalized=1704.5 | CleanBest=1148.6 | AvgClean=1150.9 | Std=24.5 | MinDist=6.08 | Conflicts=0
# [GEN  400] PenalizedBest=1195.9 | AvgPenalized=1273.2 | CleanBest=1171.5 | AvgClean=1172.9 | Std=7.2 | MinDist=6.08 | Conflicts=0
# [GEN  320] PenalizedBest=1429.9 | AvgPenalized=1462.6 | CleanBest=1294.7 | AvgClean=1297.1 | Std=12.8 | MinDist=8.49 | Conflicts=0
# [GEN  400] PenalizedBest=1366.1 | AvgPenalized=1450.4 | CleanBest=1149.1 | AvgClean=1149.7 | Std=5.9 | MinDist=5.83 | Conflicts=1
# [GEN  480] PenalizedBest=1237.5 | AvgPenalized=1341.6 | CleanBest=1156.7 | AvgClean=1162.6 | Std=22.3 | MinDist=6.00 | Conflicts=0
# [GEN  480] PenalizedBest=1573.1 | AvgPenalized=1636.5 | CleanBest=1179.8 | AvgClean=1181.3 | Std=10.7 | MinDist=6.08 | Conflicts=0
# [GEN  480] PenalizedBest=1459.8 | AvgPenalized=1482.8 | CleanBest=1226.1 | AvgClean=1226.8 | Std=5.4 | MinDist=7.62 | Conflicts=0
# [GEN  560] PenalizedBest=1217.3 | AvgPenalized=1327.6 | CleanBest=1114.8 | AvgClean=1118.1 | Std=19.5 | MinDist=6.08 | Conflicts=0
# [GEN  480] PenalizedBest=1665.0 | AvgPenalized=1761.1 | CleanBest=1137.8 | AvgClean=1139.6 | Std=8.0 | MinDist=6.08 | Conflicts=0
# [GEN  480] PenalizedBest=1193.9 | AvgPenalized=1217.1 | CleanBest=1169.5 | AvgClean=1170.1 | Std=4.0 | MinDist=6.08 | Conflicts=0
# [GEN  560] PenalizedBest=1237.5 | AvgPenalized=1360.2 | CleanBest=1156.7 | AvgClean=1160.6 | Std=15.2 | MinDist=6.00 | Conflicts=0
# [GEN  480] PenalizedBest=1366.1 | AvgPenalized=1470.8 | CleanBest=1149.1 | AvgClean=1151.6 | Std=12.3 | MinDist=5.83 | Conflicts=1
# [GEN  560] PenalizedBest=1570.4 | AvgPenalized=1662.1 | CleanBest=1177.4 | AvgClean=1179.4 | Std=9.9 | MinDist=6.08 | Conflicts=0
# [GEN  400] PenalizedBest=1424.5 | AvgPenalized=1454.4 | CleanBest=1289.3 | AvgClean=1292.0 | Std=16.0 | MinDist=7.81 | Conflicts=0
# [GEN  640] PenalizedBest=1214.8 | AvgPenalized=1287.5 | CleanBest=1112.3 | AvgClean=1114.2 | Std=9.4 | MinDist=6.08 | Conflicts=0
# [GEN  560] PenalizedBest=1452.1 | AvgPenalized=1467.4 | CleanBest=1223.1 | AvgClean=1225.7 | Std=20.9 | MinDist=7.62 | Conflicts=0
# [GEN  560] PenalizedBest=1665.0 | AvgPenalized=1684.9 | CleanBest=1137.8 | AvgClean=1138.3 | Std=3.8 | MinDist=6.08 | Conflicts=0
# [GEN  560] PenalizedBest=1191.4 | AvgPenalized=1215.5 | CleanBest=1165.7 | AvgClean=1166.6 | Std=7.2 | MinDist=6.08 | Conflicts=0
# [GEN  560] PenalizedBest=1366.1 | AvgPenalized=1426.0 | CleanBest=1149.1 | AvgClean=1150.7 | Std=11.7 | MinDist=5.83 | Conflicts=1
# [GEN  640] PenalizedBest=1237.5 | AvgPenalized=1300.6 | CleanBest=1156.7 | AvgClean=1157.7 | Std=6.4 | MinDist=6.00 | Conflicts=0
# [GEN  640] PenalizedBest=1569.0 | AvgPenalized=1610.9 | CleanBest=1176.0 | AvgClean=1177.8 | Std=9.6 | MinDist=6.08 | Conflicts=0
# [GEN  720] PenalizedBest=1214.8 | AvgPenalized=1238.5 | CleanBest=1112.3 | AvgClean=1114.0 | Std=9.0 | MinDist=6.08 | Conflicts=0
# [GEN  480] PenalizedBest=1420.5 | AvgPenalized=1475.9 | CleanBest=1285.3 | AvgClean=1287.2 | Std=8.1 | MinDist=8.54 | Conflicts=0
# [GEN  640] PenalizedBest=1450.1 | AvgPenalized=1496.2 | CleanBest=1221.1 | AvgClean=1223.9 | Std=7.1 | MinDist=7.62 | Conflicts=0
# [GEN  640] PenalizedBest=1665.0 | AvgPenalized=1737.0 | CleanBest=1137.8 | AvgClean=1140.3 | Std=11.6 | MinDist=6.08 | Conflicts=0
# [GEN  640] PenalizedBest=1191.4 | AvgPenalized=1233.1 | CleanBest=1165.7 | AvgClean=1167.6 | Std=9.0 | MinDist=6.08 | Conflicts=0
# [GEN  640] PenalizedBest=1217.5 | AvgPenalized=1278.6 | CleanBest=1150.5 | AvgClean=1152.7 | Std=11.5 | MinDist=6.08 | Conflicts=0
# [GEN  720] PenalizedBest=1237.5 | AvgPenalized=1327.7 | CleanBest=1156.7 | AvgClean=1158.8 | Std=13.3 | MinDist=6.00 | Conflicts=0
# [GEN  800] PenalizedBest=1190.1 | AvgPenalized=1221.3 | CleanBest=1096.6 | AvgClean=1105.1 | Std=13.0 | MinDist=6.08 | Conflicts=0
#
# ===== GA COMPLETADO =====
# Mejor fitness penalizado = 1190.107
# Mejor distancia real     = 1096.607
# Tiempo = 392.87 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN  720] PenalizedBest=1565.4 | AvgPenalized=1597.4 | CleanBest=1175.4 | AvgClean=1178.0 | Std=18.9 | MinDist=6.08 | Conflicts=0
# [GEN  720] PenalizedBest=1433.6 | AvgPenalized=1441.8 | CleanBest=1204.6 | AvgClean=1205.1 | Std=3.7 | MinDist=7.62 | Conflicts=0
# [GEN  720] PenalizedBest=1665.0 | AvgPenalized=1820.9 | CleanBest=1137.8 | AvgClean=1142.2 | Std=20.6 | MinDist=6.08 | Conflicts=0
# [GEN  560] PenalizedBest=1405.0 | AvgPenalized=1467.7 | CleanBest=1275.3 | AvgClean=1280.7 | Std=15.8 | MinDist=7.21 | Conflicts=0
# [GEN  720] PenalizedBest=1189.4 | AvgPenalized=1219.5 | CleanBest=1163.7 | AvgClean=1165.7 | Std=10.9 | MinDist=6.08 | Conflicts=0
# [GEN  720] PenalizedBest=1217.5 | AvgPenalized=1218.0 | CleanBest=1150.5 | AvgClean=1150.6 | Std=0.7 | MinDist=6.08 | Conflicts=0
# [GEN  800] PenalizedBest=1237.5 | AvgPenalized=1258.5 | CleanBest=1156.7 | AvgClean=1157.2 | Std=2.9 | MinDist=6.00 | Conflicts=0
#
# ===== GA COMPLETADO =====
# Mejor fitness penalizado = 1237.478
# Mejor distancia real     = 1156.678
# Tiempo = 406.74 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN   80] PenalizedBest=1695.9 | AvgPenalized=1747.1 | CleanBest=1085.2 | AvgClean=1103.8 | Std=35.2 | MinDist=5.00 | Conflicts=2
# [GEN  800] PenalizedBest=1565.4 | AvgPenalized=1678.8 | CleanBest=1175.4 | AvgClean=1179.4 | Std=14.8 | MinDist=6.08 | Conflicts=0
#
# ===== GA COMPLETADO =====
# Mejor fitness penalizado = 1565.436
# Mejor distancia real     = 1175.436
# Tiempo = 431.63 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN  800] PenalizedBest=1665.0 | AvgPenalized=1685.2 | CleanBest=1137.8 | AvgClean=1138.2 | Std=3.0 | MinDist=6.08 | Conflicts=0
#
# ===== GA COMPLETADO =====
# Mejor fitness penalizado = 1664.180
# Mejor distancia real     = 1136.980
# Tiempo = 404.75 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN  800] PenalizedBest=1427.8 | AvgPenalized=1434.2 | CleanBest=1201.7 | AvgClean=1202.1 | Std=3.0 | MinDist=7.21 | Conflicts=0
#
# ===== GA COMPLETADO =====
# Mejor fitness penalizado = 1427.799
# Mejor distancia real     = 1201.749
# Tiempo = 429.31 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN  640] PenalizedBest=1405.0 | AvgPenalized=1438.7 | CleanBest=1275.3 | AvgClean=1276.6 | Std=9.5 | MinDist=7.21 | Conflicts=0
# [GEN  800] PenalizedBest=1189.4 | AvgPenalized=1206.3 | CleanBest=1163.7 | AvgClean=1164.3 | Std=4.1 | MinDist=6.08 | Conflicts=0
#
# ===== GA COMPLETADO =====
# Mejor fitness penalizado = 1189.358
# Mejor distancia real     = 1163.708
# Tiempo = 422.15 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN   80] PenalizedBest=1672.1 | AvgPenalized=1687.3 | CleanBest=1082.3 | AvgClean=1084.3 | Std=12.5 | MinDist=5.00 | Conflicts=3
# [GEN  800] PenalizedBest=1217.5 | AvgPenalized=1269.3 | CleanBest=1150.5 | AvgClean=1151.1 | Std=4.4 | MinDist=6.08 | Conflicts=0
#
# ===== GA COMPLETADO =====
# Mejor fitness penalizado = 1217.507
# Mejor distancia real     = 1150.507
# Tiempo = 401.06 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [GEN  160] PenalizedBest=1695.9 | AvgPenalized=1748.7 | CleanBest=1170.0 | AvgClean=1173.1 | Std=16.9 | MinDist=5.00 | Conflicts=2
# [GEN   80] PenalizedBest=1790.6 | AvgPenalized=1840.1 | CleanBest=1124.9 | AvgClean=1127.6 | Std=14.7 | MinDist=5.00 | Conflicts=2
# [GEN   80] PenalizedBest=1705.7 | AvgPenalized=1711.8 | CleanBest=1170.2 | AvgClean=1170.8 | Std=5.2 | MinDist=6.00 | Conflicts=0
# [GEN   80] PenalizedBest=1781.5 | AvgPenalized=1803.8 | CleanBest=1135.9 | AvgClean=1137.0 | Std=12.8 | MinDist=3.61 | Conflicts=3
# [GEN   80] PenalizedBest=1527.0 | AvgPenalized=1604.7 | CleanBest=1124.3 | AvgClean=1126.5 | Std=10.9 | MinDist=6.00 | Conflicts=0
# [GEN  720] PenalizedBest=1403.0 | AvgPenalized=1421.4 | CleanBest=1273.3 | AvgClean=1275.1 | Std=5.4 | MinDist=7.21 | Conflicts=0
# [GEN  160] PenalizedBest=1396.8 | AvgPenalized=1437.8 | CleanBest=1082.3 | AvgClean=1095.6 | Std=12.4 | MinDist=5.39 | Conflicts=1
# [GEN   80] PenalizedBest=1211.5 | AvgPenalized=1243.7 | CleanBest=1163.7 | AvgClean=1164.6 | Std=6.6 | MinDist=6.08 | Conflicts=0
# [GEN  240] PenalizedBest=1656.6 | AvgPenalized=1691.8 | CleanBest=1168.4 | AvgClean=1169.4 | Std=7.5 | MinDist=5.00 | Conflicts=2
# [GEN  160] PenalizedBest=1586.9 | AvgPenalized=1617.6 | CleanBest=1140.3 | AvgClean=1141.8 | Std=13.3 | MinDist=6.40 | Conflicts=0
# [GEN  160] PenalizedBest=1781.5 | AvgPenalized=1836.0 | CleanBest=1135.9 | AvgClean=1137.3 | Std=6.8 | MinDist=6.32 | Conflicts=0
# [GEN  160] PenalizedBest=1705.7 | AvgPenalized=1787.6 | CleanBest=1170.2 | AvgClean=1172.0 | Std=11.2 | MinDist=6.00 | Conflicts=0
# [GEN  160] PenalizedBest=1525.6 | AvgPenalized=1533.3 | CleanBest=1122.9 | AvgClean=1123.4 | Std=4.1 | MinDist=6.00 | Conflicts=0
# [GEN  240] PenalizedBest=1275.0 | AvgPenalized=1363.3 | CleanBest=1122.4 | AvgClean=1125.2 | Std=13.0 | MinDist=6.08 | Conflicts=0
# [GEN  160] PenalizedBest=1207.3 | AvgPenalized=1382.1 | CleanBest=1161.3 | AvgClean=1169.2 | Std=31.3 | MinDist=6.08 | Conflicts=0
# [GEN  800] PenalizedBest=1397.0 | AvgPenalized=1454.2 | CleanBest=1267.3 | AvgClean=1268.3 | Std=6.4 | MinDist=7.07 | Conflicts=0
#
# ===== GA COMPLETADO =====
# Mejor fitness penalizado = 1393.035
# Mejor distancia real     = 1263.335
# Tiempo = 477.96 s
# [GEN  320] PenalizedBest=1649.8 | AvgPenalized=1745.8 | CleanBest=1161.5 | AvgClean=1164.4 | Std=13.6 | MinDist=5.00 | Conflicts=2
# [GEN  240] PenalizedBest=1535.8 | AvgPenalized=1581.0 | CleanBest=1136.9 | AvgClean=1138.7 | Std=8.1 | MinDist=6.40 | Conflicts=0
# [GEN  240] PenalizedBest=1781.5 | AvgPenalized=1848.6 | CleanBest=1135.9 | AvgClean=1137.7 | Std=10.1 | MinDist=6.32 | Conflicts=0
# [GEN  240] PenalizedBest=1693.9 | AvgPenalized=1743.2 | CleanBest=1163.0 | AvgClean=1164.9 | Std=11.7 | MinDist=6.00 | Conflicts=0
# [GEN  240] PenalizedBest=1525.6 | AvgPenalized=1664.9 | CleanBest=1122.9 | AvgClean=1124.2 | Std=6.8 | MinDist=6.00 | Conflicts=0
# [GEN  320] PenalizedBest=1219.5 | AvgPenalized=1277.4 | CleanBest=1102.7 | AvgClean=1109.8 | Std=9.3 | MinDist=6.08 | Conflicts=0
# [GEN  240] PenalizedBest=1200.3 | AvgPenalized=1254.7 | CleanBest=1157.3 | AvgClean=1160.3 | Std=13.0 | MinDist=6.08 | Conflicts=0
# [GEN  400] PenalizedBest=1649.8 | AvgPenalized=1717.0 | CleanBest=1161.5 | AvgClean=1163.9 | Std=9.5 | MinDist=5.00 | Conflicts=2
# [GEN  320] PenalizedBest=1532.4 | AvgPenalized=1569.0 | CleanBest=1133.5 | AvgClean=1134.8 | Std=7.8 | MinDist=6.40 | Conflicts=0
# [GEN  320] PenalizedBest=1781.5 | AvgPenalized=1791.8 | CleanBest=1135.9 | AvgClean=1136.5 | Std=4.2 | MinDist=6.32 | Conflicts=0
# [GEN  320] PenalizedBest=1693.9 | AvgPenalized=1721.9 | CleanBest=1163.0 | AvgClean=1163.5 | Std=4.0 | MinDist=6.00 | Conflicts=0
# [GEN  320] PenalizedBest=1525.6 | AvgPenalized=1643.4 | CleanBest=1122.9 | AvgClean=1126.5 | Std=13.0 | MinDist=6.00 | Conflicts=0
# [GEN  400] PenalizedBest=1215.2 | AvgPenalized=1234.0 | CleanBest=1098.5 | AvgClean=1099.4 | Std=6.6 | MinDist=6.08 | Conflicts=0
# [GEN  320] PenalizedBest=1198.9 | AvgPenalized=1235.5 | CleanBest=1155.9 | AvgClean=1158.4 | Std=12.8 | MinDist=6.08 | Conflicts=0
# [GEN  480] PenalizedBest=1649.8 | AvgPenalized=1697.2 | CleanBest=1161.5 | AvgClean=1163.3 | Std=13.6 | MinDist=5.00 | Conflicts=2
# [GEN  400] PenalizedBest=1532.4 | AvgPenalized=1627.1 | CleanBest=1133.5 | AvgClean=1135.0 | Std=7.9 | MinDist=6.40 | Conflicts=0
# [GEN  400] PenalizedBest=1781.5 | AvgPenalized=1812.4 | CleanBest=1135.9 | AvgClean=1136.8 | Std=5.8 | MinDist=6.32 | Conflicts=0
# [GEN  400] PenalizedBest=1525.6 | AvgPenalized=1565.2 | CleanBest=1122.9 | AvgClean=1123.5 | Std=3.6 | MinDist=6.00 | Conflicts=0
# [GEN  400] PenalizedBest=1693.9 | AvgPenalized=1746.3 | CleanBest=1163.0 | AvgClean=1163.9 | Std=5.0 | MinDist=6.00 | Conflicts=0
# [GEN  480] PenalizedBest=1211.0 | AvgPenalized=1231.6 | CleanBest=1094.2 | AvgClean=1095.3 | Std=7.8 | MinDist=6.08 | Conflicts=0
# [GEN  400] PenalizedBest=1196.8 | AvgPenalized=1236.8 | CleanBest=1152.3 | AvgClean=1154.1 | Std=7.9 | MinDist=6.08 | Conflicts=0
# [GEN  480] PenalizedBest=1781.5 | AvgPenalized=1838.5 | CleanBest=1135.9 | AvgClean=1137.4 | Std=7.4 | MinDist=6.32 | Conflicts=0
# [GEN  480] PenalizedBest=1532.4 | AvgPenalized=1586.4 | CleanBest=1133.5 | AvgClean=1134.6 | Std=7.4 | MinDist=6.40 | Conflicts=0
# [GEN  560] PenalizedBest=1649.0 | AvgPenalized=1686.0 | CleanBest=1160.7 | AvgClean=1161.7 | Std=6.1 | MinDist=5.00 | Conflicts=2
# [GEN  480] PenalizedBest=1525.6 | AvgPenalized=1623.6 | CleanBest=1122.9 | AvgClean=1124.1 | Std=8.1 | MinDist=6.00 | Conflicts=0
# [GEN  480] PenalizedBest=1693.9 | AvgPenalized=1711.4 | CleanBest=1163.0 | AvgClean=1163.1 | Std=1.6 | MinDist=6.00 | Conflicts=0
# [GEN  560] PenalizedBest=1208.1 | AvgPenalized=1220.7 | CleanBest=1091.4 | AvgClean=1092.1 | Std=5.7 | MinDist=6.08 | Conflicts=0
# [GEN  480] PenalizedBest=1196.8 | AvgPenalized=1228.2 | CleanBest=1152.3 | AvgClean=1155.1 | Std=17.1 | MinDist=6.08 | Conflicts=0
# [GEN  560] PenalizedBest=1781.5 | AvgPenalized=1903.8 | CleanBest=1135.9 | AvgClean=1138.6 | Std=13.0 | MinDist=6.32 | Conflicts=0
# [GEN  560] PenalizedBest=1524.5 | AvgPenalized=1544.9 | CleanBest=1132.5 | AvgClean=1132.9 | Std=3.2 | MinDist=6.40 | Conflicts=0
# [GEN  640] PenalizedBest=1649.0 | AvgPenalized=1744.6 | CleanBest=1159.1 | AvgClean=1162.6 | Std=9.0 | MinDist=5.00 | Conflicts=2
# [GEN  560] PenalizedBest=1524.2 | AvgPenalized=1547.7 | CleanBest=1121.5 | AvgClean=1122.4 | Std=7.2 | MinDist=6.00 | Conflicts=0
# [GEN  640] PenalizedBest=1208.1 | AvgPenalized=1237.7 | CleanBest=1091.4 | AvgClean=1091.8 | Std=3.6 | MinDist=6.08 | Conflicts=0
# [GEN  560] PenalizedBest=1692.5 | AvgPenalized=1728.1 | CleanBest=1161.5 | AvgClean=1164.1 | Std=19.7 | MinDist=6.08 | Conflicts=0
# [GEN  560] PenalizedBest=1196.8 | AvgPenalized=1272.6 | CleanBest=1152.3 | AvgClean=1154.6 | Std=10.5 | MinDist=6.08 | Conflicts=0
# [GEN  640] PenalizedBest=1517.5 | AvgPenalized=1568.6 | CleanBest=1128.5 | AvgClean=1129.8 | Std=8.0 | MinDist=6.40 | Conflicts=0
# [GEN  640] PenalizedBest=1380.6 | AvgPenalized=1409.7 | CleanBest=1196.9 | AvgClean=1197.5 | Std=4.2 | MinDist=6.00 | Conflicts=0
# [GEN  720] PenalizedBest=1649.0 | AvgPenalized=1748.7 | CleanBest=1160.7 | AvgClean=1163.8 | Std=16.9 | MinDist=5.00 | Conflicts=2
# [GEN  640] PenalizedBest=1524.2 | AvgPenalized=1531.8 | CleanBest=1121.5 | AvgClean=1122.1 | Std=4.9 | MinDist=6.00 | Conflicts=0
# [GEN  720] PenalizedBest=1191.7 | AvgPenalized=1214.7 | CleanBest=1080.9 | AvgClean=1081.4 | Std=5.0 | MinDist=6.08 | Conflicts=0
# [GEN  640] PenalizedBest=1692.5 | AvgPenalized=1736.0 | CleanBest=1161.5 | AvgClean=1162.9 | Std=10.0 | MinDist=6.08 | Conflicts=0
# [GEN  640] PenalizedBest=1196.8 | AvgPenalized=1226.5 | CleanBest=1152.3 | AvgClean=1153.1 | Std=9.4 | MinDist=6.08 | Conflicts=0
# [GEN  720] PenalizedBest=1517.5 | AvgPenalized=1607.2 | CleanBest=1128.5 | AvgClean=1130.4 | Std=9.4 | MinDist=6.40 | Conflicts=0
# [GEN  720] PenalizedBest=1364.6 | AvgPenalized=1433.3 | CleanBest=1182.6 | AvgClean=1184.8 | Std=11.8 | MinDist=7.07 | Conflicts=0
# [GEN  800] PenalizedBest=1649.0 | AvgPenalized=1701.8 | CleanBest=1160.7 | AvgClean=1161.7 | Std=5.7 | MinDist=5.00 | Conflicts=2
#
# ===== GA COMPLETADO =====
# Mejor fitness penalizado = 1595.379
# Mejor distancia real     = 1117.879
# Tiempo = 387.81 s
# [GEN  720] PenalizedBest=1521.2 | AvgPenalized=1634.4 | CleanBest=1121.5 | AvgClean=1126.9 | Std=24.3 | MinDist=6.00 | Conflicts=0
# [GEN  800] PenalizedBest=1191.7 | AvgPenalized=1231.8 | CleanBest=1080.9 | AvgClean=1082.3 | Std=9.7 | MinDist=6.08 | Conflicts=0
#
# ===== GA COMPLETADO =====
# Mejor fitness penalizado = 1191.659
# Mejor distancia real     = 1080.909
# Tiempo = 360.27 s
# [GEN  720] PenalizedBest=1692.5 | AvgPenalized=1700.3 | CleanBest=1161.5 | AvgClean=1161.7 | Std=1.4 | MinDist=6.08 | Conflicts=0
# [GEN  720] PenalizedBest=1196.8 | AvgPenalized=1211.4 | CleanBest=1152.3 | AvgClean=1153.6 | Std=8.4 | MinDist=6.08 | Conflicts=0
# [GEN  800] PenalizedBest=1514.8 | AvgPenalized=1517.2 | CleanBest=1122.8 | AvgClean=1124.1 | Std=15.5 | MinDist=6.40 | Conflicts=0
#
# ===== GA COMPLETADO =====
# Mejor fitness penalizado = 1514.808
# Mejor distancia real     = 1122.808
# Tiempo = 367.45 s
# [GEN  800] PenalizedBest=1521.2 | AvgPenalized=1553.6 | CleanBest=1121.5 | AvgClean=1122.5 | Std=7.7 | MinDist=6.00 | Conflicts=0
#
# ===== GA COMPLETADO =====
# Mejor fitness penalizado = 1511.859
# Mejor distancia real     = 1121.909
# Tiempo = 352.88 s
# [GEN  800] PenalizedBest=1350.9 | AvgPenalized=1452.2 | CleanBest=1168.9 | AvgClean=1172.2 | Std=17.3 | MinDist=7.07 | Conflicts=0
#
# ===== GA COMPLETADO =====
# Mejor fitness penalizado = 1350.921
# Mejor distancia real     = 1168.921
# Tiempo = 364.49 s
# [GEN  800] PenalizedBest=1692.5 | AvgPenalized=1713.9 | CleanBest=1161.5 | AvgClean=1162.8 | Std=9.5 | MinDist=6.08 | Conflicts=0
#
# ===== GA COMPLETADO =====
# Mejor fitness penalizado = 1692.486
# Mejor distancia real     = 1161.536
# Tiempo = 375.51 s
# [GEN  800] PenalizedBest=1196.8 | AvgPenalized=1244.7 | CleanBest=1152.3 | AvgClean=1153.3 | Std=6.4 | MinDist=6.08 | Conflicts=0
#
# ===== GA COMPLETADO =====
# Mejor fitness penalizado = 1188.329
# Mejor distancia real     = 1158.879
# Tiempo = 365.52 s
#
# ============================================================
# Experiments completed!
# Successful: 31
# Failed: 0
# Total time: 26.97 minutes
# Average time per run: 52.20 seconds
# ============================================================

# %% [markdown]
# ## 7. Statistical Analysis

# %%
import pandas as pd
from scipy import stats

# Load results from database
con = sqlite3.connect(DB_PATH)
df = pd.read_sql_query("SELECT * FROM runs", con)
con.close()

print(f"Total runs in database: {len(df)}")
df.head()
# Out:
# Total runs in database: 31
#    id  pop_size  ngen  cxpb  mutpb  seed  best_penalized   best_clean  \
# 0   1       150   800   0.8    0.3     5     1204.191486  1139.891486
# 1   2       150   800   0.8    0.3     7     1266.649855  1128.849855
# 2   3       150   800   0.8    0.3     6     1330.385642  1159.435642
# 3   4       150   800   0.8    0.3     2     1323.006709  1162.506709
# 4   5       150   800   0.8    0.3     1     1184.629292  1153.879292
#
#      time_sec            timestamp
# 0  396.329120  2025-12-11 10:08:51
# 1  402.284416  2025-12-11 10:08:57
# 2  411.140435  2025-12-11 10:09:06
# 3  421.320036  2025-12-11 10:09:16
# 4  421.890007  2025-12-11 10:09:17

# %%
# Statistical summary
print("\n" + "="*80)
print("GA STATISTICAL SUMMARY")
print("="*80)
print(f"\nConfiguration: pop_size={BEST_PARAMS['pop_size']}, ngen={BEST_PARAMS['ngen']}, "
      f"cxpb={BEST_PARAMS['cxpb']}, mutpb={BEST_PARAMS['mutpb']}")
print(f"Number of runs: {len(df)}\n")

# Best Penalized
print(f"Best Penalized:")
print(f"  Mean: {df['best_penalized'].mean():.2f}")
print(f"  Std: {df['best_penalized'].std():.2f}")
print(f"  Min: {df['best_penalized'].min():.2f}")
print(f"  Max: {df['best_penalized'].max():.2f}")
print(f"  Median: {df['best_penalized'].median():.2f}")

# Best Clean
print(f"\nBest Clean:")
print(f"  Mean: {df['best_clean'].mean():.2f}")
print(f"  Std: {df['best_clean'].std():.2f}")
print(f"  Min: {df['best_clean'].min():.2f}")
print(f"  Max: {df['best_clean'].max():.2f}")
print(f"  Median: {df['best_clean'].median():.2f}")

# Computation Time
print(f"\nComputation Time (seconds):")
print(f"  Mean: {df['time_sec'].mean():.2f}")
print(f"  Std: {df['time_sec'].std():.2f}")
print(f"  Min: {df['time_sec'].min():.2f}")
print(f"  Max: {df['time_sec'].max():.2f}")

# 95% Confidence intervals
ci_penalized = stats.t.interval(0.95, len(df)-1, 
                                 loc=df['best_penalized'].mean(),
                                 scale=stats.sem(df['best_penalized']))
ci_clean = stats.t.interval(0.95, len(df)-1,
                            loc=df['best_clean'].mean(),
                            scale=stats.sem(df['best_clean']))

print(f"\n95% Confidence Intervals:")
print(f"  Best Penalized: [{ci_penalized[0]:.2f}, {ci_penalized[1]:.2f}]")
print(f"  Best Clean: [{ci_clean[0]:.2f}, {ci_clean[1]:.2f}]")
# Out:
# ================================================================================
# GA STATISTICAL SUMMARY
# ================================================================================
#
# Configuration: pop_size=150, ngen=800, cxpb=0.8, mutpb=0.3
# Number of runs: 31
#
# Best Penalized:
#   Mean: 1311.74
#   Std: 160.12
#   Min: 1123.09
#   Max: 1692.49
#   Median: 1244.49
#
# Best Clean:
#   Mean: 1146.93
#   Std: 41.00
#   Min: 1079.32
#   Max: 1263.34
#   Median: 1152.41
#
# Computation Time (seconds):
#   Mean: 403.00
#   Std: 27.29
#   Min: 353.35
#   Max: 478.43
#
# 95% Confidence Intervals:
#   Best Penalized: [1253.01, 1370.47]
#   Best Clean: [1131.89, 1161.97]

# %% [markdown]
# ## 8. Normality Tests

# %%
# Shapiro-Wilk test for normality
stat_pen, p_pen = stats.shapiro(df['best_penalized'])
stat_clean, p_clean = stats.shapiro(df['best_clean'])

print("\n=== Normality Tests (Shapiro-Wilk) ===")
print(f"Best Penalized: stat={stat_pen:.4f}, p-value={p_pen:.4f}")
print(f"  -> {'Normal distribution' if p_pen > 0.05 else 'Not normal distribution'} (α=0.05)")
print(f"\nBest Clean: stat={stat_clean:.4f}, p-value={p_clean:.4f}")
print(f"  -> {'Normal distribution' if p_clean > 0.05 else 'Not normal distribution'} (α=0.05)")
# Out:
# === Normality Tests (Shapiro-Wilk) ===
# Best Penalized: stat=0.8620, p-value=0.0009
#   -> Not normal distribution (α=0.05)
#
# Best Clean: stat=0.9368, p-value=0.0672
#   -> Normal distribution (α=0.05)

# %% [markdown]
# ## 9. Export Results

# %%
# Export all results to CSV
df.to_csv('../results/individual/ga_all_results.csv', index=False)
print("✓ All results exported to ga_all_results.csv")

# Export summary statistics
summary = pd.DataFrame({
    'metric': ['best_penalized', 'best_clean', 'time_sec'],
    'mean': [df['best_penalized'].mean(), df['best_clean'].mean(), df['time_sec'].mean()],
    'std': [df['best_penalized'].std(), df['best_clean'].std(), df['time_sec'].std()],
    'min': [df['best_penalized'].min(), df['best_clean'].min(), df['time_sec'].min()],
    'max': [df['best_penalized'].max(), df['best_clean'].max(), df['time_sec'].max()],
    'median': [df['best_penalized'].median(), df['best_clean'].median(), df['time_sec'].median()]
})
summary.to_csv('../results/individual/ga_statistical_summary.csv', index=False)
print("✓ Statistical summary exported to ga_statistical_summary.csv")
# Out:
# ✓ All results exported to ga_all_results.csv
# ✓ Statistical summary exported to ga_statistical_summary.csv
