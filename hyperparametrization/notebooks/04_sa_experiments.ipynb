# %% [markdown]
# # Simulated Annealing Experiments with Best Parameters (30 Seeds)
#
# This notebook runs SA experiments with the best configuration using 30 different seeds for statistical analysis.

# %% [markdown]
# ## 1. Import Libraries

# %%
import os
import sys
import sqlite3
import time
import random
import numpy as np
import multiprocessing as mp

# Add project root to path
ROOT_DIR = os.path.dirname(os.path.abspath(os.getcwd()))
sys.path.append(ROOT_DIR)

from algorithms.sa_runner import run_sa

print("✓ Libraries imported successfully")
# Out:
# ✓ Libraries imported successfully

# %% [markdown]
# ## 2. Database Setup

# %%
DB_PATH = "../data/sa_experiments.db"

def init_sa_db(db_path):
    """Initialize database for SA results"""
    con = sqlite3.connect(db_path)
    cur = con.cursor()
    
    cur.execute("""
        CREATE TABLE IF NOT EXISTS runs (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            n_iter INTEGER,
            start_temp REAL,
            end_temp REAL,
            seed INTEGER,
            best_penalized REAL,
            best_clean REAL,
            time_sec REAL,
            timestamp DATETIME DEFAULT CURRENT_TIMESTAMP
        )
    """)
    
    con.commit()
    con.close()
    print(f"✓ Database initialized: {db_path}")

init_sa_db(DB_PATH)
# Out:
# ✓ Database initialized: sa_experiments.db

# %% [markdown]
# ## 3. Save Results Function

# %%
def save_sa_run(db_path, n_iter, start_temp, end_temp, seed, best_penalized, best_distance, time_sec):
    """Save a single SA run to database"""
    con = sqlite3.connect(db_path)
    cur = con.cursor()
    
    cur.execute("""
        INSERT INTO runs (
            n_iter, start_temp, end_temp, seed,
            best_penalized, best_clean, time_sec
        ) VALUES (?, ?, ?, ?, ?, ?, ?)
    """, (
        n_iter, start_temp, end_temp, seed,
        float(best_penalized), float(best_distance), time_sec
    ))
    
    con.commit()
    con.close()

print("✓ Save function defined")
# Out:
# ✓ Save function defined

# %% [markdown]
# ## 4. Worker Function for Multiprocessing

# %%
def sa_worker(args):
    """Worker function to run a single SA experiment"""
    n_iter, start_temp, end_temp, seed, db_path = args
    
    t0 = time.time()
    try:
        results = run_sa(
            n_iter=n_iter,
            start_temp=start_temp,
            end_temp=end_temp,
            seed=seed,
            show_plots=False,
            show_anim=False,
            debug_interval=max(1, n_iter // 10)
        )
        t1 = time.time()
        
        save_sa_run(db_path, n_iter, start_temp, end_temp, seed,
                   results['best_penalized'], results['best_distance'], t1 - t0)
        
        return {
            'success': True,
            'seed': seed,
            'best_penalized': results['best_penalized'],
            'time': t1 - t0
        }
    except Exception as e:
        return {
            'success': False,
            'seed': seed,
            'error': str(e)
        }

print("✓ Worker function defined")
# Out:
# ✓ Worker function defined

# %% [markdown]
# ## 5. Best Parameters Configuration

# %%
# Best parameters for SA (from grid search: n_iter=12000, start_temp=5, end_temp=0.01)
BEST_PARAMS = {
    'n_iter': 5000,
    'start_temp': 20,
    'end_temp': 0.01
}

# Seeds for statistical analysis (31 runs: 0-30)
SEEDS = list(range(31))

# Number of parallel processes
N_JOBS = min(8, mp.cpu_count())

print(f"Best parameters: {BEST_PARAMS}")
print(f"Number of seeds: {len(SEEDS)}")
print(f"Number of parallel jobs: {N_JOBS}")
print(f"Total experiments: {len(SEEDS)}")
# Out:
# Best parameters: {'n_iter': 5000, 'start_temp': 20, 'end_temp': 0.01}
# Number of seeds: 31
# Number of parallel jobs: 8
# Total experiments: 31

# %% [markdown]
# ## 6. Run Experiments with Multithreading

# %%
from tqdm.notebook import tqdm

# Generate tasks (one per seed, no nested loops)
tasks = [(BEST_PARAMS['n_iter'], BEST_PARAMS['start_temp'], BEST_PARAMS['end_temp'], 
          seed, DB_PATH) for seed in SEEDS]

print(f"Total experiments to run: {len(tasks)}")
print(f"Running with {N_JOBS} parallel workers...\n")

# Run experiments in parallel
start_time = time.time()
with mp.Pool(processes=N_JOBS) as pool:
    results = list(tqdm(
        pool.imap(sa_worker, tasks),
        total=len(tasks),
        desc="SA Experiments"
    ))
total_time = time.time() - start_time

# Summary
successful = sum(1 for r in results if r['success'])
failed = len(results) - successful

print(f"\n{'='*60}")
print(f"Experiments completed!")
print(f"Successful: {successful}")
print(f"Failed: {failed}")
print(f"Total time: {total_time/60:.2f} minutes")
print(f"Average time per run: {total_time/len(tasks):.2f} seconds")
print(f"{'='*60}")
# Out:
# Total experiments to run: 31
# Running with 8 parallel workers...
#
# [INFO] Valores únicos del BMP original:[INFO] Valores únicos del BMP original:[INFO] Valores únicos del BMP original: [INFO] Valores únicos del BMP original:[INFO] Valores únicos del BMP original:[INFO] Valores únicos del BMP original:  [INFO] Valores únicos del BMP original:[INFO] Valores únicos del BMP original:
# SA Experiments:   0%|          | 0/31 [00:00<?, ?it/s]
#   [  0 255] [  0 255]  [  0 255][  0 255]
#
# [  0 255][  0 255][  0 255]
#
# [  0 255]
#
# [INFO] Valores únicos tras invertir:
#
# [INFO] Valores únicos tras invertir:[INFO] Valores únicos tras invertir:[INFO] Valores únicos tras invertir:[INFO] Valores únicos tras invertir:   [INFO] Valores únicos tras invertir:[INFO] Valores únicos tras invertir:[INFO] Valores únicos tras invertir:  [  0 255][  0 255][  0 255]  [  0 255][  0 255]
#
#
#
# [  0 255]
# [INFO] Environment cargado: 92 x 113[INFO] Environment cargado: 92 x 113[  0 255]
# [INFO] Environment cargado: 92 x 113
#
# [  0 255][INFO] Environment cargado: 92 x 113
# [INFO] Environment cargado: 92 x 113
#
# [INFO] Environment cargado: 92 x 113
# [INFO] Environment cargado: 92 x 113
#
# [INFO] Environment cargado: 92 x 113
#
# [IT     1] T=19.9696  BestPenalized=3297.08  BestCleanDist=1032.08  CurrCleanDist=1032.08  MinDist=0.00  Conflicts=15
# [IT     1] T=19.9696  BestPenalized=3297.08  BestCleanDist=1032.08  CurrCleanDist=1032.08  MinDist=0.00  Conflicts=15
# [IT     1] T=19.9696  BestPenalized=3297.08  BestCleanDist=1032.08  CurrCleanDist=1032.08  MinDist=0.00  Conflicts=15
# [IT     1] T=19.9696  BestPenalized=3297.08  BestCleanDist=1032.08  CurrCleanDist=1032.08  MinDist=0.00  Conflicts=15
# [IT     1] T=19.9696  BestPenalized=3297.08  BestCleanDist=1032.08  CurrCleanDist=1032.08  MinDist=0.00  Conflicts=15
# [IT     1] T=19.9696  BestPenalized=3297.08  BestCleanDist=1032.08  CurrCleanDist=1032.08  MinDist=0.00  Conflicts=15[IT     1] T=19.9696  BestPenalized=3295.48  BestCleanDist=1075.88  CurrCleanDist=1075.88  MinDist=1.41  Conflicts=14
#
# [IT     1] T=19.9696  BestPenalized=3297.08  BestCleanDist=1032.08  CurrCleanDist=1032.08  MinDist=0.00  Conflicts=15
# [IT   500] T=9.3525  BestPenalized=3049.74  BestCleanDist=1109.44  CurrCleanDist=1127.85  MinDist=1.00  Conflicts=11
# [IT   500] T=9.3525  BestPenalized=2535.46  BestCleanDist=1145.71  CurrCleanDist=1146.29  MinDist=4.47  Conflicts=6
# [IT   500] T=9.3525  BestPenalized=2900.38  BestCleanDist=1159.68  CurrCleanDist=1160.26  MinDist=0.00  Conflicts=9
# [IT   500] T=9.3525  BestPenalized=2357.28  BestCleanDist=1115.78  CurrCleanDist=1139.75  MinDist=1.41  Conflicts=4
# [IT   500] T=9.3525  BestPenalized=2795.66  BestCleanDist=1223.76  CurrCleanDist=1257.49  MinDist=4.12  Conflicts=6
# [IT   500] T=9.3525  BestPenalized=3044.90  BestCleanDist=1134.05  CurrCleanDist=1136.64  MinDist=1.41  Conflicts=9
# [IT   500] T=9.3525  BestPenalized=2220.08  BestCleanDist=1374.28  CurrCleanDist=1374.28  MinDist=6.08  Conflicts=0
# [IT   500] T=9.3525  BestPenalized=2828.09  BestCleanDist=1197.09  CurrCleanDist=1263.48  MinDist=0.00  Conflicts=6
# [IT  1000] T=4.3734  BestPenalized=3049.74  BestCleanDist=1109.44  CurrCleanDist=1161.51  MinDist=1.00  Conflicts=11
# [IT  1000] T=4.3734  BestPenalized=2357.28  BestCleanDist=1115.78  CurrCleanDist=1140.34  MinDist=1.41  Conflicts=4
# [IT  1000] T=4.3734  BestPenalized=2900.38  BestCleanDist=1159.68  CurrCleanDist=1162.51  MinDist=0.00  Conflicts=9
# [IT  1000] T=4.3734  BestPenalized=2132.64  BestCleanDist=1195.44  CurrCleanDist=1199.44  MinDist=5.00  Conflicts=2
# [IT  1000] T=4.3734  BestPenalized=2625.33  BestCleanDist=1284.13  CurrCleanDist=1285.55  MinDist=4.12  Conflicts=4[IT  1000] T=4.3734  BestPenalized=2795.66  BestCleanDist=1223.76  CurrCleanDist=1258.90  MinDist=4.12  Conflicts=6
#
# [IT  1000] T=4.3734  BestPenalized=2828.09  BestCleanDist=1197.09  CurrCleanDist=1288.28  MinDist=0.00  Conflicts=6
# [IT  1000] T=4.3734  BestPenalized=2175.73  BestCleanDist=1372.93  CurrCleanDist=1372.93  MinDist=6.08  Conflicts=0
# [IT  1500] T=2.0451  BestPenalized=1892.70  BestCleanDist=1215.45  CurrCleanDist=1215.45  MinDist=6.00  Conflicts=0
# [IT  1500] T=2.0451  BestPenalized=3040.54  BestCleanDist=1285.49  CurrCleanDist=1285.49  MinDist=2.83  Conflicts=7
# [IT  1500] T=2.0451  BestPenalized=2132.64  BestCleanDist=1195.44  CurrCleanDist=1202.26  MinDist=5.00  Conflicts=2
# [IT  1500] T=2.0451  BestPenalized=2433.43  BestCleanDist=1292.18  CurrCleanDist=1294.18  MinDist=2.00  Conflicts=4
# [IT  1500] T=2.0451  BestPenalized=2491.57  BestCleanDist=1336.42  CurrCleanDist=1336.42  MinDist=5.00  Conflicts=1
# [IT  1500] T=2.0451  BestPenalized=2828.09  BestCleanDist=1197.09  CurrCleanDist=1287.69  MinDist=0.00  Conflicts=6
# [IT  1500] T=2.0451  BestPenalized=2645.13  BestCleanDist=1454.33  CurrCleanDist=1454.33  MinDist=6.40  Conflicts=0
# [IT  1500] T=2.0451  BestPenalized=2175.73  BestCleanDist=1372.93  CurrCleanDist=1372.93  MinDist=6.08  Conflicts=0
# [IT  2000] T=0.9564  BestPenalized=1890.00  BestCleanDist=1214.45  CurrCleanDist=1214.45  MinDist=6.00  Conflicts=0
# [IT  2000] T=0.9564  BestPenalized=2412.72  BestCleanDist=1377.22  CurrCleanDist=1377.22  MinDist=5.66  Conflicts=2
# [IT  2000] T=0.9564  BestPenalized=1891.24  BestCleanDist=1286.69  CurrCleanDist=1286.69  MinDist=6.71  Conflicts=0
# [IT  2000] T=0.9564  BestPenalized=2309.57  BestCleanDist=1305.32  CurrCleanDist=1305.32  MinDist=2.00  Conflicts=4
# [IT  2000] T=0.9564  BestPenalized=2475.70  BestCleanDist=1338.25  CurrCleanDist=1338.25  MinDist=5.00  Conflicts=1
# [IT  2000] T=0.9564  BestPenalized=2828.09  BestCleanDist=1197.09  CurrCleanDist=1282.45  MinDist=0.00  Conflicts=6
# [IT  2000] T=0.9564  BestPenalized=2508.97  BestCleanDist=1472.37  CurrCleanDist=1472.37  MinDist=6.40  Conflicts=0
# [IT  2000] T=0.9564  BestPenalized=2171.73  BestCleanDist=1368.93  CurrCleanDist=1368.93  MinDist=6.00  Conflicts=0
# [IT  2500] T=0.4472  BestPenalized=1889.17  BestCleanDist=1213.62  CurrCleanDist=1213.62  MinDist=6.00  Conflicts=0
# [IT  2500] T=0.4472  BestPenalized=1857.74  BestCleanDist=1282.69  CurrCleanDist=1282.69  MinDist=7.07  Conflicts=0
# [IT  2500] T=0.4472  BestPenalized=2285.47  BestCleanDist=1417.67  CurrCleanDist=1417.67  MinDist=8.54  Conflicts=0
# [IT  2500] T=0.4472  BestPenalized=2475.70  BestCleanDist=1338.25  CurrCleanDist=1338.83  MinDist=5.00  Conflicts=1
# [IT  2500] T=0.4472  BestPenalized=2306.74  BestCleanDist=1302.49  CurrCleanDist=1302.49  MinDist=2.00  Conflicts=4
# [IT  2500] T=0.4472  BestPenalized=2749.45  BestCleanDist=1305.10  CurrCleanDist=1305.10  MinDist=5.00  Conflicts=2
# [IT  2500] T=0.4472  BestPenalized=2168.73  BestCleanDist=1368.93  CurrCleanDist=1368.93  MinDist=6.00  Conflicts=0
# [IT  2500] T=0.4472  BestPenalized=2508.97  BestCleanDist=1472.37  CurrCleanDist=1472.37  MinDist=6.40  Conflicts=0
# [IT  3000] T=0.2091  BestPenalized=1889.17  BestCleanDist=1213.62  CurrCleanDist=1213.62  MinDist=6.00  Conflicts=0
# [IT  3000] T=0.2091  BestPenalized=1854.91  BestCleanDist=1279.86  CurrCleanDist=1279.86  MinDist=6.40  Conflicts=0
# [IT  3000] T=0.2091  BestPenalized=2272.17  BestCleanDist=1412.67  CurrCleanDist=1412.67  MinDist=7.81  Conflicts=0
# [IT  3000] T=0.2091  BestPenalized=2321.70  BestCleanDist=1334.25  CurrCleanDist=1334.25  MinDist=6.08  Conflicts=0
# [IT  3000] T=0.2091  BestPenalized=2037.32  BestCleanDist=1400.12  CurrCleanDist=1400.12  MinDist=6.71  Conflicts=0
# [IT  3000] T=0.2091  BestPenalized=2747.87  BestCleanDist=1306.52  CurrCleanDist=1306.52  MinDist=5.00  Conflicts=2
# [IT  3000] T=0.2091  BestPenalized=2168.73  BestCleanDist=1368.93  CurrCleanDist=1368.93  MinDist=6.00  Conflicts=0
# [IT  3500] T=0.0978  BestPenalized=1889.17  BestCleanDist=1213.62  CurrCleanDist=1213.62  MinDist=6.00  Conflicts=0
# [IT  3000] T=0.2091  BestPenalized=2507.56  BestCleanDist=1470.96  CurrCleanDist=1470.96  MinDist=6.40  Conflicts=0
# [IT  3500] T=0.0978  BestPenalized=1834.00  BestCleanDist=1277.45  CurrCleanDist=1277.45  MinDist=7.07  Conflicts=0
# [IT  3500] T=0.0978  BestPenalized=2270.17  BestCleanDist=1410.67  CurrCleanDist=1410.67  MinDist=6.71  Conflicts=0
# [IT  3500] T=0.0978  BestPenalized=2321.70  BestCleanDist=1334.25  CurrCleanDist=1334.25  MinDist=6.08  Conflicts=0
# [IT  3500] T=0.0978  BestPenalized=2725.20  BestCleanDist=1324.35  CurrCleanDist=1324.35  MinDist=5.00  Conflicts=2
# [IT  3500] T=0.0978  BestPenalized=2036.73  BestCleanDist=1399.53  CurrCleanDist=1399.53  MinDist=6.71  Conflicts=0
# [IT  3500] T=0.0978  BestPenalized=2129.71  BestCleanDist=1361.76  CurrCleanDist=1361.76  MinDist=6.00  Conflicts=0
# [IT  4000] T=0.0457  BestPenalized=1886.58  BestCleanDist=1211.03  CurrCleanDist=1211.03  MinDist=6.00  Conflicts=0
# [IT  3500] T=0.0978  BestPenalized=2506.97  BestCleanDist=1470.37  CurrCleanDist=1470.37  MinDist=6.40  Conflicts=0
# [IT  4000] T=0.0457  BestPenalized=1834.00  BestCleanDist=1277.45  CurrCleanDist=1277.45  MinDist=7.07  Conflicts=0
# [IT  4000] T=0.0457  BestPenalized=2265.93  BestCleanDist=1406.43  CurrCleanDist=1406.43  MinDist=6.71  Conflicts=0
# [IT  4000] T=0.0457  BestPenalized=2321.70  BestCleanDist=1334.25  CurrCleanDist=1334.25  MinDist=6.08  Conflicts=0
# [IT  4000] T=0.0457  BestPenalized=2722.37  BestCleanDist=1321.52  CurrCleanDist=1321.52  MinDist=5.00  Conflicts=2
# [IT  4000] T=0.0457  BestPenalized=2126.71  BestCleanDist=1361.76  CurrCleanDist=1361.76  MinDist=6.00  Conflicts=0
# [IT  4500] T=0.0214  BestPenalized=1885.76  BestCleanDist=1210.21  CurrCleanDist=1210.21  MinDist=6.00  Conflicts=0
# [IT  4000] T=0.0457  BestPenalized=2034.73  BestCleanDist=1397.53  CurrCleanDist=1397.53  MinDist=6.71  Conflicts=0
# [IT  4500] T=0.0214  BestPenalized=1816.70  BestCleanDist=1274.45  CurrCleanDist=1274.45  MinDist=7.28  Conflicts=0
# [IT  4500] T=0.0214  BestPenalized=2202.69  BestCleanDist=1398.19  CurrCleanDist=1398.19  MinDist=6.71  Conflicts=0
# [IT  4000] T=0.0457  BestPenalized=2500.16  BestCleanDist=1472.61  CurrCleanDist=1472.61  MinDist=6.40  Conflicts=0
# [IT  4500] T=0.0214  BestPenalized=2308.25  BestCleanDist=1336.25  CurrCleanDist=1336.25  MinDist=6.08  Conflicts=0
# [IT  4500] T=0.0214  BestPenalized=2720.95  BestCleanDist=1320.10  CurrCleanDist=1320.10  MinDist=5.00  Conflicts=2
# [IT  5000] T=0.0100  BestPenalized=1885.76  BestCleanDist=1210.21  CurrCleanDist=1210.21  MinDist=6.00  Conflicts=0
#
# ===== SA COMPLETADO =====
# Mejor fitness penalizado = 1885.755
# Mejor distancia real     = 1210.205
# Tiempo = 22.69 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [IT  4500] T=0.0214  BestPenalized=2126.71  BestCleanDist=1361.76  CurrCleanDist=1361.76  MinDist=6.00  Conflicts=0
# [IT     1] T=19.9696  BestPenalized=3297.08  BestCleanDist=1032.08  CurrCleanDist=1032.08  MinDist=0.00  Conflicts=15
# [IT  4500] T=0.0214  BestPenalized=1990.73  BestCleanDist=1390.53  CurrCleanDist=1390.53  MinDist=7.00  Conflicts=0
# [IT  5000] T=0.0100  BestPenalized=1797.30  BestCleanDist=1271.45  CurrCleanDist=1271.45  MinDist=8.06  Conflicts=0
#
# ===== SA COMPLETADO =====
# Mejor fitness penalizado = 1797.298
# Mejor distancia real     = 1271.448
# Tiempo = 23.54 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [IT  5000] T=0.0100  BestPenalized=2187.86  BestCleanDist=1383.36  CurrCleanDist=1383.36  MinDist=6.40  Conflicts=0
#
# ===== SA COMPLETADO =====
# Mejor fitness penalizado = 2187.860
# Mejor distancia real     = 1383.360
# Tiempo = 23.75 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [IT     1] T=19.9696  BestPenalized=3297.08  BestCleanDist=1032.08  CurrCleanDist=1032.08  MinDist=0.00  Conflicts=15
# [IT  5000] T=0.0100  BestPenalized=2285.88  BestCleanDist=1329.83  CurrCleanDist=1329.83  MinDist=6.08  Conflicts=0
#
# ===== SA COMPLETADO =====
# Mejor fitness penalizado = 2285.883
# Mejor distancia real     = 1329.833
# Tiempo = 23.97 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [IT     1] T=19.9696  BestPenalized=3297.08  BestCleanDist=1032.08  CurrCleanDist=1032.08  MinDist=0.00  Conflicts=15
# [IT  4500] T=0.0214  BestPenalized=2500.16  BestCleanDist=1472.61  CurrCleanDist=1472.61  MinDist=6.40  Conflicts=0
# [IT  5000] T=0.0100  BestPenalized=2718.95  BestCleanDist=1318.10  CurrCleanDist=1318.10  MinDist=5.00  Conflicts=2
#
# ===== SA COMPLETADO =====
# Mejor fitness penalizado = 2718.955
# Mejor distancia real     = 1318.105
# Tiempo = 24.23 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [IT     1] T=19.9696  BestPenalized=3297.08  BestCleanDist=1032.08  CurrCleanDist=1032.08  MinDist=0.00  Conflicts=15
# [IT     1] T=19.9696  BestPenalized=3297.08  BestCleanDist=1032.08  CurrCleanDist=1032.08  MinDist=0.00  Conflicts=15
# [IT  5000] T=0.0100  BestPenalized=2118.30  BestCleanDist=1356.35  CurrCleanDist=1356.35  MinDist=6.00  Conflicts=0
#
# ===== SA COMPLETADO =====
# Mejor fitness penalizado = 2118.297
# Mejor distancia real     = 1356.347
# Tiempo = 25.31 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [IT  5000] T=0.0100  BestPenalized=1989.32  BestCleanDist=1389.12  CurrCleanDist=1389.12  MinDist=7.00  Conflicts=0
#
# ===== SA COMPLETADO =====
# Mejor fitness penalizado = 1989.317
# Mejor distancia real     = 1389.117
# Tiempo = 25.35 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [IT   500] T=9.3525  BestPenalized=2310.12  BestCleanDist=1260.92  CurrCleanDist=1276.65  MinDist=3.61  Conflicts=3
# [IT     1] T=19.9696  BestPenalized=3297.08  BestCleanDist=1032.08  CurrCleanDist=1032.08  MinDist=0.00  Conflicts=15
# [IT     1] T=19.9696  BestPenalized=3297.08  BestCleanDist=1032.08  CurrCleanDist=1032.08  MinDist=0.00  Conflicts=15
# [IT   500] T=9.3525  BestPenalized=3035.01  BestCleanDist=1156.36  CurrCleanDist=1172.44  MinDist=3.16  Conflicts=6
# [IT   500] T=9.3525  BestPenalized=2567.26  BestCleanDist=1271.86  CurrCleanDist=1277.69  MinDist=2.83  Conflicts=5
# [IT   500] T=9.3525  BestPenalized=2187.69  BestCleanDist=1184.89  CurrCleanDist=1186.06  MinDist=3.61  Conflicts=3
# [IT   500] T=9.3525  BestPenalized=2298.50  BestCleanDist=1310.15  CurrCleanDist=1321.97  MinDist=5.00  Conflicts=2
# [IT  5000] T=0.0100  BestPenalized=2448.79  BestCleanDist=1464.79  CurrCleanDist=1464.79  MinDist=6.40  Conflicts=0
#
# ===== SA COMPLETADO =====
# Mejor fitness penalizado = 2448.786
# Mejor distancia real     = 1464.786
# Tiempo = 26.94 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [IT     1] T=19.9696  BestPenalized=3273.22  BestCleanDist=1053.67  CurrCleanDist=1053.67  MinDist=0.00  Conflicts=14
# [IT   500] T=9.3525  BestPenalized=2670.65  BestCleanDist=1168.95  CurrCleanDist=1247.55  MinDist=4.12  Conflicts=7
# [IT  1000] T=4.3734  BestPenalized=2770.96  BestCleanDist=1201.16  CurrCleanDist=1201.16  MinDist=3.61  Conflicts=3
# [IT   500] T=9.3525  BestPenalized=2417.84  BestCleanDist=1182.09  CurrCleanDist=1182.09  MinDist=5.00  Conflicts=2
# [IT  1000] T=4.3734  BestPenalized=2306.92  BestCleanDist=1285.82  CurrCleanDist=1285.82  MinDist=4.47  Conflicts=2
# [IT  1000] T=4.3734  BestPenalized=2131.78  BestCleanDist=1309.83  CurrCleanDist=1309.83  MinDist=5.83  Conflicts=1
# [IT  1000] T=4.3734  BestPenalized=2187.69  BestCleanDist=1184.89  CurrCleanDist=1190.31  MinDist=3.61  Conflicts=3
# [IT  1000] T=4.3734  BestPenalized=2298.50  BestCleanDist=1310.15  CurrCleanDist=1323.39  MinDist=5.00  Conflicts=2
# [IT   500] T=9.3525  BestPenalized=1979.74  BestCleanDist=1208.09  CurrCleanDist=1210.09  MinDist=5.00  Conflicts=2
# [IT  1500] T=2.0451  BestPenalized=2770.96  BestCleanDist=1201.16  CurrCleanDist=1204.58  MinDist=3.61  Conflicts=3
# [IT  1000] T=4.3734  BestPenalized=2437.92  BestCleanDist=1261.62  CurrCleanDist=1261.62  MinDist=3.61  Conflicts=3
# [IT  1000] T=4.3734  BestPenalized=2298.27  BestCleanDist=1207.82  CurrCleanDist=1217.96  MinDist=5.00  Conflicts=1
# [IT  1500] T=2.0451  BestPenalized=2305.33  BestCleanDist=1287.23  CurrCleanDist=1289.23  MinDist=4.47  Conflicts=2
# [IT  1500] T=2.0451  BestPenalized=2180.54  BestCleanDist=1214.79  CurrCleanDist=1214.79  MinDist=5.00  Conflicts=2
# [IT  1500] T=2.0451  BestPenalized=1970.76  BestCleanDist=1314.56  CurrCleanDist=1314.56  MinDist=6.40  Conflicts=0
# [IT  1500] T=2.0451  BestPenalized=2294.85  BestCleanDist=1320.80  CurrCleanDist=1324.22  MinDist=4.47  Conflicts=2
# [IT  1000] T=4.3734  BestPenalized=1979.74  BestCleanDist=1208.09  CurrCleanDist=1211.51  MinDist=5.00  Conflicts=2
# [IT  2000] T=0.9564  BestPenalized=2770.96  BestCleanDist=1201.16  CurrCleanDist=1205.99  MinDist=3.61  Conflicts=3
# [IT  1500] T=2.0451  BestPenalized=2437.09  BestCleanDist=1260.79  CurrCleanDist=1262.79  MinDist=3.61  Conflicts=3
# [IT  1500] T=2.0451  BestPenalized=2298.27  BestCleanDist=1207.82  CurrCleanDist=1216.13  MinDist=5.00  Conflicts=1
# [IT  2000] T=0.9564  BestPenalized=2180.54  BestCleanDist=1214.79  CurrCleanDist=1214.79  MinDist=5.00  Conflicts=2
# [IT  2000] T=0.9564  BestPenalized=1970.76  BestCleanDist=1314.56  CurrCleanDist=1314.56  MinDist=6.40  Conflicts=0
# [IT  2000] T=0.9564  BestPenalized=2305.33  BestCleanDist=1287.23  CurrCleanDist=1290.65  MinDist=4.47  Conflicts=2
# [IT  2000] T=0.9564  BestPenalized=2294.85  BestCleanDist=1320.80  CurrCleanDist=1322.80  MinDist=4.47  Conflicts=2
# [IT  1500] T=2.0451  BestPenalized=1979.74  BestCleanDist=1208.09  CurrCleanDist=1216.92  MinDist=5.00  Conflicts=2
# [IT  2500] T=0.4472  BestPenalized=2747.76  BestCleanDist=1193.16  CurrCleanDist=1193.16  MinDist=2.83  Conflicts=3
# [IT  2000] T=0.9564  BestPenalized=2394.51  BestCleanDist=1262.21  CurrCleanDist=1262.21  MinDist=3.61  Conflicts=3
# [IT  2000] T=0.9564  BestPenalized=2298.27  BestCleanDist=1207.82  CurrCleanDist=1216.13  MinDist=5.00  Conflicts=1
# [IT  2500] T=0.4472  BestPenalized=2179.13  BestCleanDist=1213.38  CurrCleanDist=1214.79  MinDist=5.00  Conflicts=2
# [IT  2500] T=0.4472  BestPenalized=1925.85  BestCleanDist=1308.80  CurrCleanDist=1308.80  MinDist=6.00  Conflicts=0
# [IT  2500] T=0.4472  BestPenalized=2305.33  BestCleanDist=1287.23  CurrCleanDist=1290.65  MinDist=4.47  Conflicts=2
# [IT  2500] T=0.4472  BestPenalized=2294.85  BestCleanDist=1320.80  CurrCleanDist=1321.39  MinDist=4.47  Conflicts=2
# [IT  2000] T=0.9564  BestPenalized=1979.74  BestCleanDist=1208.09  CurrCleanDist=1216.92  MinDist=5.00  Conflicts=2
# [IT  3000] T=0.2091  BestPenalized=2738.97  BestCleanDist=1185.92  CurrCleanDist=1185.92  MinDist=2.83  Conflicts=3
# [IT  2500] T=0.4472  BestPenalized=2394.51  BestCleanDist=1262.21  CurrCleanDist=1262.21  MinDist=3.61  Conflicts=3
# [IT  2500] T=0.4472  BestPenalized=2295.98  BestCleanDist=1212.48  CurrCleanDist=1212.48  MinDist=5.00  Conflicts=1
# [IT  3000] T=0.2091  BestPenalized=2179.13  BestCleanDist=1213.38  CurrCleanDist=1214.79  MinDist=5.00  Conflicts=2
# [IT  3000] T=0.2091  BestPenalized=1801.50  BestCleanDist=1299.80  CurrCleanDist=1299.80  MinDist=6.40  Conflicts=0
# [IT  3000] T=0.2091  BestPenalized=2294.85  BestCleanDist=1320.80  CurrCleanDist=1321.39  MinDist=4.47  Conflicts=2
# [IT  3000] T=0.2091  BestPenalized=2305.33  BestCleanDist=1287.23  CurrCleanDist=1290.65  MinDist=4.47  Conflicts=2
# [IT  2500] T=0.4472  BestPenalized=1979.74  BestCleanDist=1208.09  CurrCleanDist=1217.34  MinDist=5.00  Conflicts=2
# [IT  3500] T=0.0978  BestPenalized=2738.14  BestCleanDist=1185.09  CurrCleanDist=1185.09  MinDist=2.83  Conflicts=3
# [IT  3000] T=0.2091  BestPenalized=2295.98  BestCleanDist=1212.48  CurrCleanDist=1212.48  MinDist=5.00  Conflicts=1
# [IT  3000] T=0.2091  BestPenalized=2394.51  BestCleanDist=1262.21  CurrCleanDist=1262.21  MinDist=3.61  Conflicts=3
# [IT  3500] T=0.0978  BestPenalized=2179.13  BestCleanDist=1213.38  CurrCleanDist=1214.21  MinDist=5.00  Conflicts=2
# [IT  3500] T=0.0978  BestPenalized=1793.45  BestCleanDist=1297.80  CurrCleanDist=1297.80  MinDist=6.40  Conflicts=0
# [IT  3500] T=0.0978  BestPenalized=2158.85  BestCleanDist=1348.80  CurrCleanDist=1348.80  MinDist=6.00  Conflicts=0
# [IT  4000] T=0.0457  BestPenalized=2738.14  BestCleanDist=1185.09  CurrCleanDist=1185.09  MinDist=2.83  Conflicts=3
# [IT  3000] T=0.2091  BestPenalized=1880.46  BestCleanDist=1221.51  CurrCleanDist=1221.51  MinDist=5.39  Conflicts=1
# [IT  3500] T=0.0978  BestPenalized=2289.28  BestCleanDist=1207.48  CurrCleanDist=1207.48  MinDist=5.00  Conflicts=1
# [IT  3500] T=0.0978  BestPenalized=2082.83  BestCleanDist=1350.03  CurrCleanDist=1350.03  MinDist=6.00  Conflicts=0
# [IT  3500] T=0.0978  BestPenalized=2268.08  BestCleanDist=1268.03  CurrCleanDist=1268.03  MinDist=5.00  Conflicts=2
# [IT  4000] T=0.0457  BestPenalized=2179.13  BestCleanDist=1213.38  CurrCleanDist=1214.21  MinDist=5.00  Conflicts=2
# [IT  4000] T=0.0457  BestPenalized=1790.04  BestCleanDist=1294.39  CurrCleanDist=1294.39  MinDist=6.32  Conflicts=0
# [IT  4000] T=0.0457  BestPenalized=2118.85  BestCleanDist=1345.80  CurrCleanDist=1345.80  MinDist=6.00  Conflicts=0
# [IT  4500] T=0.0214  BestPenalized=2738.14  BestCleanDist=1185.09  CurrCleanDist=1185.09  MinDist=2.83  Conflicts=3
# [IT  3500] T=0.0978  BestPenalized=1880.46  BestCleanDist=1221.51  CurrCleanDist=1221.51  MinDist=5.39  Conflicts=1
# [IT  4000] T=0.0457  BestPenalized=2289.28  BestCleanDist=1207.48  CurrCleanDist=1207.48  MinDist=5.00  Conflicts=1
# [IT  4000] T=0.0457  BestPenalized=2268.08  BestCleanDist=1268.03  CurrCleanDist=1268.03  MinDist=5.00  Conflicts=2
# [IT  4000] T=0.0457  BestPenalized=2082.25  BestCleanDist=1349.45  CurrCleanDist=1349.45  MinDist=7.00  Conflicts=0
# [IT  4500] T=0.0214  BestPenalized=2172.13  BestCleanDist=1209.38  CurrCleanDist=1209.38  MinDist=5.00  Conflicts=2
# [IT  4500] T=0.0214  BestPenalized=1780.34  BestCleanDist=1289.39  CurrCleanDist=1289.39  MinDist=6.32  Conflicts=0
# [IT  4500] T=0.0214  BestPenalized=2118.85  BestCleanDist=1345.80  CurrCleanDist=1345.80  MinDist=6.00  Conflicts=0
# [IT  5000] T=0.0100  BestPenalized=2731.73  BestCleanDist=1181.68  CurrCleanDist=1181.68  MinDist=2.83  Conflicts=3
#
# ===== SA COMPLETADO =====
# Mejor fitness penalizado = 2731.728
# Mejor distancia real     = 1181.678
# Tiempo = 22.21 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [IT  4000] T=0.0457  BestPenalized=1880.46  BestCleanDist=1221.51  CurrCleanDist=1221.51  MinDist=5.39  Conflicts=1
# [IT     1] T=19.9696  BestPenalized=3297.08  BestCleanDist=1032.08  CurrCleanDist=1032.08  MinDist=0.00  Conflicts=15
# [IT  4500] T=0.0214  BestPenalized=2287.28  BestCleanDist=1205.48  CurrCleanDist=1205.48  MinDist=5.00  Conflicts=1
# [IT  4500] T=0.0214  BestPenalized=2268.08  BestCleanDist=1268.03  CurrCleanDist=1268.03  MinDist=5.00  Conflicts=2
# [IT  5000] T=0.0100  BestPenalized=2108.30  BestCleanDist=1215.55  CurrCleanDist=1215.55  MinDist=5.00  Conflicts=2
#
# ===== SA COMPLETADO =====
# Mejor fitness penalizado = 2108.298
# Mejor distancia real     = 1215.548
# Tiempo = 22.90 s
# [IT  4500] T=0.0214  BestPenalized=2080.83  BestCleanDist=1348.03  CurrCleanDist=1348.03  MinDist=7.62  Conflicts=0
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [IT     1] T=19.9696  BestPenalized=3297.08  BestCleanDist=1032.08  CurrCleanDist=1032.08  MinDist=0.00  Conflicts=15
# [IT  5000] T=0.0100  BestPenalized=1780.34  BestCleanDist=1289.39  CurrCleanDist=1289.39  MinDist=6.32  Conflicts=0
#
# ===== SA COMPLETADO =====
# Mejor fitness penalizado = 1780.339
# Mejor distancia real     = 1289.389
# Tiempo = 23.67 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [IT     1] T=19.9696  BestPenalized=3296.44  BestCleanDist=1078.39  CurrCleanDist=1078.39  MinDist=0.00  Conflicts=14
# [IT  5000] T=0.0100  BestPenalized=2068.94  BestCleanDist=1339.39  CurrCleanDist=1339.39  MinDist=6.71  Conflicts=0
#
# ===== SA COMPLETADO =====
# Mejor fitness penalizado = 2068.939
# Mejor distancia real     = 1339.389
# Tiempo = 23.63 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [IT   500] T=9.3525  BestPenalized=1680.26  BestCleanDist=1198.26  CurrCleanDist=1198.26  MinDist=6.08  Conflicts=0
# [IT  4500] T=0.0214  BestPenalized=1871.59  BestCleanDist=1221.34  CurrCleanDist=1221.34  MinDist=5.39  Conflicts=1
# [IT  5000] T=0.0100  BestPenalized=2287.28  BestCleanDist=1205.48  CurrCleanDist=1205.48  MinDist=5.00  Conflicts=1
#
# ===== SA COMPLETADO =====
# Mejor fitness penalizado = 2287.277
# Mejor distancia real     = 1205.477
# Tiempo = 22.85 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [IT     1] T=19.9696  BestPenalized=3297.08  BestCleanDist=1032.08  CurrCleanDist=1032.08  MinDist=0.00  Conflicts=15
# [IT     1] T=19.9696  BestPenalized=3297.08  BestCleanDist=1032.08  CurrCleanDist=1032.08  MinDist=0.00  Conflicts=15
# [IT  5000] T=0.0100  BestPenalized=2180.12  BestCleanDist=1271.52  CurrCleanDist=1271.52  MinDist=5.00  Conflicts=2
#
# ===== SA COMPLETADO =====
# Mejor fitness penalizado = 2180.119
# Mejor distancia real     = 1271.519
# Tiempo = 23.43 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [IT     1] T=19.9696  BestPenalized=3297.08  BestCleanDist=1032.08  CurrCleanDist=1032.08  MinDist=0.00  Conflicts=15
# [IT   500] T=9.3525  BestPenalized=2583.68  BestCleanDist=1214.13  CurrCleanDist=1224.79  MinDist=3.16  Conflicts=5
# [IT  5000] T=0.0100  BestPenalized=2076.01  BestCleanDist=1343.21  CurrCleanDist=1343.21  MinDist=7.62  Conflicts=0
#
# ===== SA COMPLETADO =====
# Mejor fitness penalizado = 2076.005
# Mejor distancia real     = 1343.205
# Tiempo = 26.75 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [IT     1] T=19.9696  BestPenalized=3297.08  BestCleanDist=1032.08  CurrCleanDist=1032.08  MinDist=0.00  Conflicts=15
# [IT   500] T=9.3525  BestPenalized=2793.78  BestCleanDist=1172.78  CurrCleanDist=1174.19  MinDist=2.00  Conflicts=4
# [IT  1000] T=4.3734  BestPenalized=1680.26  BestCleanDist=1198.26  CurrCleanDist=1198.26  MinDist=6.08  Conflicts=0
# [IT  5000] T=0.0100  BestPenalized=1871.00  BestCleanDist=1220.75  CurrCleanDist=1220.75  MinDist=5.39  Conflicts=1
#
# ===== SA COMPLETADO =====
# Mejor fitness penalizado = 1870.999
# Mejor distancia real     = 1220.749
# Tiempo = 23.31 s
# [IT   500] T=9.3525  BestPenalized=2935.47  BestCleanDist=1106.22  CurrCleanDist=1128.88  MinDist=2.00  Conflicts=9
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [IT   500] T=9.3525  BestPenalized=2985.24  BestCleanDist=1143.19  CurrCleanDist=1163.09  MinDist=1.41  Conflicts=10
# [IT     1] T=19.9696  BestPenalized=2923.24  BestCleanDist=1058.49  CurrCleanDist=1058.49  MinDist=0.00  Conflicts=10
# [IT   500] T=9.3525  BestPenalized=3189.73  BestCleanDist=1095.98  CurrCleanDist=1115.05  MinDist=2.83  Conflicts=10
# [IT  1000] T=4.3734  BestPenalized=2362.74  BestCleanDist=1302.49  CurrCleanDist=1303.90  MinDist=5.83  Conflicts=1
# [IT  1000] T=4.3734  BestPenalized=2793.78  BestCleanDist=1172.78  CurrCleanDist=1182.19  MinDist=2.00  Conflicts=4
# [IT   500] T=9.3525  BestPenalized=2455.37  BestCleanDist=1195.02  CurrCleanDist=1195.61  MinDist=4.12  Conflicts=4
# [IT  1500] T=2.0451  BestPenalized=1680.26  BestCleanDist=1198.26  CurrCleanDist=1198.26  MinDist=6.08  Conflicts=0
# [IT  1000] T=4.3734  BestPenalized=2197.98  BestCleanDist=1198.48  CurrCleanDist=1198.48  MinDist=4.47  Conflicts=3
# [IT   500] T=9.3525  BestPenalized=2244.11  BestCleanDist=1146.61  CurrCleanDist=1147.19  MinDist=5.00  Conflicts=2
# [IT  1000] T=4.3734  BestPenalized=1712.38  BestCleanDist=1318.08  CurrCleanDist=1318.08  MinDist=6.71  Conflicts=0
# [IT  1000] T=4.3734  BestPenalized=2816.20  BestCleanDist=1278.00  CurrCleanDist=1280.00  MinDist=5.00  Conflicts=5
# [IT  1500] T=2.0451  BestPenalized=2362.74  BestCleanDist=1302.49  CurrCleanDist=1332.53  MinDist=5.83  Conflicts=1
# [IT  1500] T=2.0451  BestPenalized=2787.41  BestCleanDist=1179.61  CurrCleanDist=1182.44  MinDist=2.00  Conflicts=4
# [IT  1000] T=4.3734  BestPenalized=1964.99  BestCleanDist=1271.34  CurrCleanDist=1271.34  MinDist=6.71  Conflicts=0
# [IT  2000] T=0.9564  BestPenalized=1680.26  BestCleanDist=1198.26  CurrCleanDist=1198.26  MinDist=6.08  Conflicts=0
# [IT  1500] T=2.0451  BestPenalized=2066.75  BestCleanDist=1208.55  CurrCleanDist=1208.55  MinDist=4.47  Conflicts=2
# [IT  1000] T=4.3734  BestPenalized=2244.11  BestCleanDist=1146.61  CurrCleanDist=1180.23  MinDist=5.00  Conflicts=2
# [IT  1500] T=2.0451  BestPenalized=1710.38  BestCleanDist=1316.08  CurrCleanDist=1316.08  MinDist=6.40  Conflicts=0
# [IT  1500] T=2.0451  BestPenalized=2753.73  BestCleanDist=1327.73  CurrCleanDist=1328.32  MinDist=5.00  Conflicts=4
# [IT  2000] T=0.9564  BestPenalized=2362.74  BestCleanDist=1302.49  CurrCleanDist=1333.12  MinDist=5.83  Conflicts=1
# [IT  2000] T=0.9564  BestPenalized=2787.41  BestCleanDist=1179.61  CurrCleanDist=1183.02  MinDist=2.00  Conflicts=4
# [IT  1500] T=2.0451  BestPenalized=1954.21  BestCleanDist=1267.51  CurrCleanDist=1267.51  MinDist=6.71  Conflicts=0
# [IT  2500] T=0.4472  BestPenalized=1680.26  BestCleanDist=1198.26  CurrCleanDist=1198.26  MinDist=6.08  Conflicts=0
# [IT  2000] T=0.9564  BestPenalized=2038.58  BestCleanDist=1206.13  CurrCleanDist=1207.55  MinDist=4.47  Conflicts=2
# [IT  1500] T=2.0451  BestPenalized=2244.11  BestCleanDist=1146.61  CurrCleanDist=1180.23  MinDist=5.00  Conflicts=2
# [IT  2000] T=0.9564  BestPenalized=1701.96  BestCleanDist=1310.66  CurrCleanDist=1310.66  MinDist=6.40  Conflicts=0
# [IT  2000] T=0.9564  BestPenalized=2738.08  BestCleanDist=1318.08  CurrCleanDist=1318.08  MinDist=5.00  Conflicts=4
# [IT  2500] T=0.4472  BestPenalized=2781.87  BestCleanDist=1180.02  CurrCleanDist=1180.02  MinDist=2.00  Conflicts=4
# [IT  2500] T=0.4472  BestPenalized=2353.92  BestCleanDist=1336.87  CurrCleanDist=1336.87  MinDist=5.83  Conflicts=1
# [IT  3000] T=0.2091  BestPenalized=1670.96  BestCleanDist=1197.26  CurrCleanDist=1197.26  MinDist=6.08  Conflicts=0
# [IT  2000] T=0.9564  BestPenalized=1953.04  BestCleanDist=1266.34  CurrCleanDist=1266.34  MinDist=6.71  Conflicts=0
# [IT  2000] T=0.9564  BestPenalized=2238.78  BestCleanDist=1176.23  CurrCleanDist=1176.23  MinDist=5.00  Conflicts=2
# [IT  2500] T=0.4472  BestPenalized=2038.58  BestCleanDist=1206.13  CurrCleanDist=1207.55  MinDist=4.47  Conflicts=2
# [IT  2500] T=0.4472  BestPenalized=1697.25  BestCleanDist=1306.25  CurrCleanDist=1306.25  MinDist=6.32  Conflicts=0
# [IT  2500] T=0.4472  BestPenalized=2715.00  BestCleanDist=1312.25  CurrCleanDist=1312.25  MinDist=5.00  Conflicts=4
# [IT  3000] T=0.2091  BestPenalized=2781.87  BestCleanDist=1180.02  CurrCleanDist=1180.02  MinDist=2.00  Conflicts=4
# [IT  3500] T=0.0978  BestPenalized=1668.14  BestCleanDist=1194.44  CurrCleanDist=1194.44  MinDist=6.08  Conflicts=0
# [IT  3000] T=0.2091  BestPenalized=2353.92  BestCleanDist=1336.87  CurrCleanDist=1336.87  MinDist=5.83  Conflicts=1
# [IT  3000] T=0.2091  BestPenalized=2038.58  BestCleanDist=1206.13  CurrCleanDist=1207.55  MinDist=4.47  Conflicts=2
# [IT  2500] T=0.4472  BestPenalized=2238.78  BestCleanDist=1176.23  CurrCleanDist=1176.23  MinDist=5.00  Conflicts=2
# [IT  2500] T=0.4472  BestPenalized=1921.74  BestCleanDist=1265.34  CurrCleanDist=1265.34  MinDist=6.71  Conflicts=0
# [IT  3000] T=0.2091  BestPenalized=1697.25  BestCleanDist=1306.25  CurrCleanDist=1306.25  MinDist=6.32  Conflicts=0
# [IT  3500] T=0.0978  BestPenalized=2781.87  BestCleanDist=1180.02  CurrCleanDist=1180.02  MinDist=2.00  Conflicts=4
# [IT  3000] T=0.2091  BestPenalized=2244.03  BestCleanDist=1331.73  CurrCleanDist=1331.73  MinDist=6.40  Conflicts=0
# [IT  3000] T=0.2091  BestPenalized=2232.37  BestCleanDist=1172.82  CurrCleanDist=1172.82  MinDist=5.00  Conflicts=2
# [IT  4000] T=0.0457  BestPenalized=1668.14  BestCleanDist=1194.44  CurrCleanDist=1194.44  MinDist=6.08  Conflicts=0
# [IT  3500] T=0.0978  BestPenalized=2007.64  BestCleanDist=1200.89  CurrCleanDist=1200.89  MinDist=4.47  Conflicts=2
# [IT  3500] T=0.0978  BestPenalized=2324.37  BestCleanDist=1341.87  CurrCleanDist=1341.87  MinDist=5.39  Conflicts=1
# [IT  3000] T=0.2091  BestPenalized=1921.74  BestCleanDist=1265.34  CurrCleanDist=1265.34  MinDist=6.71  Conflicts=0
# [IT  3500] T=0.0978  BestPenalized=1692.25  BestCleanDist=1304.25  CurrCleanDist=1304.25  MinDist=6.32  Conflicts=0
# [IT  4000] T=0.0457  BestPenalized=2781.87  BestCleanDist=1180.02  CurrCleanDist=1180.02  MinDist=2.00  Conflicts=4
# [IT  3500] T=0.0978  BestPenalized=2190.23  BestCleanDist=1321.73  CurrCleanDist=1321.73  MinDist=6.32  Conflicts=0
# [IT  4500] T=0.0214  BestPenalized=1668.14  BestCleanDist=1194.44  CurrCleanDist=1194.44  MinDist=6.08  Conflicts=0
# [IT  3500] T=0.0978  BestPenalized=2231.54  BestCleanDist=1171.99  CurrCleanDist=1171.99  MinDist=5.00  Conflicts=2
# [IT  4000] T=0.0457  BestPenalized=2003.23  BestCleanDist=1199.48  CurrCleanDist=1199.48  MinDist=4.47  Conflicts=2
# [IT  4000] T=0.0457  BestPenalized=2312.89  BestCleanDist=1333.39  CurrCleanDist=1333.39  MinDist=5.39  Conflicts=1
# [IT  3500] T=0.0978  BestPenalized=1919.74  BestCleanDist=1263.34  CurrCleanDist=1263.34  MinDist=6.71  Conflicts=0
# [IT  4000] T=0.0457  BestPenalized=1690.83  BestCleanDist=1302.83  CurrCleanDist=1302.83  MinDist=6.32  Conflicts=0
# [IT  4500] T=0.0214  BestPenalized=2779.87  BestCleanDist=1178.02  CurrCleanDist=1178.02  MinDist=2.00  Conflicts=4
# [IT  4000] T=0.0457  BestPenalized=2231.54  BestCleanDist=1171.99  CurrCleanDist=1171.99  MinDist=5.00  Conflicts=2
# [IT  4000] T=0.0457  BestPenalized=2151.07  BestCleanDist=1308.32  CurrCleanDist=1308.32  MinDist=6.00  Conflicts=0
# [IT  5000] T=0.0100  BestPenalized=1668.14  BestCleanDist=1194.44  CurrCleanDist=1194.44  MinDist=6.08  Conflicts=0
#
# ===== SA COMPLETADO =====
# Mejor fitness penalizado = 1668.136
# Mejor distancia real     = 1194.436
# Tiempo = 22.39 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [IT  4500] T=0.0214  BestPenalized=1995.68  BestCleanDist=1225.03  CurrCleanDist=1225.03  MinDist=5.83  Conflicts=1
# [IT     1] T=19.9696  BestPenalized=3222.70  BestCleanDist=1074.15  CurrCleanDist=1074.15  MinDist=1.41  Conflicts=13
# [IT  4500] T=0.0214  BestPenalized=2312.89  BestCleanDist=1333.39  CurrCleanDist=1333.39  MinDist=5.39  Conflicts=1
# [IT  4000] T=0.0457  BestPenalized=1917.74  BestCleanDist=1261.34  CurrCleanDist=1261.34  MinDist=7.00  Conflicts=0
# [IT  4500] T=0.0214  BestPenalized=1690.83  BestCleanDist=1302.83  CurrCleanDist=1302.83  MinDist=6.32  Conflicts=0
# [IT  5000] T=0.0100  BestPenalized=2779.87  BestCleanDist=1178.02  CurrCleanDist=1178.02  MinDist=2.00  Conflicts=4
#
# ===== SA COMPLETADO =====
# Mejor fitness penalizado = 2779.871
# Mejor distancia real     = 1178.021
# Tiempo = 22.46 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [IT  4500] T=0.0214  BestPenalized=2151.07  BestCleanDist=1308.32  CurrCleanDist=1308.32  MinDist=6.00  Conflicts=0
# [IT  4500] T=0.0214  BestPenalized=2231.54  BestCleanDist=1171.99  CurrCleanDist=1171.99  MinDist=5.00  Conflicts=2
# [IT     1] T=19.9696  BestPenalized=3297.08  BestCleanDist=1032.08  CurrCleanDist=1032.08  MinDist=0.00  Conflicts=15
# [IT   500] T=9.3525  BestPenalized=2495.28  BestCleanDist=1261.13  CurrCleanDist=1272.21  MinDist=6.08  Conflicts=0
# [IT  5000] T=0.0100  BestPenalized=1995.68  BestCleanDist=1225.03  CurrCleanDist=1225.03  MinDist=5.83  Conflicts=1
#
# ===== SA COMPLETADO =====
# Mejor fitness penalizado = 1995.684
# Mejor distancia real     = 1225.034
# Tiempo = 22.64 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [IT  5000] T=0.0100  BestPenalized=2312.89  BestCleanDist=1333.39  CurrCleanDist=1333.39  MinDist=5.39  Conflicts=1
#
# ===== SA COMPLETADO =====
# Mejor fitness penalizado = 2312.889
# Mejor distancia real     = 1333.389
# Tiempo = 23.92 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255][IT  4500] T=0.0214  BestPenalized=1917.15  BestCleanDist=1260.75  CurrCleanDist=1260.75  MinDist=7.00  Conflicts=0
#
# [INFO] Environment cargado: 92 x 113
# [IT     1] T=19.9696  BestPenalized=3297.08  BestCleanDist=1032.08  CurrCleanDist=1032.08  MinDist=0.00  Conflicts=15
# [IT     1] T=19.9696  BestPenalized=3297.08  BestCleanDist=1032.08  CurrCleanDist=1032.08  MinDist=0.00  Conflicts=15
# [IT  5000] T=0.0100  BestPenalized=1690.83  BestCleanDist=1302.83  CurrCleanDist=1302.83  MinDist=6.32  Conflicts=0
#
# ===== SA COMPLETADO =====
# Mejor fitness penalizado = 1690.833
# Mejor distancia real     = 1302.833
# Tiempo = 23.14 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [IT     1] T=19.9696  BestPenalized=3297.08  BestCleanDist=1032.08  CurrCleanDist=1032.08  MinDist=0.00  Conflicts=15
# [IT  5000] T=0.0100  BestPenalized=2140.94  BestCleanDist=1300.49  CurrCleanDist=1300.49  MinDist=6.00  Conflicts=0
#
# ===== SA COMPLETADO =====
# Mejor fitness penalizado = 2140.939
# Mejor distancia real     = 1300.489
# Tiempo = 23.49 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [IT  5000] T=0.0100  BestPenalized=2110.83  BestCleanDist=1278.03  CurrCleanDist=1278.03  MinDist=7.07  Conflicts=0
#
# ===== SA COMPLETADO =====
# Mejor fitness penalizado = 2110.834
# Mejor distancia real     = 1278.034
# Tiempo = 21.97 s
# [INFO] Valores únicos del BMP original: [  0 255]
# [INFO] Valores únicos tras invertir: [  0 255]
# [INFO] Environment cargado: 92 x 113
# [IT   500] T=9.3525  BestPenalized=2079.83  BestCleanDist=1124.98  CurrCleanDist=1239.92  MinDist=5.00  Conflicts=2
# [IT     1] T=19.9696  BestPenalized=3297.08  BestCleanDist=1032.08  CurrCleanDist=1032.08  MinDist=0.00  Conflicts=15
# [IT     1] T=19.9696  BestPenalized=3297.08  BestCleanDist=1032.08  CurrCleanDist=1032.08  MinDist=0.00  Conflicts=15
# [IT  1000] T=4.3734  BestPenalized=2495.28  BestCleanDist=1261.13  CurrCleanDist=1271.55  MinDist=6.08  Conflicts=0
# [IT   500] T=9.3525  BestPenalized=2659.55  BestCleanDist=1121.05  CurrCleanDist=1143.05  MinDist=4.12  Conflicts=3
# [IT  5000] T=0.0100  BestPenalized=1917.15  BestCleanDist=1260.75  CurrCleanDist=1260.75  MinDist=7.00  Conflicts=0
#
# ===== SA COMPLETADO =====
# Mejor fitness penalizado = 1917.149
# Mejor distancia real     = 1260.749
# Tiempo = 23.72 s
# [IT   500] T=9.3525  BestPenalized=2361.90  BestCleanDist=1165.95  CurrCleanDist=1170.19  MinDist=5.00  Conflicts=3
# [IT   500] T=9.3525  BestPenalized=2066.75  BestCleanDist=1445.80  CurrCleanDist=1445.80  MinDist=7.00  Conflicts=0
# [IT  1000] T=4.3734  BestPenalized=2079.83  BestCleanDist=1124.98  CurrCleanDist=1239.92  MinDist=5.00  Conflicts=2
# [IT   500] T=9.3525  BestPenalized=2807.20  BestCleanDist=1186.10  CurrCleanDist=1193.10  MinDist=2.00  Conflicts=10
# [IT  1000] T=4.3734  BestPenalized=2659.55  BestCleanDist=1121.05  CurrCleanDist=1144.64  MinDist=4.12  Conflicts=3
# [IT   500] T=9.3525  BestPenalized=2201.59  BestCleanDist=1386.49  CurrCleanDist=1386.49  MinDist=5.83  Conflicts=1
# [IT  1500] T=2.0451  BestPenalized=2495.28  BestCleanDist=1261.13  CurrCleanDist=1270.72  MinDist=6.08  Conflicts=0
# [IT  1000] T=4.3734  BestPenalized=2198.01  BestCleanDist=1166.36  CurrCleanDist=1176.02  MinDist=5.00  Conflicts=2
# [IT  1000] T=4.3734  BestPenalized=2066.75  BestCleanDist=1445.80  CurrCleanDist=1445.80  MinDist=7.00  Conflicts=0
# [IT  1500] T=2.0451  BestPenalized=2079.83  BestCleanDist=1124.98  CurrCleanDist=1236.92  MinDist=5.00  Conflicts=2
# [IT  1000] T=4.3734  BestPenalized=2807.20  BestCleanDist=1186.10  CurrCleanDist=1195.52  MinDist=2.00  Conflicts=10
# [IT  1500] T=2.0451  BestPenalized=2659.55  BestCleanDist=1121.05  CurrCleanDist=1146.05  MinDist=4.12  Conflicts=3
# [IT  2000] T=0.9564  BestPenalized=2495.28  BestCleanDist=1261.13  CurrCleanDist=1270.13  MinDist=6.08  Conflicts=0[IT  1000] T=4.3734  BestPenalized=2201.59  BestCleanDist=1386.49  CurrCleanDist=1406.12  MinDist=5.83  Conflicts=1
#
# [IT  1500] T=2.0451  BestPenalized=2198.01  BestCleanDist=1166.36  CurrCleanDist=1178.02  MinDist=5.00  Conflicts=2
# [IT  1500] T=2.0451  BestPenalized=2063.92  BestCleanDist=1442.97  CurrCleanDist=1442.97  MinDist=6.00  Conflicts=0
# [IT  2000] T=0.9564  BestPenalized=2079.83  BestCleanDist=1124.98  CurrCleanDist=1236.92  MinDist=5.00  Conflicts=2
# [IT  1500] T=2.0451  BestPenalized=2153.94  BestCleanDist=1252.49  CurrCleanDist=1252.49  MinDist=2.00  Conflicts=5
# [IT  2000] T=0.9564  BestPenalized=2659.55  BestCleanDist=1121.05  CurrCleanDist=1146.88  MinDist=4.12  Conflicts=3
# [IT  2500] T=0.4472  BestPenalized=2495.28  BestCleanDist=1261.13  CurrCleanDist=1267.13  MinDist=6.08  Conflicts=0
# [IT  1500] T=2.0451  BestPenalized=2175.65  BestCleanDist=1409.95  CurrCleanDist=1409.95  MinDist=5.83  Conflicts=1
# [IT  2000] T=0.9564  BestPenalized=2198.01  BestCleanDist=1166.36  CurrCleanDist=1174.19  MinDist=5.00  Conflicts=2
# [IT  2500] T=0.4472  BestPenalized=2659.55  BestCleanDist=1121.05  CurrCleanDist=1141.29  MinDist=4.12  Conflicts=3
# [IT  2000] T=0.9564  BestPenalized=2153.94  BestCleanDist=1252.49  CurrCleanDist=1254.49  MinDist=2.00  Conflicts=5
# [IT  2500] T=0.4472  BestPenalized=2079.83  BestCleanDist=1124.98  CurrCleanDist=1236.92  MinDist=5.00  Conflicts=2
# [IT  2000] T=0.9564  BestPenalized=2035.97  BestCleanDist=1439.97  CurrCleanDist=1439.97  MinDist=6.00  Conflicts=0
# [IT  3000] T=0.2091  BestPenalized=2495.28  BestCleanDist=1261.13  CurrCleanDist=1267.13  MinDist=6.08  Conflicts=0
# [IT  2500] T=0.4472  BestPenalized=2198.01  BestCleanDist=1166.36  CurrCleanDist=1174.19  MinDist=5.00  Conflicts=2
# [IT  2000] T=0.9564  BestPenalized=2175.65  BestCleanDist=1409.95  CurrCleanDist=1410.53  MinDist=5.83  Conflicts=1
# [IT  3000] T=0.2091  BestPenalized=2455.74  BestCleanDist=1204.34  CurrCleanDist=1204.34  MinDist=6.08  Conflicts=0
# [IT  2500] T=0.4472  BestPenalized=2025.49  BestCleanDist=1265.49  CurrCleanDist=1265.49  MinDist=2.83  Conflicts=4
# [IT  3000] T=0.2091  BestPenalized=2079.83  BestCleanDist=1124.98  CurrCleanDist=1236.34  MinDist=5.00  Conflicts=2
# [IT  3500] T=0.0978  BestPenalized=2489.12  BestCleanDist=1264.72  CurrCleanDist=1264.72  MinDist=6.08  Conflicts=0
# [IT  3000] T=0.2091  BestPenalized=2198.01  BestCleanDist=1166.36  CurrCleanDist=1171.36  MinDist=5.00  Conflicts=2
# [IT  2500] T=0.4472  BestPenalized=2006.18  BestCleanDist=1430.73  CurrCleanDist=1430.73  MinDist=7.00  Conflicts=0
# [IT  2500] T=0.4472  BestPenalized=2149.83  BestCleanDist=1410.53  CurrCleanDist=1410.53  MinDist=5.83  Conflicts=1
# [IT  3500] T=0.0978  BestPenalized=2455.74  BestCleanDist=1204.34  CurrCleanDist=1204.34  MinDist=6.08  Conflicts=0
# [IT  3000] T=0.2091  BestPenalized=2023.49  BestCleanDist=1263.49  CurrCleanDist=1263.49  MinDist=2.83  Conflicts=4
# [IT  3500] T=0.0978  BestPenalized=2079.83  BestCleanDist=1124.98  CurrCleanDist=1236.34  MinDist=5.00  Conflicts=2
# [IT  3500] T=0.0978  BestPenalized=2198.01  BestCleanDist=1166.36  CurrCleanDist=1171.36  MinDist=5.00  Conflicts=2
# [IT  4000] T=0.0457  BestPenalized=2489.12  BestCleanDist=1264.72  CurrCleanDist=1264.72  MinDist=6.08  Conflicts=0
# [IT  3000] T=0.2091  BestPenalized=1979.98  BestCleanDist=1424.73  CurrCleanDist=1424.73  MinDist=7.62  Conflicts=0
# [IT  3000] T=0.2091  BestPenalized=2131.45  BestCleanDist=1400.70  CurrCleanDist=1400.70  MinDist=5.83  Conflicts=1
# [IT  4000] T=0.0457  BestPenalized=2455.74  BestCleanDist=1204.34  CurrCleanDist=1204.34  MinDist=6.08  Conflicts=0
# [IT  3500] T=0.0978  BestPenalized=2010.13  BestCleanDist=1257.08  CurrCleanDist=1257.08  MinDist=2.83  Conflicts=4
# [IT  4000] T=0.0457  BestPenalized=2079.83  BestCleanDist=1124.98  CurrCleanDist=1227.34  MinDist=5.00  Conflicts=2
# [IT  4000] T=0.0457  BestPenalized=2193.66  BestCleanDist=1167.71  CurrCleanDist=1167.71  MinDist=5.00  Conflicts=2
# [IT  4500] T=0.0214  BestPenalized=2480.17  BestCleanDist=1259.72  CurrCleanDist=1259.72  MinDist=6.08  Conflicts=0
# [IT  3500] T=0.0978  BestPenalized=2123.34  BestCleanDist=1394.29  CurrCleanDist=1394.29  MinDist=5.83  Conflicts=1
# [IT  3500] T=0.0978  BestPenalized=1979.98  BestCleanDist=1424.73  CurrCleanDist=1424.73  MinDist=7.62  Conflicts=0
# [IT  4500] T=0.0214  BestPenalized=2447.44  BestCleanDist=1199.34  CurrCleanDist=1199.34  MinDist=6.08  Conflicts=0
# [IT  4000] T=0.0457  BestPenalized=2002.62  BestCleanDist=1255.32  CurrCleanDist=1255.32  MinDist=2.83  Conflicts=4
# [IT  4500] T=0.0214  BestPenalized=2191.66  BestCleanDist=1165.71  CurrCleanDist=1165.71  MinDist=5.00  Conflicts=2
# [IT  4500] T=0.0214  BestPenalized=2079.83  BestCleanDist=1124.98  CurrCleanDist=1221.34  MinDist=5.00  Conflicts=2
# [IT  5000] T=0.0100  BestPenalized=2459.51  BestCleanDist=1252.06  CurrCleanDist=1252.06  MinDist=6.08  Conflicts=0
#
# ===== SA COMPLETADO =====
# Mejor fitness penalizado = 2459.513
# Mejor distancia real     = 1252.063
# Tiempo = 20.81 s
# [IT  4000] T=0.0457  BestPenalized=1929.62  BestCleanDist=1385.87  CurrCleanDist=1385.87  MinDist=6.08  Conflicts=0
# [IT  4000] T=0.0457  BestPenalized=1979.98  BestCleanDist=1424.73  CurrCleanDist=1424.73  MinDist=7.62  Conflicts=0
# [IT  5000] T=0.0100  BestPenalized=2444.02  BestCleanDist=1195.92  CurrCleanDist=1195.92  MinDist=6.08  Conflicts=0
#
# ===== SA COMPLETADO =====
# Mejor fitness penalizado = 2444.021
# Mejor distancia real     = 1195.921
# Tiempo = 19.37 s
# [IT  5000] T=0.0100  BestPenalized=2191.66  BestCleanDist=1165.71  CurrCleanDist=1165.71  MinDist=5.00  Conflicts=2
#
# ===== SA COMPLETADO =====
# Mejor fitness penalizado = 2191.658
# Mejor distancia real     = 1165.708
# Tiempo = 18.86 s
# [IT  4500] T=0.0214  BestPenalized=1997.79  BestCleanDist=1250.49  CurrCleanDist=1250.49  MinDist=2.83  Conflicts=4
# [IT  5000] T=0.0100  BestPenalized=2079.83  BestCleanDist=1124.98  CurrCleanDist=1221.34  MinDist=5.00  Conflicts=2
#
# ===== SA COMPLETADO =====
# Mejor fitness penalizado = 2079.830
# Mejor distancia real     = 1124.980
# Tiempo = 20.41 s
# [IT  4500] T=0.0214  BestPenalized=1893.05  BestCleanDist=1376.05  CurrCleanDist=1376.05  MinDist=6.08  Conflicts=0
# [IT  4500] T=0.0214  BestPenalized=1973.53  BestCleanDist=1440.53  CurrCleanDist=1440.53  MinDist=7.62  Conflicts=0
# [IT  5000] T=0.0100  BestPenalized=1997.79  BestCleanDist=1250.49  CurrCleanDist=1250.49  MinDist=2.83  Conflicts=4
#
# ===== SA COMPLETADO =====
# Mejor fitness penalizado = 1997.789
# Mejor distancia real     = 1250.489
# Tiempo = 19.50 s
# [IT  5000] T=0.0100  BestPenalized=1887.39  BestCleanDist=1370.39  CurrCleanDist=1370.39  MinDist=6.08  Conflicts=0
#
# ===== SA COMPLETADO =====
# Mejor fitness penalizado = 1887.389
# Mejor distancia real     = 1370.389
# Tiempo = 20.35 s
# [IT  5000] T=0.0100  BestPenalized=1973.53  BestCleanDist=1440.53  CurrCleanDist=1440.53  MinDist=7.62  Conflicts=0
#
# ===== SA COMPLETADO =====
# Mejor fitness penalizado = 1973.531
# Mejor distancia real     = 1440.531
# Tiempo = 22.42 s
#
# ============================================================
# Experiments completed!
# Successful: 31
# Failed: 0
# Total time: 1.58 minutes
# Average time per run: 3.05 seconds
# ============================================================

# %% [markdown]
# ## 7. Statistical Analysis

# %%
import pandas as pd
from scipy import stats

# Load results from database
con = sqlite3.connect(DB_PATH)
df = pd.read_sql_query("SELECT * FROM runs", con)
con.close()

print(f"Total runs in database: {len(df)}")
df.head()
# Out:
# Total runs in database: 31
#    id  n_iter  start_temp  end_temp  seed  best_penalized   best_clean  \
# 0   1    5000        20.0      0.01     5     1885.755194  1210.205194
# 1   2    5000        20.0      0.01     7     1797.297835  1271.447835
# 2   3    5000        20.0      0.01     3     2187.859523  1383.359523
# 3   4    5000        20.0      0.01     4     2285.882611  1329.832611
# 4   5    5000        20.0      0.01     0     2718.954689  1318.104689
#
#     time_sec            timestamp
# 0  23.075649  2025-12-11 11:41:41
# 1  23.944516  2025-12-11 11:41:42
# 2  24.188920  2025-12-11 11:41:42
# 3  24.435895  2025-12-11 11:41:42
# 4  24.665557  2025-12-11 11:41:43

# %%
# Statistical summary
print("\n" + "="*80)
print("SA STATISTICAL SUMMARY")
print("="*80)
print(f"\nConfiguration: n_iter={BEST_PARAMS['n_iter']}, start_temp={BEST_PARAMS['start_temp']}, "
      f"end_temp={BEST_PARAMS['end_temp']}")
print(f"Number of runs: {len(df)}\n")

# Best Penalized
print(f"Best Penalized:")
print(f"  Mean: {df['best_penalized'].mean():.2f}")
print(f"  Std: {df['best_penalized'].std():.2f}")
print(f"  Min: {df['best_penalized'].min():.2f}")
print(f"  Max: {df['best_penalized'].max():.2f}")
print(f"  Median: {df['best_penalized'].median():.2f}")

# Best Clean
print(f"\nBest Clean:")
print(f"  Mean: {df['best_clean'].mean():.2f}")
print(f"  Std: {df['best_clean'].std():.2f}")
print(f"  Min: {df['best_clean'].min():.2f}")
print(f"  Max: {df['best_clean'].max():.2f}")
print(f"  Median: {df['best_clean'].median():.2f}")

# Computation Time
print(f"\nComputation Time (seconds):")
print(f"  Mean: {df['time_sec'].mean():.2f}")
print(f"  Std: {df['time_sec'].std():.2f}")
print(f"  Min: {df['time_sec'].min():.2f}")
print(f"  Max: {df['time_sec'].max():.2f}")

# 95% Confidence intervals
ci_penalized = stats.t.interval(0.95, len(df)-1, 
                                 loc=df['best_penalized'].mean(),
                                 scale=stats.sem(df['best_penalized']))
ci_clean = stats.t.interval(0.95, len(df)-1,
                            loc=df['best_clean'].mean(),
                            scale=stats.sem(df['best_clean']))

print(f"\n95% Confidence Intervals:")
print(f"  Best Penalized: [{ci_penalized[0]:.2f}, {ci_penalized[1]:.2f}]")
print(f"  Best Clean: [{ci_clean[0]:.2f}, {ci_clean[1]:.2f}]")
# Out:
# ================================================================================
# SA STATISTICAL SUMMARY
# ================================================================================
#
# Configuration: n_iter=5000, start_temp=20, end_temp=0.01
# Number of runs: 31
#
# Best Penalized:
#   Mean: 2135.03
#   Std: 288.19
#   Min: 1668.14
#   Max: 2779.87
#   Median: 2108.30
#
# Best Clean:
#   Mean: 1279.46
#   Std: 83.00
#   Min: 1124.98
#   Max: 1464.79
#   Median: 1271.52
#
# Computation Time (seconds):
#   Mean: 23.24
#   Std: 1.95
#   Min: 19.14
#   Max: 27.38
#
# 95% Confidence Intervals:
#   Best Penalized: [2029.32, 2240.74]
#   Best Clean: [1249.01, 1309.90]

# %% [markdown]
# ## 8. Normality Tests

# %%
# Shapiro-Wilk test for normality
stat_pen, p_pen = stats.shapiro(df['best_penalized'])
stat_clean, p_clean = stats.shapiro(df['best_clean'])

print("\n=== Normality Tests (Shapiro-Wilk) ===")
print(f"Best Penalized: stat={stat_pen:.4f}, p-value={p_pen:.4f}")
print(f"  -> {'Normal distribution' if p_pen > 0.05 else 'Not normal distribution'} (α=0.05)")
print(f"\nBest Clean: stat={stat_clean:.4f}, p-value={p_clean:.4f}")
print(f"  -> {'Normal distribution' if p_clean > 0.05 else 'Not normal distribution'} (α=0.05)")
# Out:
# === Normality Tests (Shapiro-Wilk) ===
# Best Penalized: stat=0.9498, p-value=0.1545
#   -> Normal distribution (α=0.05)
#
# Best Clean: stat=0.9805, p-value=0.8271
#   -> Normal distribution (α=0.05)

# %% [markdown]
# ## 9. Export Results

# %%
# Export all results to CSV
df.to_csv('../results/individual/sa_all_results.csv', index=False)
print("✓ All results exported to sa_all_results.csv")

# Export summary statistics
summary = pd.DataFrame({
    'metric': ['best_penalized', 'best_clean', 'time_sec'],
    'mean': [df['best_penalized'].mean(), df['best_clean'].mean(), df['time_sec'].mean()],
    'std': [df['best_penalized'].std(), df['best_clean'].std(), df['time_sec'].std()],
    'min': [df['best_penalized'].min(), df['best_clean'].min(), df['time_sec'].min()],
    'max': [df['best_penalized'].max(), df['best_clean'].max(), df['time_sec'].max()],
    'median': [df['best_penalized'].median(), df['best_clean'].median(), df['time_sec'].median()]
})
summary.to_csv('../results/individual/sa_statistical_summary.csv', index=False)
print("✓ Statistical summary exported to sa_statistical_summary.csv")
# Out:
# ✓ All results exported to sa_all_results.csv
# ✓ Statistical summary exported to sa_statistical_summary.csv
